# %% [markdown]
# # Kalman Filter

# %%
# include libraries
import numpy as np
import math
import csv
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# %% [markdown]
# # Needed Functions

# %%
def CSV_Read_Lidar_data(data_path):
    rows = []
    with open(data_path, 'r') as file:
        csvreader = csv.reader(file)
        for row in csvreader:
            rows.append(row)

    dataframe = pd.DataFrame([rows[0], rows[1], rows[2], rows[3]], ['Rho', 'Alpha', 'X', 'Y'])

    return dataframe

# %%
def covarience_line_fitting(points_in_line, line_alpha_rho, sigma_angle=0, sigma_dist=.005):
    sigma_angle = sigma_angle * np.ones(len(points_in_line))
    sigma_dist = sigma_dist * np.ones(len(points_in_line))

    data = np.array(points_in_line)

    #INPUIT IS X AND Y POINTS WITHIN A LINE
    dist = line_alpha_rho[1]  # whatever positions stores the distances from 0,0
    angle = line_alpha_rho[0]  # whatever positions stores the angles with the x axis
    
    x = data[:,0]
    y = data[:,1]

    n = len(x)
    x_bar = sum(x) / n
    y_bar = sum(y) / n

    S_x2 = sum((x - x_bar) ** 2)
    S_y2 = sum((y - y_bar) ** 2)
    S_xy = sum((x - x_bar) * (y - y_bar))

    # line paramters based on inputs data
    alpha = 0.5 * math.atan2(-2 * S_xy, S_y2 - S_x2)
    rho = x_bar * math.cos(alpha) + y_bar * math.sin(alpha)

    C_l = np.zeros(2)
    for i in range(0, n - 1):
        # The covariance of the measurement
        C_m = np.array([[sigma_angle[i], 0],
                        [0, sigma_dist[i]]])
        A = np.zeros((2, 2))

        # The jacobian of the line fit with respect to x and y
        A[1, 0] = ((y_bar - y[i]) * (S_y2 - S_x2) + 2 * S_xy * (x_bar - x[i])) / ((S_y2 - S_x2) ** 2 + 4 * S_xy ** 2)

        A[1, 1] = ((x_bar - x[i]) * (S_y2 - S_x2) - 2 * S_xy * (y_bar - y[i])) / ((S_y2 - S_x2) ** 2 + 4 * S_xy **2)

        A[0, 0] = math.cos(alpha) / n - x_bar * math.sin(alpha) * A[1, 0] + y_bar * math.cos(alpha) * A[1, 0]
        A[0, 1] = math.sin(alpha) / n - x_bar * math.sin(alpha) * A[1, 1] + y_bar * math.cos(alpha) * A[1, 1]

        # Jacobian of function converting dist and angle to x and y

        B = np.array([[math.cos(angle), -dist * math.sin(angle)],
                      [math.sin(angle), dist * math.cos(angle)]])
        J = A @ B
        C_l = C_l + J * C_m * J.T

    return rho, alpha, C_l

# %%
# Bunch of algorithms for split and merge

def GetPolar(X, Y):
    # center the data
    X = X - np.mean(X)
    Y = Y - np.mean(Y)
    # fit line through the first and last point (X and Y contains 2 points, start and end of the line)
    k, n = np.polyfit(X, Y, 1)
    alpha = math.atan(-1 / k)  # in radians
    ro = n / (math.sin(alpha) - k * math.cos(alpha))
    return ro, alpha

def Cartesian2Polar(x, y):
    r = np.sqrt(x ** 2 + y ** 2)
    phi = np.arctan2(y, x)
    return r, phi

def CheckPolar(ro, alpha):
    if ro < 0:
        alpha = alpha + math.pi
        if alpha > math.pi:
            alpha = alpha - 2 * math.pi
        ro = -ro
    return ro, alpha

def getDistance(P, Ps, Pe):  # point to line distance, where the line is given with points Ps and Pe
    if np.all(np.equal(Ps, Pe)):
        return np.linalg.norm(P - Ps)
    return np.divide(np.abs(np.linalg.norm(np.cross(Pe - Ps, Ps - P))), np.linalg.norm(Pe - Ps))

def GetMostDistant(P):
    dmax = 0
    index = -1
    for i in range(1, P.shape[0]):
        d = getDistance(P[i, :], P[0, :], P[-1, :])
        if (d > dmax):
            index = i
            dmax = d
    return dmax, index

def points_within_radius(mainpoint, points, r):
    result = []
    for point in points:
        if math.dist(mainpoint, point) <= r:
            result.append(point)
    return result

def gap_detection(lines, points, threshold):
    good_lines = []
    points_in_thresh_total = []
    for i in range(len(lines)):
        # get point 1 and point 2 of the line
        point_1 = lines[i][0]
        point_2 = lines[i][1]

        # get the distance of the line, then take a certain percentage of it (remember its based off both sides)
        line_dist = math.dist(point_2, point_1)
        r = line_dist / 2 * 0.10
        # print(r)

        # check all the points to see if they fall in theshold, store if they do
        points_in_thresh = []

        for j in range(len(points)):
            # distance = point_to_line_distance(points[j], lines[i])
            distance = getDistance(points[j], lines[i][0], lines[i][1])
            if distance <= (threshold * 1):
                # if distance < r:
                points_in_thresh.append(points[j])
        
        if len(points_in_thresh) <= 5 and line_dist <= 0.3:
            good_lines.append(lines[i])
            points_in_thresh_total.append(points_in_thresh)
            continue

        # check to see what % of points are between the threshold of the first and last point (might need my own threshold)
        p1_points = points_within_radius(point_1, points_in_thresh, r)
        p2_points = points_within_radius(point_2, points_in_thresh, r)
        # print(len(p1_points))
        # print(len(p2_points))
        # print(len(points_in_thresh))

        percent_in_radius = (len(p1_points) + len(p2_points)) / (len(points_in_thresh))
        # print(percent_in_radius)

        if percent_in_radius <= 0.40:
            # print("good line")
            good_lines.append(lines[i])
            points_in_thresh_total.append(points_in_thresh)
        # else:
        #     print("bad line")
        # plt.show()
        # print("\n")
        
    return good_lines, points_in_thresh_total

def SplitAndMerge(P, threshold):
    d, ind = GetMostDistant(P)
    if d > threshold:
        P1 = SplitAndMerge(P[:ind + 1, :], threshold)  # split and merge left array
        P2 = SplitAndMerge(P[ind:, :], threshold)  # split and merge right array
        # there are 2 "d" points, so exlude 1 (for example from 1st array)
        points = np.vstack((P1[:-1, :], P2))
    else:
        points = np.vstack((P[0, :], P[-1, :]))
    return points

def flatten(lst):
    result = []
    for item in lst:
        if isinstance(item, list):
            result.extend(flatten(item))
        else:
            result.append(item)
    return result

'~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'

def Algorithm_split_and_merge(inputdataframe, threshold=0.3, plot=False):

    P = np.array([list(inputdataframe['X']), list(inputdataframe['Y'])]).T

    points = SplitAndMerge(P, threshold)

    lines = []
    for i in range(len(points) - 1):
        lines.append([points[i], points[i + 1]])
        # plt.plot([points[i][0], points[i+1][0]], [points[i][1], points[i+1][1]], '-o')
    # final_lines = lines
    final_lines, points_in_line = gap_detection(lines, P, threshold)

    # flatten it to get the shitty points
    flat_list = flatten(final_lines)
    flat_list.append(flat_list[0])
    flat_list = np.array(flat_list)

    #convert from xy back to alpha rho
    alpha_rho = []
    for i in range(len(final_lines)):
        alpha, rho = GetPolar([final_lines[i][0][0], final_lines[i][1][0]], [final_lines[i][0][1], final_lines[i][1][1]])
        alpha_rho.append([alpha - 1.52, rho])

    if plot==True:
        # plt.figure()
        # plt.title('og')
        # plt.scatter(P[:, 0], P[:, 1], c='black')
        # plt.plot(points[:, 0], points[:, 1])

        # plt.figure()
        # plt.title('with gap detection')
        # plt.scatter(P[:, 0], P[:, 1], c='black')
        # plt.plot(flat_list[:, 0], flat_list[:, 1], '-o')

        plt.figure()
        plt.title('actual Lines')
        plt.scatter(P[:, 0], P[:, 1], c='black')
        for i in range(len(final_lines)):
            tmp = np.array(final_lines[i])
            plt.plot(tmp[:, 0], tmp[:, 1], '-o')
        # print(len(lines))
        # print(len(final_lines))
        plt.scatter(0, 0, c='red')  # replace this with the origin point
        plt.show()

    return final_lines, points_in_line, alpha_rho

# %%
def matching(z_hat_t,z_t,R_t,H_j,P_hat_t,g):

    matches = []
    v_t_matches = []
    sigmas_matches = []
    H_matches = []
    #initializedng vt
    #max((pittypoot.shape))
    v_t = np.zeros((2,1,max(z_t.shape),max(z_hat_t.shape)))
    sigma_itt = np.zeros((2,2,max(z_t.shape),max(z_hat_t.shape)))
    #This could be vectorized or whatever but i think itll be okay
    for i in range(max(z_t.shape)):
        for j in range(max(z_hat_t.shape)):
           
            v_t[:,0,i,j] = z_t[:,0,i] - z_hat_t[:,0,j]
            
            sigma_itt[:,:,i,j] = H_j[:,:,j] @ P_hat_t @ H_j[:,:,j].T + R_t[i]


    # Mahalanobis distance

   
    for i in range(max(z_t.shape)):
        mah_dist_best = g**2
        save_latch = False
        for j in range(max(z_hat_t.shape)):
        # for j in range(12):
            v_ = v_t[:,:,i,j]
            sigma_ = sigma_itt[:,:,i,j]
            # print(v_)
            # print(v_.T)
            mah_dist = v_.T @ sigma_ @ v_
            
            if mah_dist <= g**2:
                
                if mah_dist <= mah_dist_best:
                    ibest = i
                    jbest = j
                    save_latch = True
                    mah_dist_best = mah_dist
                    
        if save_latch == True:
            print('bestmatch',ibest,jbest,'mah_dist_best',mah_dist_best)
            matches.append([ibest,jbest])
            v_t_matches.append(v_t[:,:,ibest,jbest])
            sigmas_matches.append(sigma_itt[:,:,ibest,jbest])
            H_matches.append(H_j[:,:,jbest])

    # print(matches)

                
    return matches, v_t_matches, sigmas_matches,H_matches

# %%
def pos_estimation(H_t, x_hat, v_t,P_t_hat,sigmas):
 
    #for number of matched lines
    for i in range(len(H_t)):
        K_t = P_t_hat @ H_t[i].T @ np.linalg.pinv(sigmas[i])
        # print(f'H_t = {H_t}')
        P_t = P_t_hat - K_t @ sigmas[i] @ K_t.T

        x_t = x_hat + K_t @ v_t[i]
        x_hat = x_t

    if len(H_t) == 0:
        x_t = x_hat
        P_t = P_t_hat
        return x_t, P_t

    
    return x_t, P_t

# %%
def pos_estimation_v2(H_t, x_hat, v_t,P_t_hat,sigma):
 
    #for number of matched lines
    
    K_t = P_t_hat @ H_t.T @ np.linalg.pinv(sigma)
    # print(f'H_t = {H_t}')
    P_t = P_t_hat - K_t @ sigma @ K_t.T

    x_t = x_hat + K_t @ v_t
    x_hat = x_t

   
    return x_t, P_t

# %%
def measurement_prediction(x_hat, gt_map_df):
    """
    The measurements needs to take the MAP data and move the lines into the Robts frame (from world) THEN match lines together or something
    x_hat = 
    map = gt map
    data = observed map data
    """
    N = int(gt_map_df.shape[1])
    z_hat_t = np.zeros([2, 1, N]) # The pridiction of what the Lines detected should be, from map
    alpha_map = gt_map_df.loc['Alpha'].astype(float)
    rho_map = gt_map_df.loc['rhos'].astype(float)

    z_hat_t[0,0,:] = alpha_map[:] - x_hat[2] # removing the robots orientation in the world to rotate the line angles into frame
    z_hat_t[1,0,:] = rho_map[:]-x_hat[0]*np.cos(alpha_map[:])+x_hat[1]*np.sin(alpha_map[:]) # translation portion for the lines

    H_j = np.zeros([2,3,N])

    for k in range(N):
        H_j[:,:,k] = np.array([[0,  0,  -1],  
                    [-np.cos(alpha_map[k]), -np.sin(alpha_map[k]), 0]])  #it might not be able to handle this notation. Could easily be a loop

    return z_hat_t,H_j

# %%
# TODO pos_t_minus1 needs to be updated to previous x_hat_t after initial time step -Rob

# %%
def position_prediction(pos_t_minus1, delta_sl, delta_sr, b,P_t_minus1):

    delta_sl
    delta_sr

    theta_t_minus1 = pos_t_minus1[2]
  
    x_hat = np.empty((3,1))

    

    # This is previous postion + estimate of future position
    x_hat = np.add(pos_t_minus1, np.array([[(delta_sr+delta_sl) / 2 * (math.cos(theta_t_minus1 + (delta_sr-delta_sl) / 2 / b))],
                                    [(delta_sr+delta_sl) / 2 * (math.sin(theta_t_minus1 + (delta_sr-delta_sl) / 2 / b))],
                                    [(delta_sr-delta_sl) / b]]))
    
    delta_s = (delta_sr+delta_sl)/2
    delta_theta = (delta_sr-delta_sl) / b

    k_r =  .001
    k_l =  .001

    Q_t  = np.array([[k_r * abs(delta_sr), 0],
                    [0, k_l * abs(delta_sl) ]])
    F_deltarl = np.array([  [.5*math.cos(theta_t_minus1+delta_theta/2)-delta_s/2/b*math.sin(theta_t_minus1+delta_theta/2),.5*math.cos(theta_t_minus1+delta_theta/2)+delta_s/2/b*math.sin(theta_t_minus1+delta_theta/2)],
                            [.5*math.sin(theta_t_minus1+delta_theta/2)+delta_s/2/b*math.cos(theta_t_minus1+delta_theta/2),.5*math.sin(theta_t_minus1+delta_theta/2)-delta_s/2/b*math.cos(theta_t_minus1+delta_theta/2)],
                            [1/b,-1/b]])

    F_k_minus_1 = np.array([[1, 0, -delta_s*math.sin(theta_t_minus1+delta_theta/2)],
                            [0, 1,  delta_s*math.cos(theta_t_minus1+delta_theta/2)],
                            [0, 0, 1]])
    
    #TODO PUT IN THE FU MATRICXZ
    # @ is matrix multiplication
    P_t_minus1_2 = P_t_minus1 * np.identity(3)
    P_hat_t = F_k_minus_1 @ P_t_minus1_2 @ F_k_minus_1.T + F_deltarl@ Q_t @ F_deltarl.T
    # pos_t_minus1 = x_hat
    return x_hat, P_hat_t

# %% [markdown]
# # Initializing map

# %% [markdown]
# Ground Truth Map Generation

# %%
file_path = 'Data_Readers_Writers/Data/'
file_name = 'DownstairsScan_not_move_GT_LineData'
# file_name = 'Downstairsdata_GT_LineData'

data_path = file_path + file_name + '.pkl'

ground_truth_df = pd.read_pickle(data_path)
ground_truth_df = ground_truth_df.T
ground_truth_df
# Out:
#                                                                    0   \
# Alpha                                                        1.528933
# rhos                                                        -1.398482
# Covariance          [[1.4555015353985783e-09, 0.0], [0.0, 6.362433...
# Lines_(endpoints)   [[0.008152954618842993, -1.4039763717795215], ...
# Points_within_line  [[0.008152954618842993, -1.4039763717795215], ...
#
#                                                                    1   \
# Alpha                                                       -0.041175
# rhos                                                         6.485009
# Covariance          [[0.005981340029956629, 0.0], [0.0, 5.71429541...
# Lines_(endpoints)   [[6.258016649308644, -4.906274947628477], [6.2...
# Points_within_line  [[6.258016649308644, -4.906274947628477], [6.2...
#
#                                                                    2   \
# Alpha                                                       -0.639583
# rhos                                                          7.59319
# Covariance          [[0.0008748717973357287, 0.0], [0.0, 0.0084381...
# Lines_(endpoints)   [[6.228536477844267, -4.270601601129469], [6.4...
# Points_within_line  [[6.228536477844267, -4.270601601129469], [6.2...
#
#                                                                    3   \
# Alpha                                                        1.128703
# rhos                                                        -0.951883
# Covariance          [[1.934309383732514e-06, 0.0], [0.0, 7.9765064...
# Lines_(endpoints)   [[6.420783042874593, -4.081079035993247], [9.0...
# Points_within_line  [[0.5743819549423546, -1.4245635861035562], [0...
#
#                                                                    4   \
# Alpha                                                       -1.018859
# rhos                                                         9.276771
# Covariance          [[0.036633361399042726, 0.0], [0.0, 0.01104819...
# Lines_(endpoints)   [[9.090249923490891, -5.342591637984422], [9.3...
# Points_within_line  [[9.090249923490891, -5.342591637984422], [9.1...
#
#                                                                    5   \
# Alpha                                                       -1.497866
# rhos                                                         5.828866
# Covariance          [[4.6447851608477636e-05, 0.0], [0.0, 0.000661...
# Lines_(endpoints)   [[9.325660242370995, -5.122662232645176], [10....
# Points_within_line  [[9.29575597651457, -5.176729482115324], [9.32...
#
#                                                                    6   \
# Alpha                                                       -0.048548
# rhos                                                         4.942724
# Covariance          [[2.205959962349593e-06, 0.0], [0.0, 7.2596445...
# Lines_(endpoints)   [[4.839291570539102, -1.9675957044508525], [4....
# Points_within_line  [[4.839291570539102, -1.9675957044508525], [4....
#
#                                                                    7   \
# Alpha                                                        1.242191
# rhos                                                         1.000041
# Covariance          [[8.044530938787486e-07, 0.0], [0.0, 5.1053556...
# Lines_(endpoints)   [[4.905512354160249, -0.6156965504840072], [4....
# Points_within_line  [[4.901962050651213, -0.7021918910551128], [4....
#
#                                                                    8   \
# Alpha                                                       -0.196845
# rhos                                                         4.538875
# Covariance          [[3.525275431347958e-05, 0.0], [0.0, 6.3848124...
# Lines_(endpoints)   [[4.525753944453946, -0.48811438311895666], [4...
# Points_within_line  [[4.530791838903417, -0.5152909767069598], [4....
#
#                                                                    9   ...  \
# Alpha                                                       -1.387999  ...
# rhos                                                         1.093727  ...
# Covariance          [[1.4232551286207996e-07, 0.0], [0.0, 7.326368...  ...
# Lines_(endpoints)   [[4.569036792890612, -0.25235043152339126], [4...  ...
# Points_within_line  [[4.5639475243253225, -0.3319050320241136], [4...  ...
#
#                                                                    72  \
# Alpha                                                       -0.035465
# rhos                                                         4.926635
# Covariance          [[2.6514062105338167e-06, 0.0], [0.0, 4.811054...
# Lines_(endpoints)   [[4.9244883747137544, -0.18600533359420515], [...
# Points_within_line  [[4.839291570539102, -1.9675957044508525], [4....
#
#                                                                    73  \
# Alpha                                                       -1.078447
# rhos                                                         1.973851
# Covariance          [[3.469228555854677e-06, 0.0], [0.0, 9.9762617...
# Lines_(endpoints)   [[4.934459464359772, 0.4164314979423046], [5.0...
# Points_within_line  [[1.2877492887309843, -1.4509658822275002], [1...
#
#                                                                    74  \
# Alpha                                                        0.090297
# rhos                                                          5.09891
# Covariance          [[2.0904623401293395e-05, 0.0], [0.0, 2.187326...
# Lines_(endpoints)   [[5.064666355671715, 0.4867205371300136], [4.9...
# Points_within_line  [[5.003666694550037, 0.4515498824871636], [5.0...
#
#                                                                    75  \
# Alpha                                                        1.540337
# rhos                                                         1.914135
# Covariance          [[3.747290198379295e-08, 0.0], [0.0, 3.6479133...
# Lines_(endpoints)   [[4.937863383954888, 1.7773606057528046], [2.4...
# Points_within_line  [[4.960502196179552, 1.688495058629504], [4.95...
#
#                                                                    76  \
# Alpha                                                       -0.951685
# rhos                                                        -0.106735
# Covariance          [[3.959373773899206e-06, 0.0], [0.0, 5.0906425...
# Lines_(endpoints)   [[2.4204055380131626, 1.8525500329389983], [1....
# Points_within_line  [[2.5802720319183767, 1.8586545310723082], [2....
#
#                                                                    77  \
# Alpha                                                        1.516715
# rhos                                                         1.619326
# Covariance          [[3.0498013163140266e-09, 0.0], [0.0, 7.774659...
# Lines_(endpoints)   [[1.979545860093206, 1.5334320754059498], [1.5...
# Points_within_line  [[5.033523948091735, 1.2060737490589615], [5.0...
#
#                                                                    78  \
# Alpha                                                       -0.817356
# rhos                                                        -0.080885
# Covariance          [[3.0685515377954927e-06, 0.0], [0.0, 3.070852...
# Lines_(endpoints)   [[1.5604549321799335, 1.564953856586494], [1.1...
# Points_within_line  [[1.6888472576099294, 1.5613438830438124], [1....
#
#                                                                    79  \
# Alpha                                                        1.386155
# rhos                                                         1.393266
# Covariance          [[8.3249982917495e-08, 0.0], [0.0, 6.777710364...
# Lines_(endpoints)   [[1.1527930461452152, 1.1832886498696593], [0....
# Points_within_line  [[4.928818655176071, 0.38714385373536986], [4....
#
#                                                                    80  \
# Alpha                                                       -0.050623
# rhos                                                         0.822196
# Covariance          [[5.109496126744668e-06, 0.0], [0.0, 1.1854879...
# Lines_(endpoints)   [[0.8836948105030336, 1.2342639515749838], [0....
# Points_within_line  [[0.6549158432821173, -1.429079886560556], [0....
#
#                                                                    81
# Alpha                                                        1.518756
# rhos                                                          1.61811
# Covariance          [[2.460134558921752e-09, 0.0], [0.0, 5.5117093...
# Lines_(endpoints)   [[0.9012990914707864, 1.5857603700411165], [-5...
# Points_within_line  [[5.034204207156025, 1.2371920460687211], [5.0...
#
# [5 rows x 82 columns]

# %%
ground_truth_df
gt_endpoints = ground_truth_df.loc['Lines_(endpoints)']
# gt_endpoints
fig = plt.figure()
plt.title('map')
# ax = fig.add_subplot()
for i in range(max(ground_truth_df.shape)):
    # print(np.array(gt_endpoints[i]))
    apl = ground_truth_df.loc['Alpha'].astype(float)[i]
    rh = ground_truth_df.loc['rhos'].astype(float)[i]
    pts_2_plt = np.array(gt_endpoints[i])

    plt.plot(pts_2_plt[:, 0], pts_2_plt[:, 1],'-')
    plt.text((pts_2_plt[0, 0]+pts_2_plt[1, 0])/2,(pts_2_plt[0, 1]+pts_2_plt[1, 1])/2,'r = '+str(round(rh,3)) +'\n'+ ' a '+str(round(apl,3))+'\n'+ 'j'+str(i))
plt.scatter(0, 0, c='red')  # replace this with the origin point
plt.show()

# %% [markdown]
# # 1. Robot Position Prediction

# %%
'''
robot pos prediction ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
'''
# Some values that are global


b = .235 # distance between robots wheels (meters)
wheel_radius = 0.072 # radius of the actual wheel (meters)

"""
These are the uncertainties in the are error constants representing the 
nondeterministic parameters of the motor drive and the wheel-floor interaction. Probably can be found in DOC or just tune for it
"""

# Pull these from ros, page 337, displacewmnt of left and right wheel
# ut = [delta_sl, delta_sr].T
#TODO When converting to robot version, get these update every time step
delta_sl = 0.0
delta_sr = 0.0

# pos_t_minus1 is the [x_t-1, y_t-1, theta_t-1] position of the robot x_t-1
# the robot drives forward with the control input ut (above) to a position vector xt
# Both are world frames
#TODO get a value for this
pos_t_minus1 = np.array([[0],
                        [0],
                        [0]])
# initialize covarience matrix TODO intiialize this beter
# P_t_minus1 = 0.1
P_t_minus1 = np.array([[10, 0, 0],
                    [0, 10, 0],                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  
                    [0, 0, .9]])

g = .3

# %% [markdown]
# # 2. Observation

# %%
# Load datapath and put into dataframe
# path to csv data
data_path = 'Data_Readers_Writers/Data/DownstairsScan_not_move_scan_data_organized.csv'
# data_path = 'Data_Readers_Writers/Data/DownstairsScanV2_scan_data_organized.csv'

tmp_df = pd.read_csv(data_path)

#read and turn to list
lowrange = 0
highrange = 1070

scan_df = []
for i in range(int(tmp_df.shape[0]/1070)):
    lowrange = 0 + 1070 * i
    highrange = lowrange + 1070
    scan_df.append(tmp_df.iloc[lowrange:highrange, :])

# Delete any column that has an inf in the rho spot
for i in range(len(scan_df)):
    inf_cols = scan_df[i]['Rho'][np.isfinite(scan_df[i]['Rho'])]
    # print(inf_cols.index)
    scan_df[i] = scan_df[i].T[inf_cols.index].T.reset_index(drop=True)
scan_df
# Out:
# [          Rho     Alpha         X         Y
#  0    1.422072  0.168214  1.362451  0.330652
#  1    1.425026  0.171997  1.362449  0.339041
#  2    1.428001  0.175764  1.362395  0.347441
#  3    1.430995  0.179515  1.362290  0.355852
#  4    1.434010  0.183250  1.362132  0.364274
#  ..        ...       ...       ...       ...
#  774  1.669746  0.329354  1.355140  0.812402
#  775  1.677306  0.331473  1.355527  0.823372
#  776  1.684873  0.333573  1.355833  0.834374
#  777  1.694336  0.335265  1.357754  0.846466
#  778  1.701916  0.337328  1.357889  0.857540
#
#  [779 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    1.709503  0.339371  1.357941  0.868643
#  1    1.717097  0.341397  1.357909  0.879777
#  2    1.724699  0.343405  1.357794  0.890939
#  3    1.730425  0.345787  1.355929  0.901022
#  4    1.739922  0.347368  1.357311  0.913347
#  ..        ...       ...       ...       ...
#  754  2.260174  0.392847  1.353979  1.589492
#  755  2.273482  0.393186  1.352454  1.606508
#  756  2.286792  0.393521  1.350778  1.623559
#  757  2.303796  0.393186  1.351488  1.643734
#  758  2.306027  0.395512  1.341921  1.651555
#
#  [759 rows x 4 columns],
#             Rho     Alpha         X          Y
#  0     7.800232  0.120147  4.599005   6.230465
#  1     7.800930  0.120886  4.562747   6.257066
#  2     7.801632  0.121625  4.526336   6.283456
#  3     7.762640  0.122993  4.466581   6.277043
#  4     7.763354  0.123735  4.430055   6.302875
#  ..         ...       ...       ...        ...
#  746  11.314571  0.101795  4.600173  10.273068
#  747  11.434543  0.101234  4.588846  10.409413
#  748  11.506761  0.101104  4.556982  10.501934
#  749  11.507348  0.101606  4.495921  10.528219
#  750  11.579567  0.101474  4.462600  10.620528
#
#  [751 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    5.031470  0.245995  1.652804  4.591584
#  1    5.032888  0.247114  1.626113  4.601104
#  2    5.034311  0.248233  1.599367  4.610469
#  3    5.035741  0.249351  1.572567  4.619679
#  4    5.037177  0.250468  1.545715  4.628733
#  ..        ...       ...       ...       ...
#  746  4.397441  0.351876  0.227645  4.121718
#  747  4.391941  0.353745  0.203312  4.114980
#  748  4.408962  0.353724  0.180109  4.132077
#  749  4.410977  0.354959  0.156112  4.133053
#  750  4.412999  0.356193  0.132109  4.133890
#
#  [751 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    4.415027  0.357425  0.108101  4.134587
#  1    4.417062  0.358657  0.084090  4.135145
#  2    4.411617  0.360526  0.059960  4.127564
#  3    4.413668  0.361757  0.035990  4.127843
#  4    4.415727  0.362987  0.012019  4.127982
#  ..        ...       ...       ...       ...
#  774  4.969512  0.379462 -1.231305  4.448746
#  775  4.986525  0.379356 -1.261476  4.456916
#  776  4.996107  0.379842 -1.289559  4.457201
#  777  4.998263  0.380921 -1.315420  4.449637
#  778  5.007849  0.381404 -1.343549  4.449582
#
#  [779 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    5.032287  0.380700 -1.376435  4.464640
#  1    5.034448  0.381771 -1.402338  4.456572
#  2    5.044036  0.382248 -1.430639  4.455970
#  3    5.061047  0.382133 -1.461470  4.462793
#  4    5.063216  0.383198 -1.487361  4.454231
#  ..        ...       ...       ...       ...
#  739  5.061378  0.406964 -1.948643  4.219797
#  740  5.048997  0.409274 -1.966323  4.193924
#  741  5.051311  0.410329 -1.990643  4.182435
#  742  5.038969  0.412652 -2.007937  4.156398
#  743  5.004701  0.416920 -2.014431  4.108752
#
#  [744 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    3.903558  0.606208 -1.949797  2.547461
#  1    3.906870  0.607430 -1.964557  2.536096
#  2    3.910187  0.608649 -1.979251  2.524645
#  3    3.897132  0.612806 -1.981447  2.497441
#  4    3.887409  0.616395 -1.985899  2.473416
#  ..        ...       ...       ...       ...
#  755  3.439831  0.809903 -1.887739  1.436254
#  756  3.444038  0.811065 -1.896047  1.425268
#  757  3.448251  0.812225 -1.904292  1.414233
#  758  3.466239  0.809190 -1.928598  1.414982
#  759  3.475963  0.808677 -1.943259  1.408454
#
#  [760 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    3.480166  0.809829 -1.951406  1.397146
#  1    3.484374  0.810978 -1.959486  1.385791
#  2    3.219064  0.905146 -1.629746  1.138452
#  3    3.223634  0.906258 -1.636329  1.128969
#  4    3.223286  0.909323 -1.636246  1.114943
#  ..        ...       ...       ...       ...
#  767  3.314744  1.015329 -1.656378  0.558495
#  768  3.317575  1.017276 -1.655795  0.547611
#  769  3.320419  1.019220 -1.655142  0.536753
#  770  3.323275  1.021161 -1.654419  0.525921
#  771  3.327185  1.022585 -1.655536  0.515710
#
#  [772 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    3.331102  1.024006 -1.656590  0.505504
#  1    3.335026  1.025424 -1.657581  0.495303
#  2    3.339992  1.026326 -1.660429  0.485669
#  3    3.342893  1.028249 -1.659376  0.474918
#  4    3.346837  1.029657 -1.660180  0.464735
#  ..        ...       ...       ...       ...
#  778  3.396116  1.181167 -1.290000  0.000021
#  779  3.401488  1.181815 -1.289978 -0.007470
#  780  3.407620  1.181918 -1.291913 -0.014984
#  781  3.412994  1.182564 -1.291804 -0.022486
#  782  3.418369  1.183207 -1.291652 -0.029987
#
#  [783 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    3.424502  1.183307 -1.293455 -0.037545
#  1    3.429879  1.183947 -1.293215 -0.045055
#  2    3.436011  1.184045 -1.294930 -0.052645
#  3    3.441390  1.184682 -1.294603 -0.060164
#  4    3.446770  1.185316 -1.294232 -0.067681
#  ..        ...       ...       ...       ...
#  753  3.890659  1.099650 -1.673453 -0.564191
#  754  3.895835  1.100327 -1.670148 -0.573900
#  755  3.902824  1.100088 -1.670563 -0.584910
#  756  3.908907  1.100306 -1.669022 -0.595273
#  757  3.914989  1.100523 -1.667417 -0.605638
#
#  [758 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    3.921072  1.100739 -1.665748 -0.616004
#  1    3.927155  1.100955 -1.664014 -0.626371
#  2    3.934144  1.100717 -1.664084 -0.637454
#  3    3.941133  1.100479 -1.664081 -0.648559
#  4    3.949030  1.099791 -1.665865 -0.660423
#  ..        ...       ...       ...       ...
#  754  4.191365  1.084191 -1.657216 -1.046534
#  755  4.367076  1.054464 -1.708270 -1.315351
#  756  4.372127  1.055119 -1.700603 -1.325249
#  757  4.377180  1.055774 -1.692879 -1.335102
#  758  4.380268  1.057221 -1.681971 -1.342414
#
#  [759 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    4.389258  1.056284 -1.680371 -1.357186
#  1    4.398252  1.055350 -1.678656 -1.371983
#  2    4.407250  1.054420 -1.676826 -1.386806
#  3    4.418231  1.052707 -1.677947 -1.404222
#  4    4.429225  1.051003 -1.678922 -1.421696
#  ..        ...       ...       ...       ...
#  774  5.110744  0.936666 -1.697822 -2.507226
#  775  5.127287  0.934194 -1.694352 -2.533668
#  776  5.151027  0.929869 -1.697244 -2.570167
#  777  5.177270  0.924966 -1.701954 -2.610136
#  778  5.203636  0.920113 -1.706256 -2.650244
#
#  [779 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    5.222817  0.917130 -1.703712 -2.680362
#  1    5.242044  0.914169 -1.700875 -2.710539
#  2    5.266223  0.910029 -1.701958 -2.747574
#  3    5.292960  0.905333 -1.704753 -2.788125
#  4    5.322298  0.900094 -1.709202 -2.832224
#  ..        ...       ...       ...       ...
#  760  7.222390  0.640243 -2.243783 -5.339728
#  761  7.270825  0.636282 -2.234132 -5.404420
#  762  6.808785  0.696263 -1.769393 -4.915224
#  763  6.812510  0.696917 -1.740821 -4.925416
#  764  6.816239  0.697571 -1.712190 -4.935441
#
#  [765 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    9.882138  0.506795  0.726428 -8.609408
#  1    9.884958  0.507308  0.776410 -8.605045
#  2    9.887780  0.507822  0.826366 -8.600391
#  3    9.897594  0.507941  0.877105 -8.603406
#  4    9.900420  0.508454  0.927050 -8.598167
#  ..        ...       ...       ...       ...
#  731  7.309488  0.632380 -2.252470 -5.448779
#  732  7.332285  0.631084 -2.229831 -5.484000
#  733  7.032177  0.669994 -1.866940 -5.186201
#  734  7.035785  0.670641 -1.836793 -5.196955
#  735  7.039395  0.671287 -1.806583 -5.207533
#
#  [736 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    9.879462  0.509636  0.924477 -8.574305
#  1    9.882297  0.510149  0.974252 -8.568792
#  2    9.885134  0.510662  1.023994 -8.562990
#  3    6.177202  0.969209  1.297818 -3.246180
#  4    6.181991  0.969740  1.316646 -3.238589
#  ..        ...       ...       ...       ...
#  737  6.199928  0.963890  1.312667 -3.283322
#  738  6.204699  0.964424  1.331711 -3.275644
#  739  6.168755  0.974551  1.323207 -3.201315
#  740  6.173561  0.975079  1.341774 -3.193578
#  741  6.151585  0.982068  1.341447 -3.141588
#
#  [742 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    6.156415  0.982592  1.359668 -3.133745
#  1    6.130376  0.990717  1.355255 -3.074554
#  2    6.109078  0.997810  1.353470 -3.022824
#  3    6.088090  1.004952  1.351131 -2.971219
#  4    6.069536  1.011584  1.349916 -2.923376
#  ..        ...       ...       ...       ...
#  760  5.804897  1.203592  1.351333 -1.586491
#  761  5.803174  1.207168  1.347466 -1.563467
#  762  5.802936  1.210101  1.346007 -1.543557
#  763  5.804149  1.212389  1.347008 -1.526717
#  764  5.806789  1.214030  1.350524 -1.512901
#
#  [765 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    5.812230  1.214378  1.359286 -1.505033
#  1    5.812807  1.216984  1.358559 -1.486779
#  2    5.811362  1.220559  1.353593 -1.464179
#  3    5.812032  1.223164  1.352510 -1.446070
#  4    5.814774  1.224798  1.355386 -1.432380
#  ..        ...       ...       ...       ...
#  748  5.919108  1.285128  1.372921 -0.947266
#  749  5.924680  1.285404  1.378398 -0.939278
#  750  5.930815  1.285356  1.385489 -0.932374
#  751  5.937514  1.284985  1.394211 -0.926527
#  752  5.945344  1.283969  1.406256 -0.922804
#
#  [753 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    5.962851  1.317200  1.304860 -0.731680
#  1    5.968473  1.317444  1.309087 -0.724090
#  2    5.974095  1.317688  1.313270 -0.716476
#  3    5.981723  1.316636  1.324453 -0.712629
#  4    5.987344  1.316880  1.328569 -0.704925
#  ..        ...       ...       ...       ...
#  750  6.194656  1.342163  1.360446 -0.346992
#  751  6.199860  1.342689  1.360497 -0.338603
#  752  6.205065  1.343215  1.360497 -0.330225
#  753  6.210722  1.343426  1.362391 -0.322319
#  754  6.215930  1.343950  1.362291 -0.313953
#
#  [755 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    4.901785  0.048590  4.757889  1.154688
#  1    4.902071  0.049774  4.751104  1.182298
#  2    4.910353  0.050874  4.751910  1.211844
#  3    4.918641  0.051970  4.752533  1.241440
#  4    4.934923  0.052977  4.760701  1.273150
#  ..        ...       ...       ...       ...
#  743  5.150716  0.075609  4.752152  1.948218
#  744  5.183064  0.076259  4.770296  1.988091
#  745  5.223391  0.076785  4.795502  2.031360
#  746  5.247767  0.077537  4.805670  2.068662
#  747  5.280121  0.078164  4.822894  2.109356
#
#  [748 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    0.548900  1.339181  0.108443  0.064158
#  1    0.554553  1.341585  0.108068  0.064786
#  2    0.560210  1.343940  0.107690  0.065413
#  3    0.565869  1.346248  0.107308  0.066037
#  4    0.571312  1.350217  0.106075  0.066130
#  ..        ...       ...       ...       ...
#  742  5.621669  0.148256  3.750675  4.104392
#  743  5.662088  0.148227  3.753589  4.155787
#  744  5.694595  0.148406  3.750704  4.201385
#  745  5.711278  0.148997  3.736830  4.235092
#  746  5.727964  0.149585  3.722690  4.268779
#
#  [747 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    5.752562  0.149961  3.713508  4.308504
#  1    5.777160  0.150335  3.703989  4.348265
#  2    5.801760  0.150705  3.694133  4.388061
#  3    5.842178  0.150660  3.694172  4.440188
#  4    6.135819  0.144355  3.856315  4.690205
#  ..        ...       ...       ...       ...
#  767  2.805089  0.424606  1.031038  2.338824
#  768  2.803845  0.427081  1.015847  2.341102
#  769  2.795347  0.430750  0.997523  2.335926
#  770  2.783259  0.435046  0.977743  2.326928
#  771  2.782087  0.437545  0.962686  2.328870
#
#  [772 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    2.780933  0.440046  0.947640  2.330716
#  1    2.776183  0.443166  0.931119  2.328751
#  2    2.771459  0.446296  0.914654  2.326673
#  3    2.770366  0.448810  0.899686  2.328214
#  4    2.772891  0.450697  0.886151  2.333399
#  ..        ...       ...       ...       ...
#  796  2.364962  0.676583  0.165766  1.836534
#  797  2.365490  0.679556  0.154762  1.833480
#  798  2.372251  0.680401  0.144426  1.838335
#  799  2.374357  0.682832  0.133603  1.837148
#  800  2.378025  0.684726  0.122933  1.837893
#
#  [801 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    2.380156  0.687147  0.112136  1.836580
#  1    2.382300  0.689564  0.101359  1.835203
#  2    2.379842  0.693585  0.090306  1.827771
#  3    2.382023  0.695997  0.079603  1.826266
#  4    2.384218  0.698404  0.068922  1.824699
#  ..        ...       ...       ...       ...
#  809  2.803260  0.700029 -0.499579  2.084984
#  810  2.810061  0.700692 -0.512633  2.085932
#  811  2.819920  0.700437 -0.526691  2.090677
#  812  2.829780  0.700184 -0.540822  2.095330
#  813  2.833525  0.701751 -0.552981  2.092154
#
#  [814 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    2.840329  0.702403 -0.566165  2.092769
#  1    2.847135  0.703052 -0.579375  2.093301
#  2    2.860046  0.701889 -0.594789  2.101448
#  3    2.857702  0.705248 -0.604759  2.090274
#  4    2.858429  0.707702 -0.615752  2.082890
#  ..        ...       ...       ...       ...
#  821  3.230640  0.720382 -1.290472  2.056664
#  822  3.234474  0.721731 -1.302393  2.049136
#  823  3.247320  0.720632 -1.320766  2.051628
#  824  3.260170  0.719542 -1.339211  2.053976
#  825  3.273025  0.718460 -1.357728  2.056178
#
#  [826 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    3.282870  0.718187 -1.374092  2.054910
#  1    3.292715  0.717917 -1.390487  2.053520
#  2    3.305575  0.716852 -1.409174  2.055308
#  3    3.312406  0.717380 -1.423367  2.050376
#  4    3.325268  0.716323 -1.442149  2.051894
#  ..        ...       ...       ...       ...
#  808  3.582455  0.735656 -1.965838  1.786005
#  809  3.586354  0.736856 -1.976177  1.774560
#  810  3.575489  0.741817 -1.971490  1.749778
#  811  3.573527  0.744528 -1.975604  1.733025
#  812  3.583346  0.744207 -1.991678  1.726764
#
#  [813 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    2.558176  1.521523 -0.104942  0.069737
#  1    2.563976  1.521634 -0.105345  0.069126
#  2    2.569776  1.521745 -0.105745  0.068513
#  3    2.575576  1.521856 -0.106141  0.067898
#  4    2.581328  1.522353 -0.105688  0.066747
#  ..        ...       ...       ...       ...
#  785  3.533370  0.872371 -2.059892  0.958557
#  786  3.537820  0.873427 -2.065423  0.946579
#  787  3.550576  0.905408 -2.060279  0.748409
#  788  3.555146  0.906417 -2.064590  0.736432
#  789  3.559720  0.907422 -2.068831  0.724431
#
#  [790 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    3.556930  0.911086 -2.061655  0.708505
#  1    3.559073  0.912974 -2.061944  0.695243
#  2    3.561229  0.914860 -2.062149  0.682002
#  3    3.563398  0.916743 -2.062269  0.668782
#  4    3.565579  0.918624 -2.062306  0.655583
#  ..        ...       ...       ...       ...
#  814  3.721035  0.987972 -2.046756  0.071375
#  815  3.728085  0.987933 -2.051134  0.059605
#  816  3.732935  0.988789 -2.051446  0.047693
#  817  3.724665  0.995029 -2.027692  0.035361
#  818  3.706867  1.005386 -1.985866  0.023097
#
#  [819 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    3.698985  1.011705 -1.961967  0.011425
#  1    3.700735  1.013912 -1.956000  0.000032
#  2    3.704610  1.015199 -1.953967 -0.011315
#  3    3.714822  1.013736 -1.963868 -0.022777
#  4    3.719753  1.014562 -1.963703 -0.034181
#  ..        ...       ...       ...       ...
#  796  3.996550  1.032770 -1.962289 -0.586283
#  797  4.005638  1.031798 -1.966503 -0.600003
#  798  4.012675  1.031685 -1.966804 -0.612601
#  799  4.019712  1.031573 -1.967026 -0.625224
#  800  4.024696  1.032314 -1.963362 -0.636636
#
#  [801 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    4.031733  1.032201 -1.963430 -0.649282
#  1    4.040823  1.031238 -1.967207 -0.663228
#  2    4.047860  1.031128 -1.967106 -0.675941
#  3    4.056954  1.030172 -1.970698 -0.689996
#  4    4.063992  1.030063 -1.970425 -0.702772
#  ..        ...       ...       ...       ...
#  798  4.334664  1.014743 -1.962399 -1.176408
#  799  4.345936  1.013103 -1.965791 -1.194013
#  800  4.355098  1.012250 -1.965637 -1.209601
#  801  4.362143  1.012178 -1.961975 -1.223111
#  802  4.367068  1.012883 -1.954839 -1.234483
#
#  [803 rows x 4 columns]]

# %%
pittypoot = np.zeros([12,36,1000])
max((pittypoot.shape))
# Out:
# 1000

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)


all_xt = []
all_xhat = []
# for robot_scans in range(len(scan_df)):
for robot_scans in range(10):

    # print(f'pos_t_minus1 = {pos_t_minus1}')
    x_hat, P_hat_t = position_prediction(pos_t_minus1, delta_sl, delta_sr, b, P_t_minus1)
    # print(f'x_hat = {x_hat}')
    
    # print(f'p_hat_t = {P_hat_t}')


    '''
    OBSERVATION ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    '''

    # Run the split and merge and get covar
    # apply the split and merge algorithm


    Lines, points_in_line, line_alpha_rho = Algorithm_split_and_merge(scan_df[robot_scans].astype(float),threshold=0.1, plot=False)

    # Do covarience line fitting, save data to lists
    alphas = []
    rhos = []
    covars = []
    for i in range(len(points_in_line)):
        rho, alpha, C_l = covarience_line_fitting(points_in_line[i], line_alpha_rho[i])
        # line_info.append([alpha, rho, C_l])
        alphas.append(alpha)
        rhos.append(rho)
        covars.append(C_l)

    print(covars)
    # Create a dataframe with the good info
    all_scan_df = pd.DataFrame([alphas, rhos, covars, Lines, points_in_line], ['Alpha','rhos' ,'Covariance', 'Lines (endpoints)', ' Points within line'])



    # alpha and rho from the lidar data
    z_t = np.array([[all_scan_df.loc['Alpha'].astype(float)],
                [all_scan_df.loc['rhos'].astype(float)]])
    
    # Covariane matrix for eachlinec calculated
    R_t = np.array(all_scan_df.loc['Covariance'])

    '''
    MEASUREMENT PREDICTION ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    '''
    ground_truth_df
    z_hat_t, H_j = measurement_prediction(x_hat, ground_truth_df)


    '''
    MATCHING ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    '''
    print(z_hat_t.shape)
    print(z_t.shape)
    matches, v_t_matches, sigmas_matches, H_j = matching(z_hat_t, z_t, R_t, H_j, P_hat_t, g)

   
    print(matches)
    for match in matches:
        i = match[0]
        j = match[1]
        print('robot_measurement',z_t[:,:,i])
        print('world frame match',z_hat_t[:,:,j])
    
    '''
    ESTIMATION ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    '''
    print(f'Scan {robot_scans}')
    print(f'x_hat = {x_hat}')
    # x_t, P_t = pos_estimation(H_j, x_hat, v_t_matches, P_hat_t, sigmas_matches)
    all_xhat.append(x_hat)
    for i in range(len(H_j)):
        
        x_t, P_t = pos_estimation_v2(H_j[i], x_hat, v_t_matches[i], P_hat_t, sigmas_matches[i])
        print(x_t-x_hat)
        x_hat = x_t
        P_hat_t = P_t
    
    if len(H_j) < 1:
        P_t = P_hat_t
        x_t = x_hat
    P_t_minus1 = P_t

    pos_t_minus1 = x_t


    
    
    
    # print(f'pos_t_minus1 = {pos_t_minus1}')

    all_xt.append(x_t)
    print(f'x_t = {x_t}')

    
    
    print(f'covarience = {P_t}')

    print('\n')
    print('\n')
# Out:
# [array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 2.4468963e-09]]), array([[0.        , 0.        ],
#        [0.        , 0.00030511]]), array([[0.        , 0.        ],
#        [0.        , 0.02067812]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.94002473e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.03072023]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.22997702e-06]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 7.0126352e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.56949826e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00043239]]), array([[0.       , 0.       ],
#        [0.       , 0.0012276]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.31463182e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.62138101e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.66556298e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.46350813e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.63169615e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.16257375e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.37584952e-05]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 3.0863843e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.88902559e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.71537638e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.48442241e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00166741]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.11855151e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.56265072e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.67267359e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.88835685e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.08325776e-09]])]
# (2, 1, 82)
# (2, 1, 27)
# bestmatch 18 30 mah_dist_best [[0.04326044]]
# [[18, 30]]
# robot_measurement [[1.46082244]
#  [0.65923905]]
# world frame match [[1.32234845]
#  [0.60953074]]
# Scan 0
# x_hat = [[0.1]
#  [0. ]
#  [0. ]]
# [[-0.00892939]
#  [-0.04901764]
#  [-0.13847399]]
# x_t = [[ 0.09107061]
#  [-0.04901764]
#  [-0.13847399]]
# covarience = [[ 9.39537769e+00 -2.38350588e+00 -8.69084479e-18]
#  [-2.38350588e+00  6.04671720e-01 -1.38777878e-17]
#  [-1.02790027e-17 -2.77555756e-17  0.00000000e+00]]
#
#
#
#
# [array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 3.1034277e-09]]), array([[0.        , 0.        ],
#        [0.        , 0.00265901]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.55801579e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00593895]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.28241657e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.19526669e-05]]), array([[0.        , 0.        ],
#        [0.        , 0.03577003]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.27606891e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.99244061e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.21238837e-06]]), array([[0.       , 0.       ],
#        [0.       , 0.0005264]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.02235388e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.87944579e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.56957297e-05]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 7.2776729e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.88027635e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.63472393e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00040502]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.12874036e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.17681478e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.17234718e-05]]), array([[0.        , 0.        ],
#        [0.        , 0.00173812]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 5.5922462e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.47861798e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00142242]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.60366919e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00123788]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.11026986e-12]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.12297124e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.79577839e-09]])]
# (2, 1, 82)
# (2, 1, 30)
# bestmatch 0 60 mah_dist_best [[0.01103615]]
# bestmatch 4 7 mah_dist_best [[0.01631634]]
# bestmatch 5 5 mah_dist_best [[0.00864304]]
# bestmatch 8 47 mah_dist_best [[0.05818474]]
# bestmatch 9 26 mah_dist_best [[0.00951497]]
# bestmatch 10 47 mah_dist_best [[0.06726986]]
# bestmatch 11 7 mah_dist_best [[0.01932996]]
# bestmatch 12 12 mah_dist_best [[0.03441137]]
# bestmatch 15 39 mah_dist_best [[0.02095071]]
# bestmatch 18 39 mah_dist_best [[0.07262282]]
# bestmatch 19 39 mah_dist_best [[0.07672384]]
# bestmatch 20 39 mah_dist_best [[0.07672383]]
# bestmatch 21 45 mah_dist_best [[0.0194507]]
# bestmatch 22 22 mah_dist_best [[0.02774447]]
# bestmatch 23 39 mah_dist_best [[0.00198191]]
# bestmatch 25 3 mah_dist_best [[0.00855031]]
# bestmatch 26 5 mah_dist_best [[0.0195587]]
# bestmatch 27 60 mah_dist_best [[0.01121253]]
# bestmatch 28 39 mah_dist_best [[0.05332803]]
# bestmatch 29 60 mah_dist_best [[0.01103615]]
# [[0, 60], [4, 7], [5, 5], [8, 47], [9, 26], [10, 47], [11, 7], [12, 12], [15, 39], [18, 39], [19, 39], [20, 39], [21, 45], [22, 22], [23, 39], [25, 3], [26, 5], [27, 60], [28, 39], [29, 60]]
# robot_measurement [[0.0070893]
#  [1.3582989]]
# world frame match [[1.50464373]
#  [1.30314034]]
# robot_measurement [[-0.3835237 ]
#  [ 0.93703955]]
# world frame match [[1.3806648 ]
#  [0.87922721]]
# robot_measurement [[0.13312073]
#  [5.90780474]]
# world frame match [[-1.35939229]
#  [ 5.87766731]]
# robot_measurement [[-1.56878555]
#  [-4.84905792]]
# world frame match [[ 1.65655347]
#  [-4.66941628]]
# robot_measurement [[-0.32468739]
#  [-1.2385352 ]]
# world frame match [[ 1.29471204]
#  [-1.24162329]]
# robot_measurement [[-1.5154846 ]
#  [-4.44722016]]
# world frame match [[ 1.65655347]
#  [-4.66941628]]
# robot_measurement [[0.22091707]
#  [0.97688709]]
# world frame match [[1.3806648 ]
#  [0.87922721]]
# robot_measurement [[1.53064125]
#  [4.84457135]]
# world frame match [[0.21795374]
#  [4.89949635]]
# robot_measurement [[ 0.71016438]
#  [-0.07569942]]
# world frame match [[-0.66329672]
#  [-0.1296517 ]]
# robot_measurement [[ 0.97705917]
#  [-0.01582452]]
# world frame match [[-0.66329672]
#  [-0.1296517 ]]
# robot_measurement [[ 0.99467315]
#  [-0.01235656]]
# world frame match [[-0.66329672]
#  [-0.1296517 ]]
# robot_measurement [[ 0.99467315]
#  [-0.01235656]]
# world frame match [[-0.66329672]
#  [-0.1296517 ]]
# robot_measurement [[-0.99123201]
#  [-1.40070577]]
# world frame match [[ 1.30918771]
#  [-1.38877578]]
# robot_measurement [[ 0.00559026]
#  [-1.66268322]]
# world frame match [[ 1.63432054]
#  [-1.49659667]]
# robot_measurement [[-0.57964618]
#  [-0.10957728]]
# world frame match [[-0.66329672]
#  [-0.1296517 ]]
# robot_measurement [[-0.2674168]
#  [-1.086752 ]]
# world frame match [[ 1.26717746]
#  [-1.0900007 ]]
# robot_measurement [[-1.46529947]
#  [ 5.70469789]]
# world frame match [[-1.35939229]
#  [ 5.87766731]]
# robot_measurement [[0.00229483]
#  [1.35945785]]
# world frame match [[1.50464373]
#  [1.30314034]]
# robot_measurement [[-1.02471867]
#  [-0.02533318]]
# world frame match [[-0.66329672]
#  [-0.1296517 ]]
# robot_measurement [[0.0070893]
#  [1.3582989]]
# world frame match [[1.50464373]
#  [1.30314034]]
# Scan 1
# x_hat = [[ 0.19011339]
#  [-0.06282083]
#  [-0.13847399]]
# [[-0.2459015 ]
#  [-0.0053016 ]
#  [ 1.49755443]]
# [[-0.06753857]
#  [ 0.01401637]
#  [ 0.        ]]
# [[-0.23459871]
#  [ 0.04868657]
#  [ 0.        ]]
# [[-0.0089646 ]
#  [ 0.00186044]
#  [ 0.        ]]
# [[-0.01513636]
#  [ 0.00314127]
#  [ 0.        ]]
# [[ 0.15981671]
#  [-0.03316697]
#  [ 0.        ]]
# [[-0.02056448]
#  [ 0.00426777]
#  [ 0.        ]]
# [[ 0.01142061]
#  [-0.00237013]
#  [ 0.        ]]
# [[-0.02207932]
#  [ 0.00458215]
#  [ 0.        ]]
# [[-0.0303961 ]
#  [ 0.00630814]
#  [ 0.        ]]
# [[-0.02627346]
#  [ 0.00545257]
#  [ 0.        ]]
# [[-0.02281018]
#  [ 0.00473383]
#  [ 0.        ]]
# [[-0.00699636]
#  [ 0.00145196]
#  [ 0.        ]]
# [[-0.01165268]
#  [ 0.0024183 ]
#  [ 0.        ]]
# [[-0.00263122]
#  [ 0.00054606]
#  [ 0.        ]]
# [[-0.00499961]
#  [ 0.00103758]
#  [ 0.        ]]
# [[ 0.04529912]
#  [-0.00940099]
#  [ 0.        ]]
# [[-7.04170389e-10]
#  [-2.83840496e-10]
#  [ 0.00000000e+00]]
# [[-0.00892667]
#  [ 0.00185256]
#  [ 0.        ]]
# [[-6.69591271e-10]
#  [-2.86437088e-10]
#  [ 0.00000000e+00]]
# x_t = [[-0.32282003]
#  [-0.01270495]
#  [ 1.35908044]]
# covarience = [[ 5.06215538e-01 -1.05055558e-01  8.76476739e-18]
#  [-1.05055558e-01  2.18023176e-02  3.72877082e-18]
#  [ 8.72410981e-18  3.72877082e-18 -3.60774832e-34]]
#
#
#
#
# [array([[0.        , 0.        ],
#        [0.        , 0.00037777]]), array([[0.        , 0.        ],
#        [0.        , 0.00155902]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.51289159e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00955589]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.26002406e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.13833236e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.56630374e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00043443]]), array([[0.        , 0.        ],
#        [0.        , 0.00073749]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.92580098e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.91971571e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.34174467e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00097308]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.36747494e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.65237223e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.68337944e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.66940662e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.97608562e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00042053]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.77194647e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.90233067e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00459754]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.65949041e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00704757]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 2.8371515e-11]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.19967534e-05]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.6221147e-09]]), array([[0.        , 0.        ],
#        [0.        , 0.00038095]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.86621417e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.60815247e-05]])]
# (2, 1, 82)
# (2, 1, 30)
# bestmatch 0 47 mah_dist_best [[0.05183834]]
# bestmatch 1 67 mah_dist_best [[0.03779347]]
# bestmatch 2 30 mah_dist_best [[0.00058593]]
# bestmatch 3 27 mah_dist_best [[0.08393756]]
# bestmatch 4 5 mah_dist_best [[0.03206221]]
# bestmatch 5 3 mah_dist_best [[0.00605425]]
# bestmatch 6 70 mah_dist_best [[0.03897008]]
# bestmatch 7 22 mah_dist_best [[0.00369231]]
# bestmatch 8 47 mah_dist_best [[0.0111933]]
# bestmatch 9 7 mah_dist_best [[0.00058369]]
# bestmatch 10 70 mah_dist_best [[0.03883511]]
# bestmatch 11 47 mah_dist_best [[0.00419126]]
# bestmatch 12 47 mah_dist_best [[0.01201206]]
# bestmatch 13 43 mah_dist_best [[0.0119776]]
# bestmatch 14 76 mah_dist_best [[0.0348926]]
# bestmatch 15 43 mah_dist_best [[0.00300013]]
# bestmatch 16 30 mah_dist_best [[0.03665792]]
# bestmatch 17 22 mah_dist_best [[0.00014707]]
# bestmatch 18 3 mah_dist_best [[0.00567609]]
# bestmatch 19 43 mah_dist_best [[0.00305807]]
# bestmatch 20 76 mah_dist_best [[0.01355697]]
# bestmatch 21 47 mah_dist_best [[0.00877734]]
# bestmatch 22 3 mah_dist_best [[0.00012444]]
# bestmatch 23 24 mah_dist_best [[0.00120743]]
# bestmatch 24 79 mah_dist_best [[0.00116216]]
# bestmatch 25 76 mah_dist_best [[0.00585537]]
# bestmatch 26 79 mah_dist_best [[0.00118043]]
# bestmatch 27 1 mah_dist_best [[0.03642502]]
# bestmatch 28 7 mah_dist_best [[0.00079015]]
# bestmatch 29 67 mah_dist_best [[0.03222172]]
# [[0, 47], [1, 67], [2, 30], [3, 27], [4, 5], [5, 3], [6, 70], [7, 22], [8, 47], [9, 7], [10, 70], [11, 47], [12, 47], [13, 43], [14, 76], [15, 43], [16, 30], [17, 22], [18, 3], [19, 43], [20, 76], [21, 47], [22, 3], [23, 24], [24, 79], [25, 76], [26, 79], [27, 1], [28, 7], [29, 67]]
# robot_measurement [[-1.48557108]
#  [-5.82928413]]
# world frame match [[ 0.15899904]
#  [-4.49581822]]
# robot_measurement [[0.40132954]
#  [6.05783877]]
# world frame match [[-2.82091917]
#  [ 6.13281259]]
# robot_measurement [[-0.41095523]
#  [ 0.82997847]]
# world frame match [[-0.03673199]
#  [ 0.79078523]]
# robot_measurement [[0.50712675]
#  [8.65876738]]
# world frame match [[-2.6093971 ]
#  [ 7.87183319]]
# robot_measurement [[0.11852565]
#  [5.77187162]]
# world frame match [[-2.85694672]
#  [ 5.76602129]]
# robot_measurement [[-0.44250776]
#  [-0.51507455]]
# world frame match [[-0.23037697]
#  [-0.74587639]]
# robot_measurement [[1.56583172]
#  [4.73148513]]
# world frame match [[-1.55905566]
#  [ 4.81637059]]
# robot_measurement [[-0.43096156]
#  [-1.62952776]]
# world frame match [[ 0.13676611]
#  [-1.31229403]]
# robot_measurement [[-1.56734891]
#  [-4.36444189]]
# world frame match [[ 0.15899904]
#  [-4.49581822]]
# robot_measurement [[0.28006652]
#  [1.19149266]]
# world frame match [[-0.11688963]
#  [ 1.17795155]]
# robot_measurement [[1.53440593]
#  [4.72489312]]
# world frame match [[-1.55905566]
#  [ 4.81637059]]
# robot_measurement [[-0.85949412]
#  [-4.6314173 ]]
# world frame match [[ 0.15899904]
#  [-4.49581822]]
# robot_measurement [[-1.51143729]
#  [-4.77471197]]
# world frame match [[ 0.15899904]
#  [-4.49581822]]
# robot_measurement [[-0.01008367]
#  [-2.02410945]]
# world frame match [[ 0.17082842]
#  [-1.3009353 ]]
# robot_measurement [[ 0.74361846]
#  [-0.07602425]]
# world frame match [[-2.31076577e+00]
#  [-8.67123209e-04]]
# robot_measurement [[-0.004893  ]
#  [-1.65771194]]
# world frame match [[ 0.17082842]
#  [-1.3009353 ]]
# robot_measurement [[ 0.95270741]
#  [-0.01359562]]
# world frame match [[-0.03673199]
#  [ 0.79078523]]
# robot_measurement [[-0.0575157 ]
#  [-1.33265228]]
# world frame match [[ 0.13676611]
#  [-1.31229403]]
# robot_measurement [[-1.45101357]
#  [-0.79658602]]
# world frame match [[-0.23037697]
#  [-0.74587639]]
# robot_measurement [[ 0.00196477]
#  [-1.66180745]]
# world frame match [[ 0.17082842]
#  [-1.3009353 ]]
# robot_measurement [[-0.56103782]
#  [-0.11515511]]
# world frame match [[-2.31076577e+00]
#  [-8.67123209e-04]]
# robot_measurement [[ 1.40904163]
#  [-4.16215237]]
# world frame match [[ 0.15899904]
#  [-4.49581822]]
# robot_measurement [[-0.28416506]
#  [-0.71378475]]
# world frame match [[-0.23037697]
#  [-0.74587639]]
# robot_measurement [[-1.45915743]
#  [ 6.96964257]]
# world frame match [[-1.43248695]
#  [ 6.92107849]]
# robot_measurement [[0.0031775 ]
#  [1.35798337]]
# world frame match [[0.02707417]
#  [1.5322922 ]]
# robot_measurement [[-1.04026116]
#  [-0.00718407]]
# world frame match [[-2.31076577e+00]
#  [-8.67123209e-04]]
# robot_measurement [[0.00552098]
#  [1.35658772]]
# world frame match [[0.02707417]
#  [1.5322922 ]]
# robot_measurement [[1.43284531]
#  [6.66344998]]
# world frame match [[-1.40025561]
#  [ 6.78305841]]
# robot_measurement [[-0.3839408]
#  [ 1.092106 ]]
# world frame match [[-0.11688963]
#  [ 1.17795155]]
# robot_measurement [[0.16119205]
#  [6.16334512]]
# world frame match [[-2.82091917]
#  [ 6.13281259]]
# Scan 2
# x_hat = [[-0.30180625]
#  [ 0.08506223]
#  [ 1.35908044]]
# [[1.41427241]
#  [1.23950646]
#  [1.64457012]]
# [[ 6.33559366e-02]
#  [-3.59336725e-03]
#  [ 1.33226763e-15]]
# [[-0.04138214]
#  [ 0.00173524]
#  [ 0.        ]]
# [[-8.57776039e-01]
#  [ 4.67129429e-02]
#  [ 1.33226763e-15]]
# [[-3.26631451e-02]
#  [ 2.25468115e-03]
#  [ 1.33226763e-15]]
# [[-0.10194267]
#  [ 0.00400332]
#  [ 0.        ]]
# [[-1.53072331e-02]
#  [ 7.31049946e-04]
#  [ 1.33226763e-15]]
# [[ 2.93050305e-02]
#  [ 3.02484347e-03]
#  [-4.44089210e-16]]
# [[-2.74252484e-03]
#  [-1.97064188e-03]
#  [-8.88178420e-16]]
# [[-0.00505598]
#  [ 0.00016858]
#  [ 0.        ]]
# [[-9.70877202e-03]
#  [ 4.82062842e-04]
#  [ 1.33226763e-15]]
# [[ 1.47093483e-03]
#  [ 1.79732727e-03]
#  [-4.44089210e-16]]
# [[ 2.89822470e-03]
#  [ 3.54132501e-03]
#  [-8.88178420e-16]]
# [[-0.01590149]
#  [ 0.0113009 ]
#  [ 0.        ]]
# [[-8.08292928e-03]
#  [ 4.46762874e-04]
#  [ 1.33226763e-15]]
# [[-0.00579264]
#  [ 0.00537556]
#  [ 0.        ]]
# [[ 1.74223168e-01]
#  [-3.39093738e-03]
#  [ 4.44089210e-16]]
# [[0.00108202]
#  [0.00019364]
#  [0.        ]]
# [[ 1.18590012e-02]
#  [-4.16244903e-04]
#  [-4.44089210e-16]]
# [[-0.00721564]
#  [ 0.00533832]
#  [ 0.        ]]
# [[ 8.22853543e-03]
#  [-4.79250584e-04]
#  [ 8.88178420e-16]]
# [[-1.90427369e-03]
#  [-3.50432560e-03]
#  [ 4.44089210e-16]]
# [[-0.004833 ]
#  [ 0.0001586]
#  [ 0.       ]]
# [[-0.00385681]
#  [ 0.0001954 ]
#  [ 0.        ]]
# [[0.02345621]
#  [0.00019434]
#  [0.        ]]
# [[-5.12618505e-03]
#  [ 3.16330388e-04]
#  [ 4.44089210e-16]]
# [[0.02136601]
#  [0.00029379]
#  [0.        ]]
# [[-1.34713395e-03]
#  [ 6.96181515e-05]
#  [ 1.33226763e-15]]
# [[ 0.01052028]
#  [-0.00019635]
#  [ 0.        ]]
# [[-1.38671142e-02]
#  [ 1.56115195e-03]
#  [ 1.33226763e-15]]
# x_t = [[0.32572579]
#  [1.40091337]
#  [3.00365057]]
# covarience = [[ 2.98115479e-02 -1.50909950e-03  6.36253911e-20]
#  [-1.50909950e-03  3.71945859e-04  3.40683101e-21]
#  [ 9.07304454e-20  3.40683101e-21 -1.73472348e-18]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.33241314e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00032808]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.16542549e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.75634069e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.33113878e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.51170005e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.10645804e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.01859366e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.65529328e-08]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 2.2036316e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.45234434e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.28755911e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00053395]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.01209067e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.16561114e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00412469]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.36574196e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.97724417e-12]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.17623932e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.39341164e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.89652716e-12]]), array([[0.        , 0.        ],
#        [0.        , 0.00016849]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.52780154e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00058743]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 2.0891181e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.88434455e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00010337]]), array([[0.        , 0.        ],
#        [0.        , 0.02928832]])]
# (2, 1, 82)
# (2, 1, 28)
# bestmatch 0 36 mah_dist_best [[0.03206044]]
# bestmatch 1 43 mah_dist_best [[0.00626294]]
# bestmatch 2 36 mah_dist_best [[0.02986704]]
# bestmatch 3 43 mah_dist_best [[0.011555]]
# bestmatch 4 36 mah_dist_best [[0.03106988]]
# bestmatch 5 47 mah_dist_best [[0.00121173]]
# bestmatch 6 47 mah_dist_best [[0.00801282]]
# bestmatch 7 43 mah_dist_best [[0.01841004]]
# bestmatch 8 47 mah_dist_best [[0.00812315]]
# bestmatch 9 43 mah_dist_best [[0.02226117]]
# bestmatch 10 43 mah_dist_best [[0.02301361]]
# bestmatch 11 47 mah_dist_best [[0.00687782]]
# bestmatch 12 22 mah_dist_best [[0.00030686]]
# bestmatch 13 47 mah_dist_best [[0.00827934]]
# bestmatch 14 43 mah_dist_best [[0.00309461]]
# bestmatch 15 47 mah_dist_best [[0.03696294]]
# bestmatch 16 47 mah_dist_best [[0.00678523]]
# bestmatch 17 43 mah_dist_best [[0.00795025]]
# bestmatch 18 43 mah_dist_best [[0.00070222]]
# bestmatch 19 43 mah_dist_best [[0.00073667]]
# bestmatch 20 43 mah_dist_best [[0.00795025]]
# bestmatch 21 36 mah_dist_best [[0.03319863]]
# bestmatch 22 43 mah_dist_best [[0.00484146]]
# bestmatch 23 36 mah_dist_best [[0.01977821]]
# bestmatch 24 43 mah_dist_best [[0.00383238]]
# bestmatch 25 36 mah_dist_best [[0.0317789]]
# bestmatch 26 43 mah_dist_best [[0.0059102]]
# bestmatch 27 14 mah_dist_best [[0.03922119]]
# [[0, 36], [1, 43], [2, 36], [3, 43], [4, 36], [5, 47], [6, 47], [7, 43], [8, 47], [9, 43], [10, 43], [11, 47], [12, 22], [13, 47], [14, 43], [15, 47], [16, 47], [17, 43], [18, 43], [19, 43], [20, 43], [21, 36], [22, 43], [23, 36], [24, 43], [25, 36], [26, 43], [27, 14]]
# robot_measurement [[1.55570756]
#  [4.59008882]]
# world frame match [[-1.45375767]
#  [ 3.29644224]]
# robot_measurement [[-0.36385252]
#  [-1.29384446]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[1.44562662]
#  [4.16658773]]
# world frame match [[-1.45375767]
#  [ 3.29644224]]
# robot_measurement [[0.3110563 ]
#  [1.32563726]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[1.50877365]
#  [4.566884  ]]
# world frame match [[-1.45375767]
#  [ 3.29644224]]
# robot_measurement [[-1.4423942 ]
#  [-4.76717644]]
# world frame match [[-1.48557108]
#  [-3.19591067]]
# robot_measurement [[ 1.70450724e-05]
#  [-2.00181145e+00]]
# world frame match [[-1.48557108]
#  [-3.19591067]]
# robot_measurement [[ 0.7770106 ]
#  [-0.06945876]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[-0.01361604]
#  [-1.66007517]]
# world frame match [[-1.48557108]
#  [-3.19591067]]
# robot_measurement [[ 1.00451288]
#  [-0.01458724]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[1.0472546]
#  [0.0091089]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[-0.17365538]
#  [-1.39968475]]
# world frame match [[-1.48557108]
#  [-3.19591067]]
# robot_measurement [[-1.51741708]
#  [-0.5603147 ]]
# world frame match [[-1.50780401]
#  [-0.02599766]]
# robot_measurement [[ 0.00181717]
#  [-1.66075417]]
# world frame match [[-1.48557108]
#  [-3.19591067]]
# robot_measurement [[-0.55279519]
#  [-0.05805578]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[ 1.42883453]
#  [-4.24966613]]
# world frame match [[-1.48557108]
#  [-3.19591067]]
# robot_measurement [[-0.1770542 ]
#  [-1.45326355]]
# world frame match [[-1.48557108]
#  [-3.19591067]]
# robot_measurement [[1.29652893e-03]
#  [1.36188410e+00]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[-1.03439562]
#  [-0.01306456]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[-1.02390404]
#  [-0.01635286]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[1.29652893e-03]
#  [1.36188410e+00]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[1.48085037]
#  [6.34349572]]
# world frame match [[-1.45375767]
#  [ 3.29644224]]
# robot_measurement [[-0.35164306]
#  [ 1.40704219]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[0.23393179]
#  [6.72540496]]
# world frame match [[-1.45375767]
#  [ 3.29644224]]
# robot_measurement [[-0.50848357]
#  [-0.6967133 ]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[1.54225288]
#  [4.53346489]]
# world frame match [[-1.45375767]
#  [ 3.29644224]]
# robot_measurement [[-0.32144738]
#  [-1.09318245]]
# world frame match [[-1.4737417 ]
#  [ 0.00595283]]
# robot_measurement [[1.26204621]
#  [4.02942453]]
# world frame match [[-1.48439212]
#  [ 3.37996062]]
# Scan 3
# x_hat = [[0.22667569]
#  [1.41466387]
#  [3.00365057]]
# [[-2.28772497]
#  [-1.24448063]
#  [-3.00946522]]
# [[ 9.59188268e-01]
#  [-1.93121001e-02]
#  [-8.54351312e-16]]
# [[-8.28671754e-04]
#  [-1.00971390e-03]
#  [-2.00273825e-15]]
# [[-1.63703827e+00]
#  [ 3.29610731e-02]
#  [-1.18481613e-15]]
# [[ 5.90971179e-04]
#  [-1.59456736e-03]
#  [-2.00360561e-15]]
# [[ 2.95401056e+00]
#  [-6.03343853e-02]
#  [-1.38777878e-16]]
# [[-2.31667871e+00]
#  [ 4.73171584e-02]
#  [-9.82720849e-16]]
# [[-4.15100820e-02]
#  [ 8.34229540e-04]
#  [-1.61416019e-15]]
# [[-2.70210134e+00]
#  [ 5.52102846e-02]
#  [-9.60169444e-16]]
# [[-1.04730001e-01]
#  [ 2.10272715e-03]
#  [-1.77375475e-15]]
# [[-1.27546487e-01]
#  [ 2.56082744e-03]
#  [-1.80324505e-15]]
# [[-2.83423597e+00]
#  [ 5.79527723e-02]
#  [-8.43942971e-16]]
# [[ 5.59137162e-01]
#  [-1.15832535e-02]
#  [-8.67361738e-19]]
# [[-2.19855323e+00]
#  [ 4.49189955e-02]
#  [-9.89659743e-16]]
# [[ 1.58682049e-02]
#  [-3.17346567e-04]
#  [-6.62664368e-16]]
# [[ 1.15558430e-01]
#  [-2.36190138e-03]
#  [-2.09814804e-15]]
# [[-2.30749572e+00]
#  [ 4.71629576e-02]
#  [-8.58688121e-16]]
# [[-1.17768854e+00]
#  [ 2.35276159e-02]
#  [-9.74914593e-16]]
# [[-2.24239333e-03]
#  [ 4.47980661e-05]
#  [-3.15719673e-16]]
# [[-6.19354570e-05]
#  [ 1.23733364e-06]
#  [-3.23525928e-16]]
# [[-1.11997036e+00]
#  [ 2.23745341e-02]
#  [-9.79251402e-16]]
# [[ 3.61549108e-02]
#  [-3.21935958e-03]
#  [-1.91426736e-15]]
# [[-1.11884085e+00]
#  [ 2.23527815e-02]
#  [-7.25981775e-16]]
# [[ 2.34679954e-02]
#  [-2.03194321e-03]
#  [-1.09114107e-15]]
# [[ 4.93993044e-01]
#  [-9.86945262e-03]
#  [-7.28583860e-16]]
# [[ 2.41174442e-02]
#  [-2.03469917e-03]
#  [-2.03222855e-15]]
# [[ 6.24483458e-01]
#  [-1.24771604e-02]
#  [-8.72565908e-16]]
# [[-1.26902364e-02]
#  [ 2.59641520e-04]
#  [-1.97324795e-15]]
# x_t = [[-1.39566916e+01]
#  [ 4.03618998e-01]
#  [-5.81465423e-03]]
# covarience = [[ 1.58836887e-02 -3.38964893e-04  5.66545571e-19]
#  [-3.38964893e-04  7.65662550e-06 -1.47112952e-19]
#  [ 5.46216780e-19 -1.74218006e-19  2.60208521e-18]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.36903845e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.48017131e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.90501609e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.43143464e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.16593545e-05]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.4213305e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.17233921e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.31547493e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.15903445e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.60564116e-11]]), array([[0.        , 0.        ],
#        [0.        , 0.15603567]]), array([[0.        , 0.        ],
#        [0.        , 0.00254668]]), array([[0.        , 0.        ],
#        [0.        , 0.00322255]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.86142871e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.16261247e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.52901818e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.37896756e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00018322]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 2.2441255e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.54840368e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.41193791e-06]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 5.7186401e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00047977]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.18525403e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.67313482e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.30896667e-06]])]
# (2, 1, 82)
# (2, 1, 26)
# bestmatch 0 43 mah_dist_best [[0.00413472]]
# bestmatch 1 18 mah_dist_best [[4.8413708e-05]]
# bestmatch 2 5 mah_dist_best [[0.01342673]]
# bestmatch 3 47 mah_dist_best [[0.00769181]]
# bestmatch 4 22 mah_dist_best [[0.0017634]]
# bestmatch 5 47 mah_dist_best [[0.00766701]]
# bestmatch 6 47 mah_dist_best [[0.001541]]
# bestmatch 7 47 mah_dist_best [[0.00882037]]
# bestmatch 8 22 mah_dist_best [[3.7947797e-05]]
# bestmatch 9 47 mah_dist_best [[0.00764478]]
# bestmatch 11 71 mah_dist_best [[0.00068989]]
# bestmatch 12 47 mah_dist_best [[0.06954902]]
# bestmatch 13 47 mah_dist_best [[0.00719459]]
# bestmatch 14 5 mah_dist_best [[0.00648376]]
# bestmatch 15 71 mah_dist_best [[0.00673836]]
# bestmatch 16 47 mah_dist_best [[0.00697474]]
# bestmatch 17 7 mah_dist_best [[0.00039275]]
# bestmatch 18 71 mah_dist_best [[0.00687847]]
# bestmatch 19 63 mah_dist_best [[0.00083812]]
# bestmatch 20 71 mah_dist_best [[0.01107717]]
# bestmatch 21 36 mah_dist_best [[7.34751418e-05]]
# bestmatch 22 47 mah_dist_best [[0.01452636]]
# bestmatch 23 5 mah_dist_best [[0.01084742]]
# bestmatch 24 22 mah_dist_best [[0.00496107]]
# bestmatch 25 79 mah_dist_best [[4.87356631e-05]]
# [[0, 43], [1, 18], [2, 5], [3, 47], [4, 22], [5, 47], [6, 47], [7, 47], [8, 22], [9, 47], [11, 71], [12, 47], [13, 47], [14, 5], [15, 71], [16, 47], [17, 7], [18, 71], [19, 63], [20, 71], [21, 36], [22, 47], [23, 5], [24, 22], [25, 79]]
# robot_measurement [[0.3856962 ]
#  [1.62992903]]
# world frame match [[ 1.53572352]
#  [-0.42915521]]
# robot_measurement [[1.49783619]
#  [4.44801004]]
# world frame match [[1.3883458 ]
#  [4.38273459]]
# robot_measurement [[-1.36233642]
#  [-4.72128027]]
# world frame match [[-1.49205162]
#  [ 6.43657377]]
# robot_measurement [[ 0.00339749]
#  [-1.9835947 ]]
# world frame match [[ 1.52389414]
#  [-3.46404474]]
# robot_measurement [[ 0.80836478]
#  [-0.06716173]]
# world frame match [[1.50166121]
#  [0.01977335]]
# robot_measurement [[-0.00503756]
#  [-1.66250117]]
# world frame match [[ 1.52389414]
#  [-3.46404474]]
# robot_measurement [[ 0.86467565]
#  [-0.32332053]]
# world frame match [[ 1.52389414]
#  [-3.46404474]]
# robot_measurement [[-0.12108782]
#  [-1.36757506]]
# world frame match [[ 1.52389414]
#  [-3.46404474]]
# robot_measurement [[1.5674096]
#  [0.3789827]]
# world frame match [[1.50166121]
#  [0.01977335]]
# robot_measurement [[-0.00285094]
#  [-1.66416443]]
# world frame match [[ 1.52389414]
#  [-3.46404474]]
# robot_measurement [[-1.43247374]
#  [ 3.68279964]]
# world frame match [[-1.3821848 ]
#  [ 3.21628183]]
# robot_measurement [[ 1.35456426]
#  [-8.05366296]]
# world frame match [[ 1.52389414]
#  [-3.46404474]]
# robot_measurement [[-0.00290864]
#  [ 1.3599402 ]]
# world frame match [[ 1.52389414]
#  [-3.46404474]]
# robot_measurement [[-1.03952233]
#  [-0.00859803]]
# world frame match [[-1.49205162]
#  [ 6.43657377]]
# robot_measurement [[-1.01863385]
#  [-0.01904036]]
# world frame match [[-1.3821848 ]
#  [ 3.21628183]]
# robot_measurement [[0.02101786]
#  [1.35773251]]
# world frame match [[ 1.52389414]
#  [-3.46404474]]
# robot_measurement [[1.50912794]
#  [6.11046471]]
# world frame match [[1.24800547]
#  [5.85339319]]
# robot_measurement [[-0.41238193]
#  [ 0.98889216]]
# world frame match [[-1.3821848 ]
#  [ 3.21628183]]
# robot_measurement [[0.0707179]
#  [5.3852326]]
# world frame match [[0.24536921]
#  [5.16481528]]
# robot_measurement [[-0.44776233]
#  [-0.30430891]]
# world frame match [[-1.3821848 ]
#  [ 3.21628183]]
# robot_measurement [[1.5469253 ]
#  [4.38442278]]
# world frame match [[1.55570756]
#  [2.57940611]]
# robot_measurement [[-0.41621119]
#  [-1.3740016 ]]
# world frame match [[ 1.52389414]
#  [-3.46404474]]
# robot_measurement [[-1.55739531]
#  [-3.99653553]]
# world frame match [[-1.49205162]
#  [ 6.43657377]]
# robot_measurement [[0.29233822]
#  [1.23719584]]
# world frame match [[1.50166121]
#  [0.01977335]]
# robot_measurement [[1.50648311]
#  [4.3566565 ]]
# world frame match [[1.39196927]
#  [4.33346324]]
# Scan 4
# x_hat = [[-1.38566933e+01]
#  [ 4.03037536e-01]
#  [-5.81465423e-03]]
# [[-35.68413709]
#  [ -0.36127651]
#  [  1.15002732]]
# [[-8.46328759e-02]
#  [ 1.91481042e-03]
#  [-2.22044605e-16]]
# [[ 4.52367535e+01]
#  [-1.55058854e+00]
#  [ 2.88657986e-15]]
# [[-2.09029833e+00]
#  [-3.26308516e-02]
#  [ 5.10702591e-15]]
# [[ 5.38864246e-02]
#  [-8.10105440e-05]
#  [ 1.33226763e-15]]
# [[-2.07759289e+00]
#  [-3.60823900e-02]
#  [ 5.32907052e-15]]
# [[-2.64179610e+00]
#  [-4.58811337e-02]
#  [ 4.21884749e-15]]
# [[-2.08866420e+00]
#  [-3.62746699e-02]
#  [ 5.55111512e-15]]
# [[-0.32445227]
#  [ 0.00147275]
#  [ 0.        ]]
# [[-1.54077343e+00]
#  [-2.98562809e-02]
#  [ 4.66293670e-15]]
# [[-0.05728364]
#  [ 0.00203933]
#  [ 0.        ]]
# [[5.49209128e-02]
#  [1.12612416e-03]
#  [2.22044605e-16]]
# [[-3.70689773e+00]
#  [-7.60079701e-02]
#  [ 7.32747196e-15]]
# [[ 1.10508942e+01]
#  [-4.62879392e-01]
#  [ 1.77635684e-15]]
# [[ 1.73766274e+00]
#  [-6.09378057e-02]
#  [-4.44089210e-16]]
# [[-2.91381529e+00]
#  [-9.42692499e-02]
#  [ 7.10542736e-15]]
# [[-4.81791947e-02]
#  [ 1.16982511e-03]
#  [-4.44089210e-16]]
# [[ 9.93886287e-01]
#  [-3.62561146e-02]
#  [-1.77635684e-15]]
# [[-1.49795490e-02]
#  [ 4.20326606e-04]
#  [ 4.44089210e-16]]
# [[ 1.33668610e+00]
#  [-4.95410197e-02]
#  [-1.55431223e-15]]
# [[ 7.35450952e-01]
#  [-2.32774793e-01]
#  [ 4.88498131e-15]]
# [[-9.54428760e-02]
#  [-3.89743896e-03]
#  [ 3.77475828e-15]]
# [[ 1.00939861e+01]
#  [-4.48965328e-01]
#  [ 3.10862447e-15]]
# [[-4.17876087e-01]
#  [-5.36535117e-03]
#  [ 2.66453526e-15]]
# [[-4.06810341e-03]
#  [ 5.67900791e-05]
#  [-2.22044605e-16]]
# x_t = [[ 3.64654425]
#  [-3.15232837]
#  [ 1.14421266]]
# covarience = [[ 7.69641429e-04 -2.01958367e-05 -5.50171308e-19]
#  [-2.01958367e-05  2.04722753e-06  3.14106253e-19]
#  [-8.89618678e-20  3.14106253e-19  6.93889390e-18]]
#
#
#
#
# [array([[0.        , 0.        ],
#        [0.        , 0.00079125]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.17112119e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.44418382e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.06301066e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.92659598e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.30823089e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.23214235e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.20823701e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.30471551e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00822238]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.16854645e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.15932951e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.32240806e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.26110738e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.58090696e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.47833165e-05]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.0204934e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.12291281e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00260085]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.08344978e-05]]), array([[0.        , 0.        ],
#        [0.        , 0.00604031]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.39566832e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.24986227e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.01529771]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.44977512e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.96866441e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.91335112e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00015399]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.37042908e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00356367]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.90550611e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00019036]])]
# (2, 1, 82)
# (2, 1, 32)
# bestmatch 0 3 mah_dist_best [[0.00539673]]
# bestmatch 1 69 mah_dist_best [[0.00015165]]
# bestmatch 2 36 mah_dist_best [[0.00043523]]
# bestmatch 3 69 mah_dist_best [[0.00102497]]
# bestmatch 4 40 mah_dist_best [[0.0001855]]
# bestmatch 5 36 mah_dist_best [[0.00045732]]
# bestmatch 6 39 mah_dist_best [[0.00135864]]
# bestmatch 7 40 mah_dist_best [[0.00021263]]
# bestmatch 8 69 mah_dist_best [[0.00037334]]
# bestmatch 9 47 mah_dist_best [[0.0035796]]
# bestmatch 10 14 mah_dist_best [[0.00073186]]
# bestmatch 11 13 mah_dist_best [[0.00069076]]
# bestmatch 12 13 mah_dist_best [[0.00069378]]
# bestmatch 13 13 mah_dist_best [[0.0006971]]
# bestmatch 14 13 mah_dist_best [[0.00070534]]
# bestmatch 15 13 mah_dist_best [[0.00070837]]
# bestmatch 16 14 mah_dist_best [[0.00063211]]
# bestmatch 17 13 mah_dist_best [[0.00222097]]
# bestmatch 18 25 mah_dist_best [[0.0321213]]
# bestmatch 19 80 mah_dist_best [[0.00103367]]
# bestmatch 20 25 mah_dist_best [[0.03415761]]
# bestmatch 21 13 mah_dist_best [[0.00096248]]
# bestmatch 22 36 mah_dist_best [[0.0023268]]
# bestmatch 23 2 mah_dist_best [[0.05172374]]
# bestmatch 24 36 mah_dist_best [[0.00709095]]
# bestmatch 25 40 mah_dist_best [[0.00101191]]
# bestmatch 26 36 mah_dist_best [[0.00698337]]
# bestmatch 27 36 mah_dist_best [[0.00147811]]
# bestmatch 28 80 mah_dist_best [[0.00213251]]
# bestmatch 29 24 mah_dist_best [[0.02074335]]
# bestmatch 30 36 mah_dist_best [[0.00726576]]
# bestmatch 31 80 mah_dist_best [[0.00323344]]
# [[0, 3], [1, 69], [2, 36], [3, 69], [4, 40], [5, 36], [6, 39], [7, 40], [8, 69], [9, 47], [10, 14], [11, 13], [12, 13], [13, 13], [14, 13], [15, 13], [16, 14], [17, 13], [18, 25], [19, 80], [20, 25], [21, 13], [22, 36], [23, 2], [24, 36], [25, 40], [26, 36], [27, 36], [28, 80], [29, 24], [30, 36], [31, 80]]
# robot_measurement [[-1.19312643]
#  [-4.68308978]]
# world frame match [[-0.01550919]
#  [-5.29666572]]
# robot_measurement [[-0.00468274]
#  [-1.99319838]]
# world frame match [[ 0.03907202]
#  [-2.94143367]]
# robot_measurement [[ 0.71789603]
#  [-0.3967776 ]]
# world frame match [[ 0.40568024]
#  [-1.25088029]]
# robot_measurement [[-0.44797282]
#  [-1.93510722]]
# world frame match [[ 0.03907202]
#  [-2.94143367]]
# robot_measurement [[ 0.00867008]
#  [-1.66905498]]
# world frame match [[ 0.21687222]
#  [-2.35899173]]
# robot_measurement [[ 0.74279246]
#  [-0.68878114]]
# world frame match [[ 0.40568024]
#  [-1.25088029]]
# robot_measurement [[-1.34731798]
#  [-0.6203993 ]]
# world frame match [[-1.94598336]
#  [-0.40748481]]
# robot_measurement [[-0.00871473]
#  [-1.66143134]]
# world frame match [[ 0.21687222]
#  [-2.35899173]]
# robot_measurement [[-0.16226752]
#  [-1.74981157]]
# world frame match [[ 0.03907202]
#  [-2.94143367]]
# robot_measurement [[ 1.2358428 ]
#  [-8.18279801]]
# world frame match [[ 0.37386682]
#  [-7.84802781]]
# robot_measurement [[-0.00740949]
#  [ 1.35904445]]
# world frame match [[ 0.37504578]
#  [-1.26835635]]
# robot_measurement [[-1.0466266 ]
#  [-0.00152183]]
# world frame match [[-0.93518689]
#  [ 0.93456857]]
# robot_measurement [[-1.03473131]
#  [-0.00674683]]
# world frame match [[-0.93518689]
#  [ 0.93456857]]
# robot_measurement [[-1.03632276]
#  [-0.00895266]]
# world frame match [[-0.93518689]
#  [ 0.93456857]]
# robot_measurement [[-1.0189037 ]
#  [-0.01743377]]
# world frame match [[-0.93518689]
#  [ 0.93456857]]
# robot_measurement [[-1.02057841]
#  [-0.01977397]]
# world frame match [[-0.93518689]
#  [ 0.93456857]]
# robot_measurement [[0.03801829]
#  [1.36890013]]
# world frame match [[ 0.37504578]
#  [-1.26835635]]
# robot_measurement [[-0.37136019]
#  [ 2.2319106 ]]
# world frame match [[-0.93518689]
#  [ 0.93456857]]
# robot_measurement [[1.21398818]
#  [6.92217817]]
# world frame match [[-1.6748251 ]
#  [ 5.96936902]]
# robot_measurement [[-1.1867584 ]
#  [-3.84589915]]
# world frame match [[-1.19483521]
#  [-2.70609554]]
# robot_measurement [[1.33957979]
#  [6.49343444]]
# world frame match [[-1.6748251 ]
#  [ 5.96936902]]
# robot_measurement [[-0.41836965]
#  [ 0.97496076]]
# world frame match [[-0.93518689]
#  [ 0.93456857]]
# robot_measurement [[0.04583642]
#  [5.15810824]]
# world frame match [[ 0.40568024]
#  [-1.25088029]]
# robot_measurement [[1.1995324 ]
#  [7.60579473]]
# world frame match [[-1.78379586]
#  [ 6.46137205]]
# robot_measurement [[1.55391608]
#  [4.26607517]]
# world frame match [[ 0.40568024]
#  [-1.25088029]]
# robot_measurement [[-0.26772771]
#  [-0.7333267 ]]
# world frame match [[ 0.21687222]
#  [-2.35899173]]
# robot_measurement [[1.56819443]
#  [3.8789822 ]]
# world frame match [[ 0.40568024]
#  [-1.25088029]]
# robot_measurement [[0.3693773 ]
#  [1.47633655]]
# world frame match [[ 0.40568024]
#  [-1.25088029]]
# robot_measurement [[-1.55830624]
#  [-4.24044938]]
# world frame match [[-1.19483521]
#  [-2.70609554]]
# robot_measurement [[1.14533642]
#  [3.62415517]]
# world frame match [[-1.21761917]
#  [ 3.17285156]]
# robot_measurement [[1.55663516]
#  [4.28150313]]
# world frame match [[ 0.40568024]
#  [-1.25088029]]
# robot_measurement [[-1.32951707]
#  [-4.53426997]]
# world frame match [[-1.19483521]
#  [-2.70609554]]
# Scan 5
# x_hat = [[ 3.68792055]
#  [-3.06128991]
#  [ 1.14421266]]
# [[-0.27154723]
#  [-0.00513379]
#  [ 1.17761725]]
# [[-1.46055968]
#  [-0.2283093 ]
#  [ 0.        ]]
# [[ 7.50665217e-01]
#  [-4.39839948e-01]
#  [ 4.44089210e-16]]
# [[-3.31553449e-01]
#  [-1.84593262e-02]
#  [-4.44089210e-16]]
# [[-0.09725976]
#  [-0.07438822]
#  [ 0.        ]]
# [[ 2.77639733e-01]
#  [-1.37184478e-01]
#  [ 4.44089210e-16]]
# [[ 7.26935806e-02]
#  [-1.26890161e-02]
#  [ 4.44089210e-16]]
# [[-0.09991032]
#  [-0.05186447]
#  [ 0.        ]]
# [[-0.24557608]
#  [-0.01646094]
#  [ 0.        ]]
# [[-4.47174022e-04]
#  [ 3.48632067e-04]
#  [ 8.88178420e-16]]
# [[ 0.59417198]
#  [-0.45811257]
#  [ 0.        ]]
# [[ 0.1397155 ]
#  [-0.01621741]
#  [ 0.        ]]
# [[ 0.1202624]
#  [-0.0139594]
#  [ 0.       ]]
# [[ 0.1060027 ]
#  [-0.01230421]
#  [ 0.        ]]
# [[ 0.09506934]
#  [-0.01103513]
#  [ 0.        ]]
# [[ 0.08637463]
#  [-0.01002589]
#  [ 0.        ]]
# [[ 0.30921806]
#  [-0.362399  ]
#  [ 0.        ]]
# [[-1.09787605e-01]
#  [ 1.18635426e-02]
#  [ 4.44089210e-16]]
# [[-1.94606993e-02]
#  [ 3.34022613e-03]
#  [ 2.66453526e-15]]
# [[ 0.08724175]
#  [-0.01131427]
#  [ 0.        ]]
# [[-5.20921432e-03]
#  [ 9.12372139e-04]
#  [ 3.10862447e-15]]
# [[-4.22221301e-03]
#  [ 4.41722305e-04]
#  [ 4.44089210e-16]]
# [[ 0.66682713]
#  [-0.70956599]
#  [ 0.        ]]
# [[-3.60585481e-03]
#  [ 6.39578042e-04]
#  [ 2.66453526e-15]]
# [[ 5.84994337e-01]
#  [-6.24580618e-01]
#  [ 1.33226763e-15]]
# [[-1.01705985e-01]
#  [-6.69943157e-02]
#  [-4.44089210e-16]]
# [[ 5.01145632e-01]
#  [-4.92182508e-01]
#  [ 1.33226763e-15]]
# [[ 0.055657  ]
#  [-0.05466156]
#  [ 0.        ]]
# [[ 9.88743637e-02]
#  [-1.04094295e-02]
#  [-4.44089210e-16]]
# [[-5.99749102e-03]
#  [ 6.41705935e-04]
#  [ 2.22044605e-15]]
# [[ 4.07847302e-01]
#  [-4.30594960e-01]
#  [ 1.33226763e-15]]
# [[ 0.08637768]
#  [-0.0085764 ]
#  [ 0.        ]]
# x_t = [[ 5.97185613]
#  [-7.32036528]
#  [ 2.32182991]]
# covarience = [[ 4.31281619e-05 -4.11833968e-06  1.35311591e-19]
#  [-4.11833968e-06  3.64256346e-06 -3.33763331e-20]
#  [ 1.62416645e-19 -7.40339146e-20 -3.46944695e-18]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.61053919e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.06143009e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.38215583e-06]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 4.5617445e-09]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.9822794e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.17407282e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.47751978e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.11627702e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.02010423]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.40967668e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.59937995e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.01553558]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.15364444e-06]]), array([[0.       , 0.       ],
#        [0.       , 0.0560185]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.56877442e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.90387746e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.78325494e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.63054599e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.25444379e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.25394815e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.09361888]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.74574018e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.85347296e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.02910304]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.32155712e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00114896]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.19372756e-11]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.47794375e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.09334646e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.51835535e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.26457519e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.13010751e-07]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.1325904e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.29270979e-05]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 4.0251824e-10]])]
# (2, 1, 82)
# (2, 1, 35)
# bestmatch 0 36 mah_dist_best [[0.00152982]]
# bestmatch 1 36 mah_dist_best [[0.00718415]]
# bestmatch 2 36 mah_dist_best [[0.00084192]]
# bestmatch 3 36 mah_dist_best [[0.00190183]]
# bestmatch 4 36 mah_dist_best [[0.00827571]]
# bestmatch 5 36 mah_dist_best [[0.00156329]]
# bestmatch 6 36 mah_dist_best [[0.0172856]]
# bestmatch 7 36 mah_dist_best [[0.00134452]]
# bestmatch 8 35 mah_dist_best [[0.02256616]]
# bestmatch 9 36 mah_dist_best [[0.00178907]]
# bestmatch 10 14 mah_dist_best [[0.00091894]]
# bestmatch 11 36 mah_dist_best [[0.01627153]]
# bestmatch 12 14 mah_dist_best [[0.00112399]]
# bestmatch 13 80 mah_dist_best [[0.03932497]]
# bestmatch 14 36 mah_dist_best [[0.00233151]]
# bestmatch 15 36 mah_dist_best [[0.00625947]]
# bestmatch 16 36 mah_dist_best [[0.00223621]]
# bestmatch 17 36 mah_dist_best [[0.00356962]]
# bestmatch 18 14 mah_dist_best [[0.00194987]]
# bestmatch 19 36 mah_dist_best [[0.00244861]]
# bestmatch 21 36 mah_dist_best [[0.02839598]]
# bestmatch 22 69 mah_dist_best [[0.00062303]]
# bestmatch 23 25 mah_dist_best [[0.04117716]]
# bestmatch 24 14 mah_dist_best [[0.00139693]]
# bestmatch 25 25 mah_dist_best [[0.03283642]]
# bestmatch 26 14 mah_dist_best [[0.00352081]]
# bestmatch 27 36 mah_dist_best [[0.00089547]]
# bestmatch 28 36 mah_dist_best [[0.01709583]]
# bestmatch 29 36 mah_dist_best [[0.00116474]]
# bestmatch 30 13 mah_dist_best [[0.00152878]]
# bestmatch 31 36 mah_dist_best [[0.00320748]]
# bestmatch 32 36 mah_dist_best [[0.01645374]]
# bestmatch 33 69 mah_dist_best [[0.00126695]]
# bestmatch 34 36 mah_dist_best [[0.00187064]]
# ...
#        [0.00000000e+00, 1.93347776e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.22048256e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.87592047e-09]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.1103941e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.12781796e-09]])]
# (2, 1, 82)
# (2, 1, 27)
# bestmatch 0 13 mah_dist_best [[0.00167429]]
# bestmatch 1 13 mah_dist_best [[0.0144115]]
# bestmatch 2 13 mah_dist_best [[0.00145613]]
# bestmatch 3 41 mah_dist_best [[0.00056948]]
# bestmatch 4 13 mah_dist_best [[0.00066247]]
# bestmatch 5 13 mah_dist_best [[0.00171934]]
# bestmatch 6 13 mah_dist_best [[0.0001003]]
# bestmatch 8 13 mah_dist_best [[0.00135524]]
# bestmatch 9 80 mah_dist_best [[0.00029263]]
# bestmatch 10 35 mah_dist_best [[0.00353474]]
# bestmatch 11 80 mah_dist_best [[0.00059183]]
# bestmatch 12 13 mah_dist_best [[0.01760472]]
# bestmatch 13 13 mah_dist_best [[0.00027307]]
# bestmatch 14 6 mah_dist_best [[0.00526894]]
# bestmatch 15 13 mah_dist_best [[0.00171664]]
# bestmatch 16 13 mah_dist_best [[0.00010302]]
# bestmatch 17 13 mah_dist_best [[0.01613653]]
# bestmatch 18 13 mah_dist_best [[0.000588]]
# bestmatch 19 13 mah_dist_best [[0.01484281]]
# bestmatch 20 13 mah_dist_best [[0.00294908]]
# bestmatch 21 13 mah_dist_best [[0.01620939]]
# bestmatch 22 13 mah_dist_best [[0.0017717]]
# bestmatch 23 13 mah_dist_best [[0.00814438]]
# bestmatch 24 13 mah_dist_best [[0.00165498]]
# bestmatch 25 13 mah_dist_best [[0.01501693]]
# bestmatch 26 13 mah_dist_best [[0.0016365]]
# [[0, 13], [1, 13], [2, 13], [3, 41], [4, 13], [5, 13], [6, 13], [8, 13], [9, 80], [10, 35], [11, 80], [12, 13], [13, 13], [14, 6], [15, 13], [16, 13], [17, 13], [18, 13], [19, 13], [20, 13], [21, 13], [22, 13], [23, 13], [24, 13], [25, 13], [26, 13]]
# robot_measurement [[-0.01386678]
#  [-1.66239477]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[ 1.35701698]
#  [-0.0509119 ]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-0.04414803]
#  [-1.28844734]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-1.35790856]
#  [-0.26185957]]
# world frame match [[-0.94378155]
#  [ 3.87452521]]
# robot_measurement [[-0.26834213]
#  [-1.59707598]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-0.00504994]
#  [-1.67078727]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-0.4786748 ]
#  [-0.08582481]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-0.01055887]
#  [ 1.35750872]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-1.05403178]
#  [ 0.00999539]]
# world frame match [[-0.91270217]
#  [ 2.97189135]]
# robot_measurement [[0.27190733]
#  [5.43788006]]
# world frame match [[-0.75991216]
#  [ 2.58409605]]
# robot_measurement [[-1.25240356]
#  [-1.86590747]]
# world frame match [[-0.91270217]
#  [ 2.97189135]]
# robot_measurement [[1.56891974]
#  [5.45272314]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-0.3977026 ]
#  [ 1.38919473]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[0.28461001]
#  [6.90714194]]
# world frame match [[-0.91062758]
#  [ 7.02912297]]
# robot_measurement [[-0.01587877]
#  [ 4.66050044]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-0.47750552]
#  [-0.25275859]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[1.55043854]
#  [3.90879014]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-0.24991885]
#  [-0.57113748]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[1.44071512]
#  [3.50003965]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[0.27497863]
#  [1.04254375]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[1.55535345]
#  [3.90649702]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-0.00860812]
#  [-1.97351233]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[ 0.85124605]
#  [-0.42016762]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-0.01768223]
#  [-1.65873359]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[ 1.39686537]
#  [-0.10805754]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# robot_measurement [[-0.0057602 ]
#  [-1.28726252]]
# world frame match [[-0.65305385]
#  [-0.57748095]]
# Scan 8
# x_hat = [[ -0.60322185]
#  [-30.57741943]
#  [  0.86207962]]
# [[ 0.89486338]
#  [ 1.00955142]
#  [-0.63918707]]
# [[-1.44796381e-05]
#  [-1.71366100e-05]
#  [-2.77555756e-16]]
# [[2.09014212e-05]
#  [2.47367717e-05]
#  [3.88578059e-16]]
# [[ 5.35969880e-02]
#  [-2.51802104e-01]
#  [ 6.16173779e-15]]
# [[2.76906186e-05]
#  [3.46857675e-05]
#  [5.27355937e-16]]
# [[3.21233431e-05]
#  [4.02382780e-05]
#  [6.10622664e-16]]
# [[-1.41457267e-05]
#  [-1.77191920e-05]
#  [-2.77555756e-16]]
# [[-5.84739511e-05]
#  [-7.32455241e-05]
#  [-1.08246745e-15]]
# [[ 2.07699723e-02]
#  [-9.75226819e-02]
#  [ 2.55351296e-15]]
# [[-5.96712940e-03]
#  [ 2.78054796e-02]
#  [-1.38777878e-15]]
# [[ 5.08848510e-02]
#  [-2.38925079e-01]
#  [ 6.27276009e-15]]
# [[-8.26783533e-05]
#  [-1.12854215e-04]
#  [-1.58206781e-15]]
# [[-5.40123647e-05]
#  [-7.37257429e-05]
#  [-1.02695630e-15]]
# [[ 4.68049482e-06]
#  [-2.19758621e-05]
#  [ 0.00000000e+00]]
# [[-1.54338373e-04]
#  [-2.10723237e-04]
#  [-2.94209102e-15]]
# [[-9.18187990e-06]
#  [-1.25363214e-05]
#  [-1.66533454e-16]]
# [[-1.31957560e-04]
#  [-1.80165979e-04]
#  [-2.49800181e-15]]
# [[-5.31927625e-07]
#  [-7.26258214e-07]
#  [ 0.00000000e+00]]
# [[-8.29456616e-05]
#  [-1.13248429e-04]
#  [-1.58206781e-15]]
# [[-2.70480092e-05]
#  [-3.69295331e-05]
#  [-5.27355937e-16]]
# [[-1.32118490e-04]
#  [-1.80385703e-04]
#  [-2.49800181e-15]]
# [[4.03997755e-05]
#  [5.51591371e-05]
#  [7.77156117e-16]]
# [[-4.32834159e-06]
#  [-5.90962659e-06]
#  [-8.32667268e-17]]
# [[3.11631232e-05]
#  [4.25480331e-05]
#  [5.82867088e-16]]
# [[-1.16221483e-05]
#  [-1.58680998e-05]
#  [-2.22044605e-16]]
# [[2.02520104e-05]
#  [2.76507334e-05]
#  [3.88578059e-16]]
# x_t = [[  0.41032556]
#  [-30.12916052]
#  [  0.22289256]]
# covarience = [[ 1.83282207e-07 -8.59450228e-07  2.61582617e-20]
#  [-8.59450228e-07  4.05789389e-06 -2.27169604e-20]
#  [ 2.61582617e-20 -3.62694876e-20 -2.95874037e-34]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.00611698e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.76550367e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.01757248]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.61118971e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.40551706e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.02148763]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.92002162e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00646432]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.96895427e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.56865888e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.21382506e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.59159882e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.41970224e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00486274]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.40206073e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00854925]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.96115025e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00360335]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.86836935e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.92689648e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.08247611e-07]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 9.5089485e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00078585]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.88386121e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.58451827e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.96924862e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00248171]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 9.3072529e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.69096274e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.86017615e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.94669948e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.12988212e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.50167126e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.88831492e-06]])]
# (2, 1, 82)
# (2, 1, 34)
# bestmatch 0 13 mah_dist_best [[1.36107959e-05]]
# bestmatch 1 61 mah_dist_best [[0.00375839]]
# bestmatch 2 13 mah_dist_best [[0.00063054]]
# bestmatch 3 13 mah_dist_best [[1.12328373e-06]]
# bestmatch 4 80 mah_dist_best [[0.00026974]]
# bestmatch 6 13 mah_dist_best [[1.95475779e-05]]
# bestmatch 7 10 mah_dist_best [[0.00475764]]
# bestmatch 8 35 mah_dist_best [[4.46176047e-05]]
# bestmatch 9 33 mah_dist_best [[0.00125522]]
# bestmatch 10 41 mah_dist_best [[0.00218714]]
# bestmatch 11 41 mah_dist_best [[0.00208577]]
# bestmatch 12 41 mah_dist_best [[0.0020894]]
# bestmatch 13 1 mah_dist_best [[0.00896504]]
# bestmatch 14 80 mah_dist_best [[0.00505335]]
# bestmatch 15 29 mah_dist_best [[0.00568811]]
# bestmatch 16 80 mah_dist_best [[0.00013059]]
# bestmatch 17 1 mah_dist_best [[0.0015032]]
# bestmatch 18 33 mah_dist_best [[0.00021526]]
# bestmatch 19 80 mah_dist_best [[0.0003145]]
# bestmatch 20 35 mah_dist_best [[0.01020708]]
# bestmatch 21 13 mah_dist_best [[0.00028847]]
# bestmatch 22 12 mah_dist_best [[0.01156587]]
# bestmatch 23 35 mah_dist_best [[0.0087671]]
# bestmatch 24 13 mah_dist_best [[0.00014972]]
# bestmatch 25 80 mah_dist_best [[0.00684666]]
# bestmatch 26 61 mah_dist_best [[0.00789076]]
# bestmatch 27 80 mah_dist_best [[0.00637226]]
# bestmatch 28 13 mah_dist_best [[8.37474527e-06]]
# bestmatch 29 13 mah_dist_best [[8.73750906e-06]]
# bestmatch 30 13 mah_dist_best [[0.0044185]]
# bestmatch 31 13 mah_dist_best [[5.24495289e-07]]
# bestmatch 32 13 mah_dist_best [[0.00769103]]
# bestmatch 33 80 mah_dist_best [[0.00067295]]
# [[0, 13], [1, 61], [2, 13], [3, 13], [4, 80], [6, 13], [7, 10], [8, 35], [9, 33], [10, 41], [11, 41], [12, 41], [13, 1], [14, 80], [15, 29], [16, 80], [17, 1], [18, 33], [19, 80], [20, 35], [21, 13], [22, 12], [23, 35], [24, 13], [25, 80], [26, 61], [27, 80], [28, 13], [29, 13], [30, 13], [31, 13], [32, 13], [33, 80]]
# robot_measurement [[-0.0650249 ]
#  [-1.28335056]]
# world frame match [[-0.01386678]
#  [-1.56676661]]
# robot_measurement [[-1.31562542]
#  [-0.17606857]]
# world frame match [[-0.32621811]
#  [ 3.3460391 ]]
# robot_measurement [[ 0.27375984]
#  [-1.70375996]]
# world frame match [[-0.01386678]
#  [-1.56676661]]
# robot_measurement [[-0.02893871]
#  [-1.64478273]]
# world frame match [[-0.01386678]
#  [-1.56676661]]
# robot_measurement [[-0.44683474]
#  [-0.14167382]]
# world frame match [[-0.2735151 ]
#  [ 1.83844021]]
# robot_measurement [[-0.07983423]
#  [-1.84412425]]
# world frame match [[-0.01386678]
#  [-1.56676661]]
# robot_measurement [[-1.39029117]
#  [ 5.30210734]]
# world frame match [[-0.24990396]
#  [ 5.22384472]]
# robot_measurement [[-0.01243465]
#  [ 1.36094525]]
# world frame match [[-0.12072509]
#  [ 1.52678852]]
# robot_measurement [[0.34612762]
#  [5.45691337]]
# world frame match [[-0.24507369]
#  [ 5.07607799]]
# robot_measurement [[-1.05193977]
#  [-0.00319068]]
# world frame match [[-0.30459448]
#  [ 2.72877094]]
# robot_measurement [[-1.0259879 ]
#  [-0.01999916]]
# world frame match [[-0.30459448]
#  [ 2.72877094]]
# robot_measurement [[-1.02683549]
#  [-0.02337214]]
# world frame match [[-0.30459448]
#  [ 2.72877094]]
# robot_measurement [[1.19133493]
#  [6.71738291]]
# world frame match [[-0.26406772]
#  [ 7.21690084]]
# robot_measurement [[-1.3229934 ]
#  [-4.05682137]]
# world frame match [[-0.2735151 ]
#  [ 1.83844021]]
# robot_measurement [[0.76896791]
#  [6.53682952]]
# world frame match [[-0.27752647]
#  [ 6.08318596]]
# robot_measurement [[-0.44898065]
#  [ 1.02720491]]
# world frame match [[-0.2735151 ]
#  [ 1.83844021]]
# robot_measurement [[0.36291   ]
#  [7.37286622]]
# world frame match [[-0.26406772]
#  [ 7.21690084]]
# robot_measurement [[-0.00859423]
#  [ 4.73329231]]
# world frame match [[-0.24507369]
#  [ 5.07607799]]
# robot_measurement [[-0.47930625]
#  [-0.18890755]]
# world frame match [[-0.2735151 ]
#  [ 1.83844021]]
# robot_measurement [[1.55056556]
#  [3.7899819 ]]
# world frame match [[-0.12072509]
#  [ 1.52678852]]
# robot_measurement [[-0.2712789 ]
#  [-0.60691337]]
# world frame match [[-0.01386678]
#  [-1.56676661]]
# robot_measurement [[1.55487621]
#  [3.40951939]]
# world frame match [[-0.14341281]
#  [ 2.19736608]]
# robot_measurement [[1.43003329]
#  [3.40193304]]
# world frame match [[-0.12072509]
#  [ 1.52678852]]
# robot_measurement [[0.0260001 ]
#  [0.11860321]]
# world frame match [[-0.01386678]
#  [-1.56676661]]
# robot_measurement [[-1.56790069]
#  [-3.76535732]]
# world frame match [[-0.2735151 ]
#  [ 1.83844021]]
# robot_measurement [[1.14266943]
#  [3.20222243]]
# world frame match [[-0.32621811]
#  [ 3.3460391 ]]
# robot_measurement [[-1.46641877]
#  [-3.9512852 ]]
# world frame match [[-0.2735151 ]
#  [ 1.83844021]]
# robot_measurement [[-0.00581797]
#  [-1.96847764]]
# world frame match [[-0.01386678]
#  [-1.56676661]]
# robot_measurement [[ 0.0043809 ]
#  [-1.95227331]]
# world frame match [[-0.01386678]
#  [-1.56676661]]
# robot_measurement [[ 1.07131193]
#  [-0.04329348]]
# world frame match [[-0.01386678]
#  [-1.56676661]]
# robot_measurement [[-0.01993231]
#  [-1.65522098]]
# world frame match [[-0.01386678]
#  [-1.56676661]]
# robot_measurement [[ 1.43495135]
#  [-0.21078323]]
# world frame match [[-0.01386678]
#  [-1.56676661]]
# robot_measurement [[-0.58576487]
#  [-1.0439822 ]]
# world frame match [[-0.2735151 ]
#  [ 1.83844021]]
# Scan 9
# x_hat = [[  0.50785177]
#  [-30.10705537]
#  [  0.22289256]]
# [[-0.27495581]
#  [-0.06419172]
#  [ 0.05115812]]
# [[ 3.10707454e-02]
#  [-8.07452975e-02]
#  [ 8.88178420e-16]]
# [[1.49497065e-06]
#  [3.99815857e-07]
#  [0.00000000e+00]]
# [[2.98416079e-04]
#  [7.98085767e-05]
#  [0.00000000e+00]]
# [[ 1.56641197e-02]
#  [-3.69593224e-02]
#  [ 3.88578059e-16]]
# [[0.001047  ]
#  [0.00030159]
#  [0.        ]]
# [[-3.60613750e-06]
#  [ 8.07062628e-06]
#  [ 0.00000000e+00]]
# [[ 0.00090549]
#  [-0.0011461 ]
#  [ 0.        ]]
# [[-2.22577677e-03]
#  [ 4.92951514e-03]
#  [-5.55111512e-17]]
# [[ 2.15563415e-02]
#  [-5.43626068e-02]
#  [ 6.10622664e-16]]
# [[ 2.01443337e-02]
#  [-5.08016861e-02]
#  [ 5.55111512e-16]]
# [[ 2.00554937e-02]
#  [-5.05776418e-02]
#  [ 5.55111512e-16]]
# [[ 3.54656935e-05]
#  [-8.20936015e-05]
#  [ 0.00000000e+00]]
# [[ 4.59814387e-02]
#  [-1.08780989e-01]
#  [ 1.11022302e-15]]
# [[-2.00444299e-05]
#  [ 4.78476723e-05]
#  [ 0.00000000e+00]]
# [[ 6.00643623e-03]
#  [-1.42097727e-02]
#  [ 1.66533454e-16]]
# [[-1.6018556e-05]
#  [ 3.7064612e-05]
#  [ 0.0000000e+00]]
# [[ 2.47127906e-03]
#  [-5.44606688e-03]
#  [ 5.55111512e-17]]
# [[ 1.50630612e-02]
#  [-3.56544501e-02]
#  [ 3.88578059e-16]]
# [[-1.15566036e-02]
#  [ 1.37874294e-02]
#  [-5.55111512e-17]]
# [[-3.31364272e-03]
#  [-1.53677989e-03]
#  [ 1.11022302e-16]]
# [[-0.0003924 ]
#  [ 0.00056118]
#  [ 0.        ]]
# [[-0.00906136]
#  [ 0.01084788]
#  [ 0.        ]]
# [[-5.82282586e-03]
#  [-2.75285366e-03]
#  [ 1.66533454e-16]]
# [[ 4.24208689e-02]
#  [-1.01199309e-01]
#  [ 1.05471187e-15]]
# [[ 1.82323517e-05]
#  [-4.83766010e-05]
#  [ 0.00000000e+00]]
# [[ 3.63503880e-02]
#  [-8.67157271e-02]
#  [ 8.88178420e-16]]
# [[ 1.37635335e-03]
#  [ 7.04785640e-04]
#  [-5.55111512e-17]]
# [[ 1.31334066e-03]
#  [ 6.72518897e-04]
#  [-5.55111512e-17]]
# [[-3.73823544e-03]
#  [-1.91422839e-03]
#  [ 1.11022302e-16]]
# [[0.0003    ]
#  [0.00015362]
#  [0.        ]]
# [[-4.28761685e-03]
#  [-2.19554868e-03]
#  [ 1.11022302e-16]]
# [[ 2.05383381e-02]
#  [-4.94510435e-02]
#  [ 4.99600361e-16]]
# x_t = [[  0.47507647]
#  [-30.82369528]
#  [  0.27405068]]
# covarience = [[ 3.09481974e-07 -6.47588941e-07  1.27751580e-20]
#  [-6.47588941e-07  3.48486822e-06 -2.48137200e-20]
#  [ 5.99889447e-21 -5.19187743e-20 -2.73541778e-35]]

# %%
plt.figure()
# plt.xlim(-1,1)
# plt.ylim(-1,1)
color = []
for i in range(len(all_xt)):
    
    color.append(i/len(all_xt))
color = np.array(color)

plt.scatter(np.array(all_xhat)[:,0], np.array(all_xhat)[:,1], c='red',s = 150)
plt.scatter(np.array(all_xt)[:,0], np.array(all_xt)[:,1], c=color   ,s=100)
