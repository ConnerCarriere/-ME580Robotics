# %% [markdown]
# # Kalman Filter

# %%
# include libraries
import numpy as np
import math
import csv
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# %% [markdown]
# # Needed Functions

# %%
def CSV_Read_Lidar_data(data_path):
    rows = []
    with open(data_path, 'r') as file:
        csvreader = csv.reader(file)
        for row in csvreader:
            rows.append(row)

    dataframe = pd.DataFrame([rows[0], rows[1], rows[2], rows[3]], ['Rho', 'Alpha', 'X', 'Y'])

    return dataframe

# %%
def covarience_line_fitting(points_in_line, line_alpha_rho, sigma_angle=0, sigma_dist=.005):
    sigma_angle = sigma_angle * np.ones(len(points_in_line))
    sigma_dist = sigma_dist * np.ones(len(points_in_line))

    data = np.array(points_in_line)

    #INPUIT IS X AND Y POINTS WITHIN A LINE
    dist = line_alpha_rho[1]  # whatever positions stores the distances from 0,0
    angle = line_alpha_rho[0]  # whatever positions stores the angles with the x axis
    
    x = data[:,0]
    y = data[:,1]

    n = len(x)
    x_bar = sum(x) / n
    y_bar = sum(y) / n

    S_x2 = sum((x - x_bar) ** 2)
    S_y2 = sum((y - y_bar) ** 2)
    S_xy = sum((x - x_bar) * (y - y_bar))

    # line paramters based on inputs data
    alpha = 0.5 * math.atan2(-2 * S_xy, S_y2 - S_x2)
    rho = x_bar * math.cos(alpha) + y_bar * math.sin(alpha)

    C_l = np.zeros(2)
    for i in range(0, n - 1):
        # The covariance of the measurement
        C_m = np.array([[sigma_angle[i], 0],
                        [0, sigma_dist[i]]])
        A = np.zeros((2, 2))

        # The jacobian of the line fit with respect to x and y
        A[1, 0] = ((y_bar - y[i]) * (S_y2 - S_x2) + 2 * S_xy * (x_bar - x[i])) / ((S_y2 - S_x2) ** 2 + 4 * S_xy ** 2)

        A[1, 1] = ((x_bar - x[i]) * (S_y2 - S_x2) - 2 * S_xy * (y_bar - y[i])) / ((S_y2 - S_x2) ** 2 + 4 * S_xy **2)

        A[0, 0] = math.cos(alpha) / n - x_bar * math.sin(alpha) * A[1, 0] + y_bar * math.cos(alpha) * A[1, 0]
        A[0, 1] = math.sin(alpha) / n - x_bar * math.sin(alpha) * A[1, 1] + y_bar * math.cos(alpha) * A[1, 1]

        # Jacobian of function converting dist and angle to x and y

        B = np.array([[math.cos(angle), -dist * math.sin(angle)],
                      [math.sin(angle), dist * math.cos(angle)]])
        J = A @ B
        C_l = C_l + J * C_m * J.T

    return rho, alpha, C_l

# %%
# Bunch of algorithms for split and merge

def GetPolar(X, Y):
    # center the data
    X = X - np.mean(X)
    Y = Y - np.mean(Y)
    # fit line through the first and last point (X and Y contains 2 points, start and end of the line)
    k, n = np.polyfit(X, Y, 1)
    alpha = math.atan(-1 / k)  # in radians
    ro = n / (math.sin(alpha) - k * math.cos(alpha))
    return ro, alpha

def Cartesian2Polar(x, y):
    r = np.sqrt(x ** 2 + y ** 2)
    phi = np.arctan2(y, x)
    return r, phi

def CheckPolar(ro, alpha):
    if ro < 0:
        alpha = alpha + math.pi
        if alpha > math.pi:
            alpha = alpha - 2 * math.pi
        ro = -ro
    return ro, alpha

def getDistance(P, Ps, Pe):  # point to line distance, where the line is given with points Ps and Pe
    if np.all(np.equal(Ps, Pe)):
        return np.linalg.norm(P - Ps)
    return np.divide(np.abs(np.linalg.norm(np.cross(Pe - Ps, Ps - P))), np.linalg.norm(Pe - Ps))

def GetMostDistant(P):
    dmax = 0
    index = -1
    for i in range(1, P.shape[0]):
        d = getDistance(P[i, :], P[0, :], P[-1, :])
        if (d > dmax):
            index = i
            dmax = d
    return dmax, index

def points_within_radius(mainpoint, points, r):
    result = []
    for point in points:
        if math.dist(mainpoint, point) <= r:
            result.append(point)
    return result

def gap_detection(lines, points, threshold):
    good_lines = []
    points_in_thresh_total = []
    for i in range(len(lines)):
        # get point 1 and point 2 of the line
        point_1 = lines[i][0]
        point_2 = lines[i][1]

        # get the distance of the line, then take a certain percentage of it (remember its based off both sides)
        line_dist = math.dist(point_2, point_1)
        r = line_dist / 2 * 0.10
        # print(r)

        # check all the points to see if they fall in theshold, store if they do
        points_in_thresh = []

        for j in range(len(points)):
            # distance = point_to_line_distance(points[j], lines[i])
            distance = getDistance(points[j], lines[i][0], lines[i][1])
            if distance <= (threshold * 1):
                # if distance < r:
                points_in_thresh.append(points[j])
        
        if len(points_in_thresh) <= 5 and line_dist <= 0.3:
            good_lines.append(lines[i])
            points_in_thresh_total.append(points_in_thresh)
            continue

        # check to see what % of points are between the threshold of the first and last point (might need my own threshold)
        p1_points = points_within_radius(point_1, points_in_thresh, r)
        p2_points = points_within_radius(point_2, points_in_thresh, r)
        # print(len(p1_points))
        # print(len(p2_points))
        # print(len(points_in_thresh))

        percent_in_radius = (len(p1_points) + len(p2_points)) / (len(points_in_thresh))
        # print(percent_in_radius)

        if percent_in_radius <= 0.40:
            # print("good line")
            good_lines.append(lines[i])
            points_in_thresh_total.append(points_in_thresh)
        # else:
        #     print("bad line")
        # plt.show()
        # print("\n")
        
    return good_lines, points_in_thresh_total

def SplitAndMerge(P, threshold):
    d, ind = GetMostDistant(P)
    if d > threshold:
        P1 = SplitAndMerge(P[:ind + 1, :], threshold)  # split and merge left array
        P2 = SplitAndMerge(P[ind:, :], threshold)  # split and merge right array
        # there are 2 "d" points, so exlude 1 (for example from 1st array)
        points = np.vstack((P1[:-1, :], P2))
    else:
        points = np.vstack((P[0, :], P[-1, :]))
    return points

def flatten(lst):
    result = []
    for item in lst:
        if isinstance(item, list):
            result.extend(flatten(item))
        else:
            result.append(item)
    return result

'~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'

def Algorithm_split_and_merge(inputdataframe, threshold=0.3, plot=False):

    P = np.array([list(inputdataframe['X']), list(inputdataframe['Y'])]).T

    points = SplitAndMerge(P, threshold)

    lines = []
    for i in range(len(points) - 1):
        lines.append([points[i], points[i + 1]])
        # plt.plot([points[i][0], points[i+1][0]], [points[i][1], points[i+1][1]], '-o')
    # final_lines = lines
    final_lines, points_in_line = gap_detection(lines, P, threshold)

    # flatten it to get the shitty points
    flat_list = flatten(final_lines)
    flat_list.append(flat_list[0])
    flat_list = np.array(flat_list)

    #convert from xy back to alpha rho
    alpha_rho = []
    for i in range(len(final_lines)):
        alpha, rho = GetPolar([final_lines[i][0][0], final_lines[i][1][0]], [final_lines[i][0][1], final_lines[i][1][1]])
        alpha_rho.append([alpha, rho])

    if plot==True:
        # plt.figure()
        # plt.title('og')
        # plt.scatter(P[:, 0], P[:, 1], c='black')
        # plt.plot(points[:, 0], points[:, 1])

        # plt.figure()
        # plt.title('with gap detection')
        # plt.scatter(P[:, 0], P[:, 1], c='black')
        # plt.plot(flat_list[:, 0], flat_list[:, 1], '-o')

        plt.figure()
        plt.title('actual Lines')
        plt.scatter(P[:, 0], P[:, 1], c='black')
        for i in range(len(final_lines)):
            tmp = np.array(final_lines[i])
            plt.plot(tmp[:, 0], tmp[:, 1], '-o')
        # print(len(lines))
        # print(len(final_lines))
        plt.scatter(0, 0, c='red')  # replace this with the origin point
        plt.show()

    return final_lines, points_in_line, alpha_rho

# %%
def matching(z_hat_t,z_t,R_t,H_j,P_hat_t,g):

    matches = []
    v_t_matches = []
    sigmas_matches = []
    H_matches = []
    #initializedng vt
    #max((pittypoot.shape))
    v_t = np.zeros((2,1,max(z_t.shape),max(z_hat_t.shape)))
    sigma_itt = np.zeros((2,2,max(z_t.shape),max(z_hat_t.shape)))
    #This could be vectorized or whatever but i think itll be okay
    for i in range(max(z_t.shape)):
        for j in range(max(z_hat_t.shape)):
           
            v_t[:,0,i,j] = z_t[:,0,i] - z_hat_t[:,0,j]
            
            sigma_itt[:,:,i,j] = H_j[:,:,j] @ P_hat_t @ H_j[:,:,j].T + R_t[i]


    # Mahalanobis distance

   
    for i in range(max(z_t.shape)):
        mah_dist_best = g**2
        save_latch = False
        for j in range(max(z_hat_t.shape)):
        # for j in range(12):
            v_ = v_t[:,:,i,j]
            sigma_ = sigma_itt[:,:,i,j]
            # print(v_)
            # print(v_.T)
            mah_dist = v_.T @ sigma_ @ v_
            
            if mah_dist <= g**2:
                
                if mah_dist <= mah_dist_best:
                    ibest = i
                    jbest = j
                    save_latch = True
                    mah_dist_best = mah_dist
                    
        if save_latch == True:
            print('bestmatch',ibest,jbest,'mah_dist_best',mah_dist_best)
            matches.append([ibest,jbest])
            v_t_matches.append(v_t[:,:,ibest,jbest])
            sigmas_matches.append(sigma_itt[:,:,ibest,jbest])
            H_matches.append(H_j[:,:,jbest])

    # print(matches)

                
    return matches, v_t_matches, sigmas_matches,H_matches

# %%
def pos_estimation(H_t, x_hat, v_t,P_t_hat,sigmas):
 
    #for number of matched lines
    for i in range(len(H_t)):
        K_t = P_t_hat @ H_t[i].T @ np.linalg.pinv(sigmas[i])
        # print(f'H_t = {H_t}')
        P_t = P_t_hat - K_t @ sigmas[i] @ K_t.T

        x_t = x_hat + K_t @ v_t[i]
        x_hat = x_t

    if len(H_t) == 0:
        x_t = x_hat
        P_t = P_t_hat
        return x_t, P_t

    
    return x_t, P_t

# %%
def pos_estimation_v2(H_t, x_hat, v_t,P_t_hat,sigma):
 
    #for number of matched lines
    
    K_t = P_t_hat @ H_t.T @ np.linalg.pinv(sigma)
    # print(f'H_t = {H_t}')
    P_t = P_t_hat - K_t @ sigma @ K_t.T

    x_t = x_hat + K_t @ v_t
    x_hat = x_t

   
    return x_t, P_t

# %%
def measurement_prediction(x_hat, gt_map_df):
    """
    The measurements needs to take the MAP data and move the lines into the Robts frame (from world) THEN match lines together or something
    x_hat = 
    map = gt map
    data = observed map data
    """
    N = int(gt_map_df.shape[1])
    z_hat_t = np.zeros([2, 1, N]) # The pridiction of what the Lines detected should be, from map
    alpha_map = gt_map_df.loc['Alpha'].astype(float)
    rho_map = gt_map_df.loc['rhos'].astype(float)

    z_hat_t[0,0,:] = alpha_map[:] - x_hat[2] # removing the robots orientation in the world to rotate the line angles into frame
    z_hat_t[1,0,:] = rho_map[:]-x_hat[0]*np.cos(alpha_map[:])+x_hat[1]*np.sin(alpha_map[:]) # translation portion for the lines

    H_j = np.zeros([2,3,N])

    for k in range(N):
        H_j[:,:,k] = np.array([[0,  0,  -1],  
                    [-np.cos(alpha_map[k]), -np.sin(alpha_map[k]), 0]])  #it might not be able to handle this notation. Could easily be a loop

    return z_hat_t,H_j

# %%
# TODO pos_t_minus1 needs to be updated to previous x_hat_t after initial time step -Rob

# %%
def position_prediction(pos_t_minus1, delta_sl, delta_sr, b,P_t_minus1):

    delta_sl
    delta_sr

    theta_t_minus1 = pos_t_minus1[2]
  
    x_hat = np.empty((3,1))

    

    # This is previous postion + estimate of future position
    x_hat = np.add(pos_t_minus1, np.array([[(delta_sr+delta_sl) / 2 * (math.cos(theta_t_minus1 + (delta_sr-delta_sl) / 2 / b))],
                                    [(delta_sr+delta_sl) / 2 * (math.sin(theta_t_minus1 + (delta_sr-delta_sl) / 2 / b))],
                                    [(delta_sr-delta_sl) / b]]))
    
    delta_s = (delta_sr+delta_sl)/2
    delta_theta = (delta_sr-delta_sl) / b

    k_r =  .001
    k_l =  .001

    Q_t  = np.array([[k_r * abs(delta_sr), 0],
                    [0, k_l * abs(delta_sl) ]])
    F_deltarl = np.array([  [.5*math.cos(theta_t_minus1+delta_theta/2)-delta_s/2/b*math.sin(theta_t_minus1+delta_theta/2),.5*math.cos(theta_t_minus1+delta_theta/2)+delta_s/2/b*math.sin(theta_t_minus1+delta_theta/2)],
                            [.5*math.sin(theta_t_minus1+delta_theta/2)+delta_s/2/b*math.cos(theta_t_minus1+delta_theta/2),.5*math.sin(theta_t_minus1+delta_theta/2)-delta_s/2/b*math.cos(theta_t_minus1+delta_theta/2)],
                            [1/b,-1/b]])

    F_k_minus_1 = np.array([[1, 0, -delta_s*math.sin(theta_t_minus1+delta_theta/2)],
                            [0, 1,  delta_s*math.cos(theta_t_minus1+delta_theta/2)],
                            [0, 0, 1]])
    
    #TODO PUT IN THE FU MATRICXZ
    # @ is matrix multiplication
    P_t_minus1_2 = P_t_minus1 * np.identity(3)
    P_hat_t = F_k_minus_1 @ P_t_minus1_2 @ F_k_minus_1.T + F_deltarl@ Q_t @ F_deltarl.T
    # pos_t_minus1 = x_hat
    return x_hat, P_hat_t

# %% [markdown]
# # Initializing map

# %% [markdown]
# Ground Truth Map Generation

# %%
file_path = 'Data_Readers_Writers/Data/'
file_name = 'DownstairsScan_not_move_GT_LineData'
# file_name = 'Downstairsdata_GT_LineData'

data_path = file_path + file_name + '.pkl'

ground_truth_df = pd.read_pickle(data_path)
ground_truth_df = ground_truth_df.T
ground_truth_df
# Out:
#                                                                    0   \
# Alpha                                                        1.528933
# rhos                                                        -1.398482
# Covariance          [[1.4555015353985783e-09, 0.0], [0.0, 6.362433...
# Lines_(endpoints)   [[0.008152954618842993, -1.4039763717795215], ...
# Points_within_line  [[0.008152954618842993, -1.4039763717795215], ...
#
#                                                                    1   \
# Alpha                                                       -0.041175
# rhos                                                         6.485009
# Covariance          [[0.005981340029956629, 0.0], [0.0, 5.71429541...
# Lines_(endpoints)   [[6.258016649308644, -4.906274947628477], [6.2...
# Points_within_line  [[6.258016649308644, -4.906274947628477], [6.2...
#
#                                                                    2   \
# Alpha                                                       -0.639583
# rhos                                                          7.59319
# Covariance          [[0.0008748717973357287, 0.0], [0.0, 0.0084381...
# Lines_(endpoints)   [[6.228536477844267, -4.270601601129469], [6.4...
# Points_within_line  [[6.228536477844267, -4.270601601129469], [6.2...
#
#                                                                    3   \
# Alpha                                                        1.128703
# rhos                                                        -0.951883
# Covariance          [[1.934309383732514e-06, 0.0], [0.0, 7.9765064...
# Lines_(endpoints)   [[6.420783042874593, -4.081079035993247], [9.0...
# Points_within_line  [[0.5743819549423546, -1.4245635861035562], [0...
#
#                                                                    4   \
# Alpha                                                       -1.018859
# rhos                                                         9.276771
# Covariance          [[0.036633361399042726, 0.0], [0.0, 0.01104819...
# Lines_(endpoints)   [[9.090249923490891, -5.342591637984422], [9.3...
# Points_within_line  [[9.090249923490891, -5.342591637984422], [9.1...
#
#                                                                    5   \
# Alpha                                                       -1.497866
# rhos                                                         5.828866
# Covariance          [[4.6447851608477636e-05, 0.0], [0.0, 0.000661...
# Lines_(endpoints)   [[9.325660242370995, -5.122662232645176], [10....
# Points_within_line  [[9.29575597651457, -5.176729482115324], [9.32...
#
#                                                                    6   \
# Alpha                                                       -0.048548
# rhos                                                         4.942724
# Covariance          [[2.205959962349593e-06, 0.0], [0.0, 7.2596445...
# Lines_(endpoints)   [[4.839291570539102, -1.9675957044508525], [4....
# Points_within_line  [[4.839291570539102, -1.9675957044508525], [4....
#
#                                                                    7   \
# Alpha                                                        1.242191
# rhos                                                         1.000041
# Covariance          [[8.044530938787486e-07, 0.0], [0.0, 5.1053556...
# Lines_(endpoints)   [[4.905512354160249, -0.6156965504840072], [4....
# Points_within_line  [[4.901962050651213, -0.7021918910551128], [4....
#
#                                                                    8   \
# Alpha                                                       -0.196845
# rhos                                                         4.538875
# Covariance          [[3.525275431347958e-05, 0.0], [0.0, 6.3848124...
# Lines_(endpoints)   [[4.525753944453946, -0.48811438311895666], [4...
# Points_within_line  [[4.530791838903417, -0.5152909767069598], [4....
#
#                                                                    9   ...  \
# Alpha                                                       -1.387999  ...
# rhos                                                         1.093727  ...
# Covariance          [[1.4232551286207996e-07, 0.0], [0.0, 7.326368...  ...
# Lines_(endpoints)   [[4.569036792890612, -0.25235043152339126], [4...  ...
# Points_within_line  [[4.5639475243253225, -0.3319050320241136], [4...  ...
#
#                                                                    72  \
# Alpha                                                       -0.035465
# rhos                                                         4.926635
# Covariance          [[2.6514062105338167e-06, 0.0], [0.0, 4.811054...
# Lines_(endpoints)   [[4.9244883747137544, -0.18600533359420515], [...
# Points_within_line  [[4.839291570539102, -1.9675957044508525], [4....
#
#                                                                    73  \
# Alpha                                                       -1.078447
# rhos                                                         1.973851
# Covariance          [[3.469228555854677e-06, 0.0], [0.0, 9.9762617...
# Lines_(endpoints)   [[4.934459464359772, 0.4164314979423046], [5.0...
# Points_within_line  [[1.2877492887309843, -1.4509658822275002], [1...
#
#                                                                    74  \
# Alpha                                                        0.090297
# rhos                                                          5.09891
# Covariance          [[2.0904623401293395e-05, 0.0], [0.0, 2.187326...
# Lines_(endpoints)   [[5.064666355671715, 0.4867205371300136], [4.9...
# Points_within_line  [[5.003666694550037, 0.4515498824871636], [5.0...
#
#                                                                    75  \
# Alpha                                                        1.540337
# rhos                                                         1.914135
# Covariance          [[3.747290198379295e-08, 0.0], [0.0, 3.6479133...
# Lines_(endpoints)   [[4.937863383954888, 1.7773606057528046], [2.4...
# Points_within_line  [[4.960502196179552, 1.688495058629504], [4.95...
#
#                                                                    76  \
# Alpha                                                       -0.951685
# rhos                                                        -0.106735
# Covariance          [[3.959373773899206e-06, 0.0], [0.0, 5.0906425...
# Lines_(endpoints)   [[2.4204055380131626, 1.8525500329389983], [1....
# Points_within_line  [[2.5802720319183767, 1.8586545310723082], [2....
#
#                                                                    77  \
# Alpha                                                        1.516715
# rhos                                                         1.619326
# Covariance          [[3.0498013163140266e-09, 0.0], [0.0, 7.774659...
# Lines_(endpoints)   [[1.979545860093206, 1.5334320754059498], [1.5...
# Points_within_line  [[5.033523948091735, 1.2060737490589615], [5.0...
#
#                                                                    78  \
# Alpha                                                       -0.817356
# rhos                                                        -0.080885
# Covariance          [[3.0685515377954927e-06, 0.0], [0.0, 3.070852...
# Lines_(endpoints)   [[1.5604549321799335, 1.564953856586494], [1.1...
# Points_within_line  [[1.6888472576099294, 1.5613438830438124], [1....
#
#                                                                    79  \
# Alpha                                                        1.386155
# rhos                                                         1.393266
# Covariance          [[8.3249982917495e-08, 0.0], [0.0, 6.777710364...
# Lines_(endpoints)   [[1.1527930461452152, 1.1832886498696593], [0....
# Points_within_line  [[4.928818655176071, 0.38714385373536986], [4....
#
#                                                                    80  \
# Alpha                                                       -0.050623
# rhos                                                         0.822196
# Covariance          [[5.109496126744668e-06, 0.0], [0.0, 1.1854879...
# Lines_(endpoints)   [[0.8836948105030336, 1.2342639515749838], [0....
# Points_within_line  [[0.6549158432821173, -1.429079886560556], [0....
#
#                                                                    81
# Alpha                                                        1.518756
# rhos                                                          1.61811
# Covariance          [[2.460134558921752e-09, 0.0], [0.0, 5.5117093...
# Lines_(endpoints)   [[0.9012990914707864, 1.5857603700411165], [-5...
# Points_within_line  [[5.034204207156025, 1.2371920460687211], [5.0...
#
# [5 rows x 82 columns]

# %%
ground_truth_df
gt_endpoints = ground_truth_df.loc['Lines_(endpoints)']
# gt_endpoints
fig = plt.figure()
plt.title('map')
# ax = fig.add_subplot()
for i in range(max(ground_truth_df.shape)):
    # print(np.array(gt_endpoints[i]))
    apl = ground_truth_df.loc['Alpha'].astype(float)[i]
    rh = ground_truth_df.loc['rhos'].astype(float)[i]
    pts_2_plt = np.array(gt_endpoints[i])

    plt.plot(pts_2_plt[:, 0], pts_2_plt[:, 1],'-')
    plt.text((pts_2_plt[0, 0]+pts_2_plt[1, 0])/2,(pts_2_plt[0, 1]+pts_2_plt[1, 1])/2,'r = '+str(round(rh,3)) +'\n'+ ' a '+str(round(apl,3))+'\n'+ 'j'+str(i))
plt.scatter(0, 0, c='red')  # replace this with the origin point
plt.show()

# %% [markdown]
# # 1. Robot Position Prediction

# %%
'''
robot pos prediction ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
'''
# Some values that are global


b = .235 # distance between robots wheels (meters)
wheel_radius = 0.072 # radius of the actual wheel (meters)

"""
These are the uncertainties in the are error constants representing the 
nondeterministic parameters of the motor drive and the wheel-floor interaction. Probably can be found in DOC or just tune for it
"""

# Pull these from ros, page 337, displacewmnt of left and right wheel
# ut = [delta_sl, delta_sr].T
#TODO When converting to robot version, get these update every time step
delta_sl = 0.0
delta_sr = 0.0

# pos_t_minus1 is the [x_t-1, y_t-1, theta_t-1] position of the robot x_t-1
# the robot drives forward with the control input ut (above) to a position vector xt
# Both are world frames
#TODO get a value for this
pos_t_minus1 = np.array([[0],
                        [0],
                        [0]])
# initialize covarience matrix TODO intiialize this beter
# P_t_minus1 = 0.1
P_t_minus1 = np.array([[10, 0, 0],
                    [0, 10, 0],                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  
                    [0, 0, .9]])

g = .7

# %% [markdown]
# # 2. Observation

# %%
# Load datapath and put into dataframe
# path to csv data
data_path = 'Data_Readers_Writers/Data/DownstairsScan_not_move_scan_data_organized.csv'
# data_path = 'Data_Readers_Writers/Data/DownstairsScanV2_scan_data_organized.csv'

tmp_df = pd.read_csv(data_path)

#read and turn to list
lowrange = 0
highrange = 1070

scan_df = []
for i in range(int(tmp_df.shape[0]/1070)):
    lowrange = 0 + 1070 * i
    highrange = lowrange + 1070
    scan_df.append(tmp_df.iloc[lowrange:highrange, :])

# Delete any column that has an inf in the rho spot
for i in range(len(scan_df)):
    inf_cols = scan_df[i]['Rho'][np.isfinite(scan_df[i]['Rho'])]
    # print(inf_cols.index)
    scan_df[i] = scan_df[i].T[inf_cols.index].T.reset_index(drop=True)
scan_df
# Out:
# [          Rho     Alpha         X         Y
#  0    1.404012  0.004136  1.403976  0.008153
#  1    1.404048  0.008272  1.403905  0.016306
#  2    1.406108  0.012390  1.405787  0.024493
#  3    1.406192  0.016519  1.405621  0.032656
#  4    1.404300  0.020677  1.403408  0.040759
#  ..        ...       ...       ...       ...
#  829  6.347022  1.348068  1.395949 -0.130121
#  830  6.352685  1.348270  1.396681 -0.122012
#  831  6.358349  1.348472  1.397366 -0.113900
#  832  6.364455  1.348367  1.399998 -0.105934
#  833  6.370119  1.348568  1.400589 -0.097803
#
#  [834 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0
rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    5.198725  0.319274 -0.300737  4.926830
#  1    5.208144  0.319850 -0.329876  4.932982
#  2    5.217565  0.320425 -0.359096  4.938963
#  3    5.211807  0.321966 -0.387144  4.928819
#  4    5.213648  0.323022 -0.415759  4.926487
#  ..        ...       ...       ...       ...
#  827  5.164412  0.303746  0.128801  4.926316
#  828  5.166152  0.304818  0.100192  4.926981
#  829  5.160269  0.306357  0.071464  4.919481
#  830  5.169649  0.306961  0.042965  4.927813
#  831  5.171407  0.308032  0.014349  4.927979
#
#  [832 rows x 4 columns],
#            Rho     Alpha         X         Y
#  0    5.180791  0.308631 -0.014291  4.935979
#  1    5.182558  0.309699 -0.042954  4.935813
#  2    5.184331  0.310766 -0.071615  4.935480
#  3    5.178496  0.312306 -0.100112  4.926983
#  4    5.180283  0.313373 -0.128721  4.926319
#  ..        ...       ...       ...       ...
#  829  4.803807  0.314625  0.384214  4.551813
#  830  4.805607  0.315774  0.357775  4.553967
#  831  4.807414  0.316923  0.331325  4.555968
#  832  4.809227  0.318070  0.304863  4.557815
#  833  4.811046  0.319216  0.278391  4.559509
#
#  [834 rows x 4 columns]]

# %%
pittypoot = np.zeros([12,36,1000])
max((pittypoot.shape))
# Out:
# 1000

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)


all_xt = []
all_xhat = []
# for robot_scans in range(len(scan_df)):
for robot_scans in range(10):

    # print(f'pos_t_minus1 = {pos_t_minus1}')
    x_hat, P_hat_t = position_prediction(pos_t_minus1, delta_sl, delta_sr, b, P_t_minus1)
    # print(f'x_hat = {x_hat}')
    
    # print(f'p_hat_t = {P_hat_t}')


    '''
    OBSERVATION ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    '''

    # Run the split and merge and get covar
    # apply the split and merge algorithm


    Lines, points_in_line, line_alpha_rho = Algorithm_split_and_merge(scan_df[robot_scans].astype(float),threshold=0.1, plot=False)

    # Do covarience line fitting, save data to lists
    alphas = []
    rhos = []
    covars = []
    for i in range(len(points_in_line)):
        rho, alpha, C_l = covarience_line_fitting(points_in_line[i], line_alpha_rho[i])
        # line_info.append([alpha, rho, C_l])
        alphas.append(alpha)
        rhos.append(rho)
        covars.append(C_l)

    print(covars)
    # Create a dataframe with the good info
    all_scan_df = pd.DataFrame([alphas, rhos, covars, Lines, points_in_line], ['Alpha','rhos' ,'Covariance', 'Lines (endpoints)', ' Points within line'])



    # alpha and rho from the lidar data
    z_t = np.array([[all_scan_df.loc['Alpha'].astype(float)],
                [all_scan_df.loc['rhos'].astype(float)]])
    
    # Covariane matrix for eachlinec calculated
    R_t = np.array(all_scan_df.loc['Covariance'])

    '''
    MEASUREMENT PREDICTION ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    '''
    ground_truth_df
    z_hat_t, H_j = measurement_prediction(x_hat, ground_truth_df)


    '''
    MATCHING ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    '''
    print(z_hat_t.shape)
    print(z_t.shape)
    matches, v_t_matches, sigmas_matches, H_j = matching(z_hat_t, z_t, R_t, H_j, P_hat_t, g)

   
    print(matches)
    for match in matches:
        i = match[0]
        j = match[1]
        print('robot_measurement',z_t[:,:,i])
        print('world frame match',z_hat_t[:,:,j])
    
    '''
    ESTIMATION ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    '''
    print(f'Scan {robot_scans}')
    print(f'x_hat = {x_hat}')
    # x_t, P_t = pos_estimation(H_j, x_hat, v_t_matches, P_hat_t, sigmas_matches)
    all_xhat.append(x_hat)
    for i in range(len(H_j)):
        
        x_t, P_t = pos_estimation_v2(H_j[i], x_hat, v_t_matches[i], P_hat_t, sigmas_matches[i])
        print(x_t-x_hat)
        x_hat = x_t
        P_hat_t = P_t
    
    if len(H_j) < 1:
        P_t = P_hat_t
        x_t = x_hat
    P_t_minus1 = P_t

    pos_t_minus1 = x_t


    
    
    
    # print(f'pos_t_minus1 = {pos_t_minus1}')

    all_xt.append(x_t)
    print(f'x_t = {x_t}')

    
    
    print(f'covarience = {P_t}')

    print('\n')
    print('\n')
# Out:
# [array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 2.3567653e-11]]), array([[0.        , 0.        ],
#        [0.        , 0.00976668]]), array([[0.        , 0.        ],
#        [0.        , 0.02140113]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.96840878e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00415316]]), array([[0.000000e+00, 0.000000e+00],
#        [0.000000e+00, 6.283847e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.05942716e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.59037847e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00036357]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.78090533e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00010573]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.25796957e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00187671]]), array([[0.        , 0.        ],
#        [0.        , 0.00487754]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.6153349e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.24941729e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.24739748e-11]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.0370474e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.89301748e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.86527749e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.12570042e-11]]), array([[0.       , 0.       ],
#        [0.       , 0.0090894]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.35092955e-10]])]
# (2, 1, 82)
# (2, 1, 23)
# bestmatch 3 80 mah_dist_best [[0.31445926]]
# bestmatch 19 30 mah_dist_best [[0.13969578]]
# [[3, 80], [19, 30]]
# robot_measurement [[-0.43996588]
#  [ 0.95562432]]
# world frame match [[-0.05062255]
#  [ 0.8221965 ]]
# robot_measurement [[1.46637353]
#  [0.74413239]]
# world frame match [[1.32234845]
#  [0.63412072]]
# Scan 0
# x_hat = [[0.]
#  [0.]
#  [0.]]
# [[-0.13325689]
#  [ 0.00675157]
#  [ 0.38934333]]
# [[-0.00545807]
#  [-0.10772679]
#  [ 0.        ]]
# x_t = [[-0.13871496]
#  [-0.10097522]
#  [ 0.38934333]]
# covarience = [[0.00098976 0.01952526 0.        ]
#  [0.01952526 0.38537564 0.        ]
#  [0.         0.         0.        ]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.93496674e-11]]), array([[0.        , 0.        ],
#        [0.        , 0.00878596]]), array([[0.        , 0.        ],
#        [0.        , 0.02143929]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.52204284e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00032781]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.56880821e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.61997036e-05]]), array([[0.        , 0.        ],
#        [0.        , 0.00018059]]), array([[0.        , 0.        ],
#        [0.        , 0.00036034]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.07721351e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00011646]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.41529322e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00125866]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.48998107e-10]]), array([[0.000000e+00, 0.000000e+00],
#        [0.000000e+00, 4.497274e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.47592109e-11]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.0381456e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.04209244e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00010556]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 4.0823078e-11]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 2.8288444e-11]])]
# (2, 1, 82)
# (2, 1, 21)
# bestmatch 0 80 mah_dist_best [[0.00036951]]
# bestmatch 1 1 mah_dist_best [[0.00019839]]
# bestmatch 2 25 mah_dist_best [[0.00325993]]
# bestmatch 3 80 mah_dist_best [[4.01225217e-05]]
# bestmatch 4 65 mah_dist_best [[0.00100732]]
# bestmatch 5 33 mah_dist_best [[0.00073429]]
# bestmatch 6 33 mah_dist_best [[1.57861033e-05]]
# bestmatch 7 64 mah_dist_best [[2.2762602e-05]]
# bestmatch 8 31 mah_dist_best [[0.00039168]]
# bestmatch 9 80 mah_dist_best [[0.00043559]]
# bestmatch 10 33 mah_dist_best [[2.63848224e-05]]
# bestmatch 11 36 mah_dist_best [[3.49459557e-05]]
# bestmatch 12 47 mah_dist_best [[0.06596877]]
# bestmatch 13 80 mah_dist_best [[0.01666329]]
# bestmatch 14 80 mah_dist_best [[0.00229077]]
# bestmatch 15 22 mah_dist_best [[0.00461252]]
# bestmatch 16 80 mah_dist_best [[0.00201264]]
# bestmatch 17 43 mah_dist_best [[0.0031075]]
# bestmatch 18 61 mah_dist_best [[7.02283152e-05]]
# bestmatch 19 22 mah_dist_best [[0.00473736]]
# bestmatch 20 80 mah_dist_best [[0.00037007]]
# [[0, 80], [1, 1], [2, 25], [3, 80], [4, 65], [5, 33], [6, 33], [7, 64], [8, 31], [9, 80], [10, 33], [11, 36], [12, 47], [13, 80], [14, 80], [15, 22], [16, 80], [17, 43], [18, 61], [19, 22], [20, 80]]
# robot_measurement [[-0.04044902]
#  [ 1.39849914]]
# world frame match [[-0.43996588]
#  [ 0.9658432 ]]
# robot_measurement [[1.531895  ]
#  [6.48982498]]
# world frame match [[-0.4305185]
#  [ 6.6277633]]
# robot_measurement [[0.95098417]
#  [7.60750262]]
# world frame match [[-0.91995577]
#  [ 7.77173007]]
# robot_measurement [[-0.414185  ]
#  [ 1.10839951]]
# world frame match [[-0.43996588]
#  [ 0.9658432 ]]
# robot_measurement [[0.25788756]
#  [7.39070364]]
# world frame match [[-0.53451948]
#  [ 7.06268701]]
# robot_measurement [[0.07458013]
#  [5.8462039 ]]
# world frame match [[-0.41152447]
#  [ 5.05697125]]
# robot_measurement [[1.51522719]
#  [4.94526311]]
# world frame match [[-0.41152447]
#  [ 5.05697125]]
# robot_measurement [[-0.43680389]
#  [-1.50125379]]
# world frame match [[ 1.13958999]
#  [-1.49356343]]
# robot_measurement [[1.37751162]
#  [4.53845737]]
# world frame match [[-0.58618852]
#  [ 4.69465995]]
# robot_measurement [[0.25526734]
#  [1.43546913]]
# world frame match [[-0.43996588]
#  [ 0.9658432 ]]
# robot_measurement [[1.55061945]
#  [4.91424901]]
# world frame match [[-0.41152447]
#  [ 5.05697125]]
# robot_measurement [[0.45263312]
#  [1.77924694]]
# world frame match [[1.16054957]
#  [1.78877162]]
# robot_measurement [[-1.46571006]
#  [-5.10382776]]
# world frame match [[ 1.12873615]
#  [-4.69019091]]
# robot_measurement [[-0.03645589]
#  [-1.93959386]]
# world frame match [[-0.43996588]
#  [ 0.9658432 ]]
# robot_measurement [[ 0.61802802]
#  [-0.11019569]]
# world frame match [[-0.43996588]
#  [ 0.9658432 ]]
# robot_measurement [[-0.04716568]
#  [-1.61973109]]
# world frame match [[ 1.10650322]
#  [-1.51002141]]
# robot_measurement [[ 0.76963767]
#  [-0.04126376]]
# world frame match [[-0.43996588]
#  [ 0.9658432 ]]
# robot_measurement [[-0.20919891]
#  [-1.40361154]]
# world frame match [[ 1.14056553]
#  [-1.4934838 ]]
# robot_measurement [[1.48898952]
#  [0.77788997]]
# world frame match [[-0.49266888]
#  [ 0.89427653]]
# robot_measurement [[-0.04401146]
#  [-1.62120576]]
# world frame match [[ 1.10650322]
#  [-1.51002141]]
# robot_measurement [[-0.04170436]
#  [ 1.39882881]]
# world frame match [[-0.43996588]
#  [ 0.9658432 ]]
# Scan 1
# x_hat = [[-0.13871496]
#  [-0.10097522]
#  [ 0.38934333]]
# [[-0.21665863]
#  [ 4.27412843]
#  [ 0.        ]]
# [[0.00122197]
#  [0.0241183 ]
#  [0.        ]]
# [[-0.00612447]
#  [-0.12087961]
#  [ 0.        ]]
# [[-9.75224346e-10]
#  [ 8.36308889e-09]
#  [ 0.00000000e+00]]
# [[0.02130081]
#  [0.42041769]
#  [0.        ]]
# [[-0.1077438]
#  [-2.1265571]
#  [ 0.       ]]
# [[0.01312074]
#  [0.25896624]
#  [0.        ]]
# [[9.75056687e-05]
#  [1.92448575e-03]
#  [0.00000000e+00]]
# [[-0.00518522]
#  [-0.10234157]
#  [ 0.        ]]
# [[-3.44618134e-09]
#  [ 2.29090227e-08]
#  [ 0.00000000e+00]]
# [[0.0103645 ]
#  [0.20456577]
#  [0.        ]]
# [[7.84151963e-05]
#  [1.54769390e-03]
#  [0.00000000e+00]]
# [[0.00285019]
#  [0.05625475]
#  [0.        ]]
# [[ 2.20197960e-08]
#  [-1.28236281e-07]
#  [ 0.00000000e+00]]
# [[ 8.13657269e-09]
#  [-4.73848085e-08]
#  [ 0.00000000e+00]]
# [[0.00065683]
#  [0.01296387]
#  [0.        ]]
# [[ 7.85333742e-09]
#  [-3.90746338e-08]
#  [ 0.00000000e+00]]
# [[-0.00047267]
#  [-0.00932914]
#  [ 0.        ]]
# [[-0.00214429]
#  [-0.04232217]
#  [ 0.        ]]
# [[0.00051583]
#  [0.01018106]
#  [0.        ]]
# [[-3.63515534e-09]
#  [ 1.21308181e-08]
#  [ 0.00000000e+00]]
# x_t = [[-0.4268372 ]
#  [ 2.7626633 ]
#  [ 0.38934333]]
# covarience = [[8.17426788e-05 1.61336859e-03 0.00000000e+00]
#  [1.61336859e-03 3.18433268e-02 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.09916543e-11]]), array([[0.        , 0.        ],
#        [0.        , 0.00520556]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.79882709e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.31626306e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.66304069e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.49637608e-07]]), array([[0.       , 0.       ],
#        [0.       , 0.0003549]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.79579144e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.68910221e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.30792641e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00138144]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.93788842e-12]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.14559102e-06]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 8.7360993e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.97465209e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.91752366e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00010186]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.22754124e-10]]), array([[0.        , 0.        ],
#        [0.        , 0.16454593]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.85068012e-11]])]
# (2, 1, 82)
# (2, 1, 20)
# bestmatch 0 64 mah_dist_best [[1.06811653e-05]]
# bestmatch 1 65 mah_dist_best [[2.09344424e-05]]
# bestmatch 2 80 mah_dist_best [[3.69154023e-06]]
# bestmatch 3 35 mah_dist_best [[5.45170211e-06]]
# bestmatch 4 72 mah_dist_best [[1.92691636e-05]]
# bestmatch 5 80 mah_dist_best [[0.00093716]]
# bestmatch 6 31 mah_dist_best [[2.36622077e-05]]
# bestmatch 7 80 mah_dist_best [[1.36909041e-08]]
# bestmatch 8 72 mah_dist_best [[2.35469222e-05]]
# bestmatch 9 80 mah_dist_best [[0.00012297]]
# bestmatch 10 63 mah_dist_best [[0.01601098]]
# bestmatch 11 78 mah_dist_best [[0.00012974]]
# bestmatch 12 80 mah_dist_best [[0.00024377]]
# bestmatch 13 39 mah_dist_best [[0.00018166]]
# bestmatch 14 80 mah_dist_best [[0.00024345]]
# bestmatch 15 71 mah_dist_best [[0.00061931]]
# bestmatch 16 61 mah_dist_best [[1.00811913e-05]]
# bestmatch 17 71 mah_dist_best [[0.00016143]]
# bestmatch 18 4 mah_dist_best [[0.17816485]]
# bestmatch 19 64 mah_dist_best [[1.16960163e-05]]
# [[0, 64], [1, 65], [2, 80], [3, 35], [4, 72], [5, 80], [6, 31], [7, 80], [8, 72], [9, 80], [10, 63], [11, 78], [12, 80], [13, 39], [14, 80], [15, 71], [16, 61], [17, 71], [18, 4], [19, 64]]
# robot_measurement [[-0.04101066]
#  [ 1.39795505]]
# world frame match [[1.13958999]
#  [1.37962432]]
# robot_measurement [[1.40046479]
#  [6.99281108]]
# world frame match [[-0.53451948]
#  [ 6.93350512]]
# robot_measurement [[-0.39946511]
#  [ 1.25902464]]
# world frame match [[-0.43996588]
#  [ 1.10869358]]
# robot_measurement [[0.08295601]
#  [5.923976  ]]
# world frame match [[-0.28717587]
#  [ 5.80898002]]
# robot_measurement [[1.52266585]
#  [4.94352657]]
# world frame match [[-0.42480787]
#  [ 5.25524735]]
# robot_measurement [[-0.38740141]
#  [-1.28604489]]
# world frame match [[-0.43996588]
#  [ 1.10869358]]
# robot_measurement [[1.36820046]
#  [4.53685524]]
# world frame match [[-0.58618852]
#  [ 4.41715794]]
# robot_measurement [[0.18371662]
#  [1.09953117]]
# world frame match [[-0.43996588]
#  [ 1.10869358]]
# robot_measurement [[1.53602634]
#  [4.92701816]]
# world frame match [[-0.42480787]
#  [ 5.25524735]]
# robot_measurement [[0.49148542]
#  [1.97100128]]
# world frame match [[-0.43996588]
#  [ 1.10869358]]
# robot_measurement [[-1.47672699]
#  [-5.10253706]]
# world frame match [[-0.14978878]
#  [-7.32166642]]
# robot_measurement [[-0.02314802]
#  [-1.89119967]]
# world frame match [[-1.20669892]
#  [-1.80378157]]
# robot_measurement [[ 0.61651224]
#  [-0.09871642]]
# world frame match [[-0.43996588]
#  [ 1.10869358]]
# robot_measurement [[-0.06558096]
#  [-1.62598104]]
# world frame match [[-1.19111404]
#  [-1.73096318]]
# robot_measurement [[ 0.75347069]
#  [-0.08087775]]
# world frame match [[-0.43996588]
#  [ 1.10869358]]
# robot_measurement [[-0.20448624]
#  [-1.40350235]]
# world frame match [[-1.77734279]
#  [-1.54531715]]
# robot_measurement [[1.46798716]
#  [0.74646381]]
# world frame match [[-0.49266888]
#  [ 0.88550131]]
# robot_measurement [[-0.05361841]
#  [-1.61772136]]
# world frame match [[-1.77734279]
#  [-1.54531715]]
# robot_measurement [[-1.20948458]
#  [ 8.12252193]]
# world frame match [[-1.40820252]
#  [ 7.14814146]]
# robot_measurement [[-0.04412575]
#  [ 1.39880612]]
# world frame match [[1.13958999]
#  [1.37962432]]
# Scan 2
# x_hat = [[-0.4268372 ]
#  [ 2.7626633 ]
#  [ 0.38934333]]
# [[-1.97275491e-06]
#  [-1.83467226e-02]
#  [ 0.00000000e+00]]
# [[-8.10847787e-04]
#  [ 3.39643986e-05]
#  [ 0.00000000e+00]]
# [[-0.07426728]
#  [ 0.00311087]
#  [ 0.        ]]
# [[-0.01126275]
#  [ 0.00047177]
#  [ 0.        ]]
# [[ 0.05791045]
#  [-0.00242572]
#  [ 0.        ]]
# [[ 0.43947678]
#  [-0.01840858]
#  [ 0.        ]]
# [[-1.75313787e-03]
#  [ 7.34347853e-05]
#  [ 0.00000000e+00]]
# [[ 1.35549672e-03]
#  [-5.67783669e-05]
#  [ 0.00000000e+00]]
# [[ 0.03086838]
#  [-0.001293  ]
#  [ 0.        ]]
# [[-0.09708895]
#  [ 0.00406681]
#  [ 0.        ]]
# [[-0.01083356]
#  [ 0.00045379]
#  [ 0.        ]]
# [[ 6.04665926e-05]
#  [-2.53286958e-06]
#  [ 0.00000000e+00]]
# [[ 0.11868122]
#  [-0.00497126]
#  [ 0.        ]]
# [[-6.84240288e-05]
#  [ 2.86620294e-06]
#  [ 0.00000000e+00]]
# [[ 0.1024172]
#  [-0.00429  ]
#  [ 0.       ]]
# [[-1.38874430e-05]
#  [ 5.81804418e-07]
#  [ 0.00000000e+00]]
# [[ 0.00360207]
#  [-0.00015088]
#  [ 0.        ]]
# [[ 6.90665147e-06]
#  [-2.89350415e-07]
#  [ 0.00000000e+00]]
# [[-3.83060029e-05]
#  [ 1.60463252e-06]
#  [ 0.00000000e+00]]
# [[-4.75064432e-13]
#  [-1.26583188e-11]
#  [ 0.00000000e+00]]
# x_t = [[0.13140265]
#  [2.72093322]
#  [0.38934333]]
# covarience = [[ 1.31735084e-05 -5.51804249e-07  0.00000000e+00]
#  [-5.51804249e-07  2.31346835e-08  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.17152786e-11]]), array([[0.        , 0.        ],
#        [0.        , 0.00524608]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.84140261e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.65898338e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.59648755e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.49380886e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00035442]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.79670132e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.66637171e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.30900955e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00139061]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.94265275e-12]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.28726824e-06]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 2.3974673e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.97526127e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.74179116e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00011312]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.22679585e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.58617978e-11]])]
# (2, 1, 82)
# (2, 1, 19)
# bestmatch 0 43 mah_dist_best [[3.07958749e-10]]
# bestmatch 1 4 mah_dist_best [[3.40386844e-05]]
# bestmatch 2 22 mah_dist_best [[5.44945283e-10]]
# bestmatch 3 2 mah_dist_best [[8.37952101e-08]]
# bestmatch 4 46 mah_dist_best [[3.0787462e-06]]
# bestmatch 5 32 mah_dist_best [[3.60996524e-08]]
# bestmatch 6 36 mah_dist_best [[1.55408746e-06]]
# bestmatch 7 43 mah_dist_best [[2.96590252e-09]]
# bestmatch 8 33 mah_dist_best [[4.41328697e-06]]
# bestmatch 9 43 mah_dist_best [[1.00914155e-06]]
# bestmatch 10 76 mah_dist_best [[0.01017483]]
# bestmatch 11 47 mah_dist_best [[1.18441005e-11]]
# bestmatch 12 73 mah_dist_best [[1.048229e-06]]
# bestmatch 13 71 mah_dist_best [[8.76163324e-11]]
# bestmatch 14 73 mah_dist_best [[1.95912497e-06]]
# bestmatch 15 47 mah_dist_best [[1.87333119e-08]]
# bestmatch 16 80 mah_dist_best [[9.12900731e-06]]
# bestmatch 17 71 mah_dist_best [[6.67453217e-11]]
# bestmatch 18 43 mah_dist_best [[3.14548942e-10]]
# [[0, 43], [1, 4], [2, 22], [3, 2], [4, 46], [5, 32], [6, 36], [7, 43], [8, 33], [9, 43], [10, 76], [11, 47], [12, 73], [13, 71], [14, 73], [15, 47], [16, 80], [17, 71], [18, 43]]
# robot_measurement [[-0.04086976]
#  [ 1.39763235]]
# world frame match [[1.14056553]
#  [1.31502482]]
# robot_measurement [[1.40763463]
#  [6.97149155]]
# world frame match [[-1.40820252]
#  [ 6.89096885]]
# robot_measurement [[-0.40105372]
#  [ 1.24591953]]
# world frame match [[1.10650322]
#  [1.28373844]]
# robot_measurement [[0.0852403 ]
#  [5.96213858]]
# world frame match [[-1.02892653]
#  [ 5.86374106]]
# robot_measurement [[1.51944793]
#  [4.94328861]]
# world frame match [[-1.65063588]
#  [ 5.14297836]]
# robot_measurement [[-0.3873594]
#  [-1.2862778]]
# world frame match [[-1.68344322]
#  [-1.12298755]]
# robot_measurement [[1.36790532]
#  [4.53820194]]
# world frame match [[1.16054957]
#  [4.60441759]]
# robot_measurement [[0.18363591]
#  [1.09817797]]
# world frame match [[1.14056553]
#  [1.31502482]]
# robot_measurement [[1.53511665]
#  [4.9247881 ]]
# world frame match [[-0.41152447]
#  [ 4.72433208]]
# robot_measurement [[0.49142081]
#  [1.96975455]]
# world frame match [[1.14056553]
#  [1.31502482]]
# robot_measurement [[-1.4822049 ]
#  [-5.09954616]]
# world frame match [[-1.34102866]
#  [-2.39890248]]
# robot_measurement [[-0.02662385]
#  [-1.9005262 ]]
# world frame match [[ 1.12873615]
#  [-1.88643584]]
# robot_measurement [[ 0.61954936]
#  [-0.10574279]]
# world frame match [[-1.46779026]
#  [-0.4860164 ]]
# robot_measurement [[-0.05480232]
#  [-1.61959192]]
# world frame match [[-1.77734279]
#  [-1.60575947]]
# robot_measurement [[ 0.75346626]
#  [-0.08089243]]
# world frame match [[-1.46779026]
#  [-0.4860164 ]]
# robot_measurement [[-0.1844033 ]
#  [-1.39339818]]
# world frame match [[ 1.12873615]
#  [-1.88643584]]
# robot_measurement [[1.52137035]
#  [0.82217177]]
# world frame match [[-0.43996588]
#  [ 0.55328044]]
# robot_measurement [[-0.05365038]
#  [-1.61783406]]
# world frame match [[-1.77734279]
#  [-1.60575947]]
# robot_measurement [[-0.04400055]
#  [ 1.39849847]]
# world frame match [[1.14056553]
#  [1.31502482]]
# Scan 3
# x_hat = [[0.13140265]
#  [2.72093322]
#  [0.38934333]]
# [[-0.98568244]
#  [-0.04231232]
#  [ 0.        ]]
# [[-5.78757734e-05]
#  [ 2.36577291e-06]
#  [ 0.00000000e+00]]
# [[ 0.02284729]
#  [-0.00093166]
#  [ 0.        ]]
# [[-0.0620977 ]
#  [ 0.00253832]
#  [ 0.        ]]
# [[ 0.00280717]
#  [-0.00011479]
#  [ 0.        ]]
# [[ 0.11850851]
#  [-0.0048461 ]
#  [ 0.        ]]
# [[-9.06275301e-06]
#  [ 3.74406878e-07]
#  [ 0.00000000e+00]]
# [[3.78929544e-04]
#  [5.91579665e-05]
#  [0.00000000e+00]]
# [[-0.0044402 ]
#  [ 0.00018145]
#  [ 0.        ]]
# [[-2.99674081e-05]
#  [-4.81168248e-06]
#  [ 0.00000000e+00]]
# [[ 0.00282384]
#  [-0.00011543]
#  [ 0.        ]]
# [[ 0.00666877]
#  [-0.0002674 ]
#  [ 0.        ]]
# [[-0.06304679]
#  [ 0.00257768]
#  [ 0.        ]]
# [[ 0.01450416]
#  [-0.0005934 ]
#  [ 0.        ]]
# [[-0.02865456]
#  [ 0.00117131]
#  [ 0.        ]]
# [[-0.12176822]
#  [ 0.00483593]
#  [ 0.        ]]
# [[-0.00340006]
#  [ 0.00013892]
#  [ 0.        ]]
# [[ 0.00922087]
#  [-0.0003773 ]
#  [ 0.        ]]
# [[-1.59361615e-04]
#  [-3.35924197e-05]
#  [ 0.00000000e+00]]
# x_t = [[-0.96018403]
#  [ 2.68284193]
#  [ 0.38934333]]
# covarience = [[ 1.30812082e-06 -5.34293537e-08  0.00000000e+00]
#  [-5.34293537e-08  2.20398234e-09  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.83705736e-11]]), array([[0.       , 0.       ],
#        [0.       , 0.0252547]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.46024696e-05]]), array([[0.        , 0.        ],
#        [0.        , 0.01662372]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.80960407e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.14616129e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.37502922e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.15946592e-05]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.6167517e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00034768]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.66359227e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00014912]]), array([[0.        , 0.        ],
#        [0.        , 0.00546414]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.80760006e-12]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.26312474e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.06538296e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.14097058e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.76027874e-08]]), array([[0.       , 0.       ],
#        [0.       , 0.0001169]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.2287994e-10]]), array([[0.        , 0.        ],
#        [0.        , 0.05572829]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.17460872e-11]])]
# (2, 1, 82)
# (2, 1, 22)
# bestmatch 0 43 mah_dist_best [[2.6077712e-11]]
# bestmatch 1 25 mah_dist_best [[9.22753585e-05]]
# bestmatch 2 63 mah_dist_best [[0.00015684]]
# bestmatch 3 25 mah_dist_best [[0.00024717]]
# bestmatch 4 43 mah_dist_best [[1.22707455e-09]]
# bestmatch 5 29 mah_dist_best [[1.21349528e-09]]
# bestmatch 6 32 mah_dist_best [[2.88020077e-08]]
# bestmatch 7 70 mah_dist_best [[9.1146387e-13]]
# bestmatch 8 32 mah_dist_best [[1.09570228e-08]]
# bestmatch 9 36 mah_dist_best [[9.77908265e-07]]
# bestmatch 10 61 mah_dist_best [[3.73190995e-10]]
# bestmatch 11 70 mah_dist_best [[7.89835198e-10]]
# bestmatch 12 63 mah_dist_best [[0.01440453]]
# bestmatch 13 47 mah_dist_best [[1.47993428e-12]]
# bestmatch 14 34 mah_dist_best [[5.2681324e-08]]
# bestmatch 15 47 mah_dist_best [[3.6512706e-10]]
# bestmatch 16 34 mah_dist_best [[1.65928318e-07]]
# bestmatch 17 71 mah_dist_best [[3.55256646e-11]]
# bestmatch 18 43 mah_dist_best [[2.93644897e-05]]
# bestmatch 19 47 mah_dist_best [[3.6938479e-10]]
# bestmatch 20 4 mah_dist_best [[0.04660413]]
# bestmatch 21 43 mah_dist_best [[2.62473138e-11]]
# [[0, 43], [1, 25], [2, 63], [3, 25], [4, 43], [5, 29], [6, 32], [7, 70], [8, 32], [9, 36], [10, 61], [11, 70], [12, 63], [13, 47], [14, 34], [15, 47], [16, 34], [17, 71], [18, 43], [19, 47], [20, 4], [21, 43]]
# robot_measurement [[-0.04219238]
#  [ 1.39844533]]
# world frame match [[1.14056553]
#  [1.32158514]]
# robot_measurement [[1.36591829]
#  [7.13190722]]
# world frame match [[-0.91995577]
#  [ 7.0714618 ]]
# robot_measurement [[-1.3194909 ]
#  [-4.97273604]]
# world frame match [[-0.14978878]
#  [-6.82248917]]
# robot_measurement [[0.67102328]
#  [7.19339576]]
# world frame match [[-0.91995577]
#  [ 7.0714618 ]]
# robot_measurement [[-0.39962384]
#  [ 1.25600848]]
# world frame match [[1.14056553]
#  [1.32158514]]
# robot_measurement [[0.06171999]
#  [5.72923694]]
# world frame match [[-0.44397725]
#  [ 5.75848195]]
# robot_measurement [[-0.48152691]
#  [-0.57553519]]
# world frame match [[-1.68344322]
#  [-0.78814631]]
# robot_measurement [[1.51951878]
#  [4.94548696]]
# world frame match [[-0.58931855]
#  [ 4.94559184]]
# robot_measurement [[-0.32300829]
#  [-0.99290716]]
# world frame match [[-1.68344322]
#  [-0.78814631]]
# robot_measurement [[1.37191563]
#  [4.53611644]]
# world frame match [[1.16054957]
#  [4.58915086]]
# robot_measurement [[0.26107432]
#  [1.43546913]]
# world frame match [[-0.49266888]
#  [ 1.42423654]]
# robot_measurement [[1.49964624]
#  [4.94788364]]
# world frame match [[-0.58931855]
#  [ 4.94559184]]
# robot_measurement [[-1.33842515]
#  [-5.19903589]]
# world frame match [[-0.14978878]
#  [-6.82248917]]
# robot_measurement [[-0.01898839]
#  [-1.88288484]]
# world frame match [[ 1.12873615]
#  [-1.86695586]]
# robot_measurement [[ 0.61949831]
#  [-0.10611331]]
# world frame match [[-1.50783474]
#  [-0.21413496]]
# robot_measurement [[-0.05153122]
#  [-1.61895061]]
# world frame match [[ 1.12873615]
#  [-1.86695586]]
# robot_measurement [[ 0.7537144 ]
#  [-0.08122207]]
# world frame match [[-1.50783474]
#  [-0.21413496]]
# robot_measurement [[-0.18465145]
#  [-1.39362776]]
# world frame match [[-1.77734279]
#  [-1.36987359]]
# robot_measurement [[1.51933064]
#  [0.82040762]]
# world frame match [[1.14056553]
#  [1.32158514]]
# robot_measurement [[-0.05343732]
#  [-1.61785145]]
# world frame match [[ 1.12873615]
#  [-1.86695586]]
# robot_measurement [[-1.33225906]
#  [ 8.41024138]]
# world frame match [[-1.40820252]
#  [ 7.49576404]]
# robot_measurement [[-0.04300011]
#  [ 1.3986654 ]]
# world frame match [[1.14056553]
#  [1.32158514]]
# Scan 4
# x_hat = [[-0.96018403]
#  [ 2.68284193]
#  [ 0.38934333]]
# [[-0.93100467]
#  [-0.03834245]
#  [ 0.        ]]
# [[-1.39560083e-06]
#  [ 5.64015781e-08]
#  [ 0.00000000e+00]]
# [[-0.02563464]
#  [ 0.0010351 ]
#  [ 0.        ]]
# [[-4.21979193e-06]
#  [ 1.70539949e-07]
#  [ 0.00000000e+00]]
# [[7.78983513e-05]
#  [3.29606257e-06]
#  [0.00000000e+00]]
# [[ 0.01344015]
#  [-0.00054287]
#  [ 0.        ]]
# [[-0.03664246]
#  [ 0.00148891]
#  [ 0.        ]]
# [[ 4.16546996e-07]
#  [-1.68246013e-08]
#  [ 0.00000000e+00]]
# [[ 0.08108955]
#  [-0.00329502]
#  [ 0.        ]]
# [[-8.61430456e-07]
#  [ 3.90250183e-08]
#  [ 0.00000000e+00]]
# [[-1.10269581e-03]
#  [ 4.44902932e-05]
#  [ 0.00000000e+00]]
# [[-3.94840536e-06]
#  [ 1.59346985e-07]
#  [ 0.00000000e+00]]
# [[-7.47887193e-05]
#  [ 3.01468282e-06]
#  [ 0.00000000e+00]]
# [[ 0.00887292]
#  [-0.0002814 ]
#  [ 0.        ]]
# [[-0.00294405]
#  [ 0.00011953]
#  [ 0.        ]]
# [[-0.13244096]
#  [ 0.00418517]
#  [ 0.        ]]
# [[-1.70758300e-03]
#  [ 6.94279272e-05]
#  [ 0.00000000e+00]]
# [[ 0.02117697]
#  [-0.00086692]
#  [ 0.        ]]
# [[5.04907225e-07]
#  [9.85740103e-08]
#  [0.00000000e+00]]
# [[-0.10564602]
#  [ 0.0031004 ]
#  [ 0.        ]]
# [[-1.85412292e-06]
#  [ 7.52716045e-08]
#  [ 0.00000000e+00]]
# [[-0.00183913]
#  [-0.00040753]
#  [ 0.        ]]
# x_t = [[-2.0745749 ]
#  [ 2.64915566]
#  [ 0.38934333]]
# covarience = [[ 2.02226005e-07 -8.16828480e-09  0.00000000e+00]
#  [-8.16828480e-09  3.57396727e-10  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.15693262e-11]]), array([[0.        , 0.        ],
#        [0.        , 0.02346717]]), array([[0.        , 0.        ],
#        [0.        , 0.01409812]]), array([[0.        , 0.        ],
#        [0.        , 0.04323829]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.01107206e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00331997]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.76103172e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.34055098e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.38461101e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.33974582e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00034511]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.34500794e-05]]), array([[0.        , 0.        ],
#        [0.        , 0.00011321]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.25294485e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00142086]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.75620386e-12]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.88989578e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.01209666e-10]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.14259589e-06]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 1.7447098e-08]]), array([[0.       , 0.       ],
#        [0.       , 0.0001164]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.16407561e-10]]), array([[0.        , 0.        ],
#        [0.        , 0.00795873]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.65116309e-10]])]
# (2, 1, 82)
# (2, 1, 24)
# bestmatch 0 22 mah_dist_best [[6.42929852e-13]]
# bestmatch 1 13 mah_dist_best [[0.00031014]]
# bestmatch 2 31 mah_dist_best [[0.00164404]]
# bestmatch 3 2 mah_dist_best [[0.00030133]]
# bestmatch 4 43 mah_dist_best [[2.32041333e-09]]
# bestmatch 5 65 mah_dist_best [[0.0006379]]
# bestmatch 6 27 mah_dist_best [[3.85681254e-11]]
# bestmatch 7 78 mah_dist_best [[2.0096916e-10]]
# bestmatch 8 14 mah_dist_best [[3.79424156e-06]]
# bestmatch 9 71 mah_dist_best [[7.64068958e-09]]
# bestmatch 10 69 mah_dist_best [[8.10723046e-08]]
# bestmatch 11 22 mah_dist_best [[1.82439339e-06]]
# bestmatch 12 14 mah_dist_best [[4.05286743e-06]]
# bestmatch 13 45 mah_dist_best [[1.61840141e-09]]
# bestmatch 14 63 mah_dist_best [[0.00059914]]
# bestmatch 15 47 mah_dist_best [[3.14079354e-12]]
# bestmatch 16 32 mah_dist_best [[4.74509682e-07]]
# bestmatch 17 47 mah_dist_best [[7.28154368e-11]]
# bestmatch 18 32 mah_dist_best [[1.25412276e-06]]
# bestmatch 19 71 mah_dist_best [[1.65365428e-09]]
# bestmatch 20 73 mah_dist_best [[4.7274242e-06]]
# bestmatch 21 47 mah_dist_best [[5.16066756e-11]]
# bestmatch 22 1 mah_dist_best [[0.00016235]]
# bestmatch 23 22 mah_dist_best [[9.59352747e-13]]
# [[0, 22], [1, 13], [2, 31], [3, 2], [4, 43], [5, 65], [6, 27], [7, 78], [8, 14], [9, 71], [10, 69], [11, 22], [12, 14], [13, 45], [14, 63], [15, 47], [16, 32], [17, 47], [18, 32], [19, 71], [20, 73], [21, 47], [22, 1], [23, 22]]
# robot_measurement [[-0.04062332]
#  [ 1.39797392]]
# world frame match [[1.10650322]
#  [1.37734515]]
# robot_measurement [[1.01232272]
#  [7.87155174]]
# world frame match [[-0.18031756]
#  [ 7.75659219]]
# robot_measurement [[1.55334599]
#  [6.39676082]]
# world frame match [[-0.58618852]
#  [ 6.0552747 ]]
# robot_measurement [[0.9252848 ]
#  [7.59305568]]
# world frame match [[-1.02892653]
#  [ 7.67653646]]
# robot_measurement [[-0.40695936]
#  [ 1.24579468]]
# world frame match [[1.14056553]
#  [1.33347895]]
# robot_measurement [[0.49720798]
#  [9.01865562]]
# world frame match [[-0.53451948]
#  [ 8.58033012]]
# robot_measurement [[0.09266183]
#  [6.02056826]]
# world frame match [[-1.63965999]
#  [ 5.99675292]]
# robot_measurement [[-0.48135884]
#  [-0.57581637]]
# world frame match [[-1.20669892]
#  [-0.59369251]]
# robot_measurement [[1.52433999]
#  [4.94408745]]
# world frame match [[1.12991511]
#  [4.73136236]]
# robot_measurement [[-0.38298329]
#  [-1.28386214]]
# world frame match [[-1.77734279]
#  [-1.13417398]]
# robot_measurement [[1.36997054]
#  [4.53848628]]
# world frame match [[0.79394135]
#  [4.52315999]]
# robot_measurement [[0.30577722]
#  [1.65626107]]
# world frame match [[1.10650322]
#  [1.37734515]]
# robot_measurement [[1.54529767]
#  [4.92057265]]
# world frame match [[1.12991511]
#  [4.73136236]]
# robot_measurement [[0.49034465]
#  [1.96449656]]
# world frame match [[0.78137039]
#  [1.99111619]]
# robot_measurement [[-1.47831757]
#  [-5.0985961 ]]
# world frame match [[-0.14978878]
#  [-5.74791386]]
# robot_measurement [[-0.02743765]
#  [-1.90018878]]
# world frame match [[ 1.12873615]
#  [-1.84187537]]
# robot_measurement [[ 0.6150575 ]
#  [-0.10273942]]
# world frame match [[-1.68344322]
#  [-0.4513129 ]]
# robot_measurement [[-0.06055299]
#  [-1.62293817]]
# world frame match [[ 1.12873615]
#  [-1.84187537]]
# robot_measurement [[ 0.75373542]
#  [-0.08125534]]
# world frame match [[-1.68344322]
#  [-0.4513129 ]]
# robot_measurement [[-0.18428976]
#  [-1.39410634]]
# world frame match [[-1.77734279]
#  [-1.13417398]]
# robot_measurement [[1.51915835]
#  [0.82148821]]
# world frame match [[-1.46779026]
#  [ 0.61999593]]
# robot_measurement [[-0.05231264]
#  [-1.6185019 ]]
# world frame match [[ 1.12873615]
#  [-1.84187537]]
# robot_measurement [[-1.29011523]
#  [ 8.3059523 ]]
# world frame match [[-0.4305185 ]
#  [ 8.44877735]]
# robot_measurement [[-0.06736662]
#  [ 1.4007296 ]]
# world frame match [[1.10650322]
#  [1.37734515]]
# Scan 5
# x_hat = [[-2.0745749 ]
#  [ 2.64915566]
#  [ 0.38934333]]
# [[-0.20675546]
#  [-0.00486616]
#  [ 0.        ]]
# [[-2.38160540e-07]
#  [ 1.68395125e-08]
#  [ 0.00000000e+00]]
# [[-1.21546511e-06]
#  [ 8.61443223e-08]
#  [ 0.00000000e+00]]
# [[ 8.22777637e-08]
#  [-5.84832494e-09]
#  [ 0.00000000e+00]]
# [[-4.37707760e-04]
#  [ 3.69234536e-05]
#  [ 0.00000000e+00]]
# [[-6.65834765e-06]
#  [ 4.71747098e-07]
#  [ 0.00000000e+00]]
# [[-0.00675285]
#  [ 0.00048484]
#  [ 0.        ]]
# [[-9.40622499e-04]
#  [ 6.68970924e-05]
#  [ 0.00000000e+00]]
# [[ 2.08897656e-06]
#  [-1.99382384e-07]
#  [ 0.00000000e+00]]
# [[ 0.00476896]
#  [-0.00034576]
#  [ 0.        ]]
# [[-5.95195062e-07]
#  [ 4.12020587e-08]
#  [ 0.00000000e+00]]
# [[-2.26576708e-06]
#  [-8.23780910e-08]
#  [ 0.00000000e+00]]
# [[ 1.36407629e-06]
#  [-1.30471914e-07]
#  [ 0.00000000e+00]]
# [[ 1.62193249e-04]
#  [-1.12373247e-05]
#  [ 0.00000000e+00]]
# [[-1.86736982e-05]
#  [ 1.31687716e-06]
#  [ 0.00000000e+00]]
# [[-0.04823708]
#  [ 0.00469613]
#  [ 0.        ]]
# [[-1.28268947e-03]
#  [ 9.18102284e-05]
#  [ 0.00000000e+00]]
# [[ 0.10591685]
#  [-0.01031524]
#  [ 0.        ]]
# [[-5.74698046e-04]
#  [ 4.09987374e-05]
#  [ 0.00000000e+00]]
# [[ 0.11110858]
#  [-0.0079841 ]
#  [ 0.        ]]
# [[-3.44535422e-05]
#  [ 2.43430831e-06]
#  [ 0.00000000e+00]]
# [[ 0.1367778 ]
#  [-0.01379359]
#  [ 0.        ]]
# [[ 6.63171634e-07]
#  [-4.60756175e-08]
#  [ 0.00000000e+00]]
# [[-2.76199177e-03]
#  [-6.49960525e-05]
#  [ 0.00000000e+00]]
# x_t = [[-1.98364351]
#  [ 2.61719609]
#  [ 0.38934333]]
# covarience = [[ 3.68564206e-08 -2.56218068e-09  0.00000000e+00]
#  [-2.56218068e-09  1.97228400e-10  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.95957952e-11]]), array([[0.        , 0.        ],
#        [0.        , 0.01321477]]), array([[0.        , 0.        ],
#        [0.        , 0.03054639]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.96008897e-07]]), array([[0.       , 0.       ],
#        [0.       , 0.0029399]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.84653917e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.66724618e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.04659979e-05]]), array([[0.       , 0.       ],
#        [0.       , 0.0005828]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.14429348e-05]]), array([[0.        , 0.        ],
#        [0.        , 0.00011626]]), array([[0.        , 0.        ],
#        [0.        , 0.00955429]]), array([[0.        , 0.        ],
#        [0.        , 0.00048751]]), array([[0.        , 0.        ],
#        [0.        , 0.00636184]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.10697437e-11]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.15406831e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 9.48135798e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.04037291e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.45448004e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00010368]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.13480427e-10]]), array([[0.        , 0.        ],
#        [0.        , 0.00601475]]), array([[0.000000e+00, 0.000000e+00],
#        [0.000000e+00, 1.456734e-10]])]
# (2, 1, 82)
# (2, 1, 23)
# bestmatch 0 22 mah_dist_best [[1.46532647e-12]]
# bestmatch 1 63 mah_dist_best [[0.00058992]]
# bestmatch 2 33 mah_dist_best [[0.00015758]]
# bestmatch 3 43 mah_dist_best [[4.55100919e-10]]
# bestmatch 4 65 mah_dist_best [[0.00042869]]
# bestmatch 5 46 mah_dist_best [[3.50591394e-11]]
# bestmatch 6 14 mah_dist_best [[5.59322629e-06]]
# bestmatch 7 71 mah_dist_best [[3.9253732e-06]]
# bestmatch 8 56 mah_dist_best [[2.60553578e-08]]
# bestmatch 9 45 mah_dist_best [[1.29547812e-06]]
# bestmatch 10 14 mah_dist_best [[5.99472874e-06]]
# bestmatch 11 7 mah_dist_best [[6.98753601e-05]]
# bestmatch 12 14 mah_dist_best [[3.83619648e-05]]
# bestmatch 13 63 mah_dist_best [[0.00263799]]
# bestmatch 14 47 mah_dist_best [[1.62972819e-14]]
# bestmatch 15 32 mah_dist_best [[4.9935783e-07]]
# bestmatch 16 47 mah_dist_best [[3.61678231e-10]]
# bestmatch 17 34 mah_dist_best [[1.15763559e-06]]
# bestmatch 18 71 mah_dist_best [[1.14240875e-09]]
# bestmatch 19 73 mah_dist_best [[2.56489953e-06]]
# bestmatch 20 47 mah_dist_best [[2.7739521e-11]]
# bestmatch 21 24 mah_dist_best [[8.05596408e-08]]
# bestmatch 22 22 mah_dist_best [[2.02258147e-12]]
# [[0, 22], [1, 63], [2, 33], [3, 43], [4, 65], [5, 46], [6, 14], [7, 71], [8, 56], [9, 45], [10, 14], [11, 7], [12, 14], [13, 63], [14, 47], [15, 32], [16, 47], [17, 34], [18, 71], [19, 73], [20, 47], [21, 24], [22, 22]]
# robot_measurement [[-0.04039761]
#  [ 1.39756707]]
# world frame match [[1.10650322]
#  [1.3386664 ]]
# robot_measurement [[-1.5157123]
#  [-6.0551161]]
# world frame match [[-0.14978878]
#  [-5.84383164]]
# robot_measurement [[0.56393121]
#  [6.91298289]]
# world frame match [[-0.41152447]
#  [ 6.84115878]]
# robot_measurement [[-0.40508485]
#  [ 1.25863586]]
# world frame match [[1.14056553]
#  [1.29782916]]
# robot_measurement [[0.47938599]
#  [8.87683621]]
# world frame match [[-0.53451948]
#  [ 8.49497878]]
# robot_measurement [[0.07634732]
#  [5.86005016]]
# world frame match [[-1.65063588]
#  [ 5.88599993]]
# robot_measurement [[1.51583738]
#  [4.94879374]]
# world frame match [[1.12991511]
#  [4.69476088]]
# robot_measurement [[-0.39966576]
#  [-1.3275789 ]]
# world frame match [[-1.77734279]
#  [-1.11927644]]
# robot_measurement [[1.41072036]
#  [4.5592851 ]]
# world frame match [[1.15578891]
#  [4.56597142]]
# robot_measurement [[0.31354213]
#  [1.6805013 ]]
# world frame match [[0.78137039]
#  [1.92626324]]
# robot_measurement [[1.54359081]
#  [4.92183481]]
# world frame match [[1.12991511]
#  [4.69476088]]
# robot_measurement [[1.08476659]
#  [4.20288667]]
# world frame match [[0.85284748]
#  [4.11736763]]
# robot_measurement [[1.51211605]
#  [4.97527676]]
# world frame match [[1.12991511]
#  [4.69476088]]
# robot_measurement [[-1.30408653]
#  [-5.19989387]]
# world frame match [[-0.14978878]
#  [-5.84383164]]
# robot_measurement [[-0.02406205]
#  [-1.88583163]]
# world frame match [[ 1.12873615]
#  [-1.87858194]]
# robot_measurement [[ 0.61642775]
#  [-0.09881967]]
# world frame match [[-1.68344322]
#  [-0.44540953]]
# robot_measurement [[-0.10697653]
#  [-1.68628006]]
# world frame match [[ 1.12873615]
#  [-1.87858194]]
# robot_measurement [[ 0.76976405]
#  [-0.04125581]]
# world frame match [[-1.50783474]
#  [ 0.29220225]]
# robot_measurement [[-0.17902812]
#  [-1.38687521]]
# world frame match [[-1.77734279]
#  [-1.11927644]]
# robot_measurement [[1.4784295 ]
#  [0.76245639]]
# world frame match [[-1.46779026]
#  [ 0.60517645]]
# robot_measurement [[-0.05194616]
#  [-1.61925879]]
# world frame match [[ 1.12873615]
#  [-1.87858194]]
# robot_measurement [[-1.33373523]
#  [ 8.41633799]]
# world frame match [[-0.46274984]
#  [ 8.41267826]]
# robot_measurement [[-0.06030213]
#  [ 1.39939386]]
# world frame match [[1.10650322]
#  [1.3386664 ]]
# Scan 6
# x_hat = [[-1.98364351]
#  [ 2.61719609]
#  [ 0.38934333]]
# [[-0.38486044]
#  [-0.02742679]
#  [ 0.        ]]
# [[ 2.87493548e-07]
#  [-1.95589980e-08]
#  [ 0.00000000e+00]]
# [[-4.43165660e-08]
#  [ 3.02639247e-09]
#  [ 0.00000000e+00]]
# [[-6.80722870e-05]
#  [ 7.01539863e-06]
#  [ 0.00000000e+00]]
# [[-2.4432513e-06]
#  [ 1.6713149e-07]
#  [ 0.0000000e+00]]
# [[ 0.00346757]
#  [-0.00024523]
#  [ 0.        ]]
# [[ 8.67133182e-07]
#  [-1.11507747e-07]
#  [ 0.00000000e+00]]
# [[ 1.02497187e-05]
#  [-7.38966486e-07]
#  [ 0.00000000e+00]]
# [[-8.71538797e-09]
#  [ 7.99265987e-10]
#  [ 0.00000000e+00]]
# [[ 6.69868289e-05]
#  [-4.37548832e-06]
#  [ 0.00000000e+00]]
# [[ 5.77792559e-07]
#  [-7.43036042e-08]
#  [ 0.00000000e+00]]
# [[-4.13533128e-08]
#  [ 2.66610378e-09]
#  [ 0.00000000e+00]]
# [[ 1.70220185e-07]
#  [-2.18901639e-08]
#  [ 0.00000000e+00]]
# [[-1.72992943e-06]
#  [ 1.17447879e-07]
#  [ 0.00000000e+00]]
# [[-0.00642218]
#  [ 0.00085574]
#  [ 0.        ]]
# [[-4.97130133e-04]
#  [ 3.47808443e-05]
#  [ 0.00000000e+00]]
# [[ 0.00501351]
#  [-0.00066822]
#  [ 0.        ]]
# [[ 2.80970258e-04]
#  [-1.93707884e-05]
#  [ 0.00000000e+00]]
# [[ 0.07328277]
#  [-0.00520342]
#  [ 0.        ]]
# [[-1.32498894e-05]
#  [ 9.09422161e-07]
#  [ 0.00000000e+00]]
# [[ 0.14618376]
#  [-0.02034254]
#  [ 0.        ]]
# [[-9.93756633e-09]
#  [ 6.60164812e-10]
#  [ 0.00000000e+00]]
# [[-0.01571196]
#  [-0.00073802]
#  [ 0.        ]]
# x_t = [[-2.1629131 ]
#  [ 2.56344589]
#  [ 0.38934333]]
# covarience = [[ 1.62602704e-08 -1.08317297e-09  0.00000000e+00]
#  [-1.08317297e-09  8.78094517e-11  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.17349667e-11]]), array([[0.        , 0.        ],
#        [0.        , 0.00525899]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.82734042e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.50230341e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.86554232e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.51496805e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00033565]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.35670595e-06]]), array([[0.        , 0.        ],
#        [0.        , 0.00010102]]), array([[0.        , 0.        ],
#        [0.        , 0.00934903]]), array([[0.        , 0.        ],
#        [0.        , 0.00371378]]), array([[0.        , 0.        ],
#        [0.        , 0.00537088]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 2.1132559e-12]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.15166062e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.23006215e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.00341864e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.25067806e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00011936]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.14968017e-10]]), array([[0.        , 0.        ],
#        [0.        , 0.21732194]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.12281238e-11]])]
# (2, 1, 82)
# (2, 1, 21)
# bestmatch 0 22 mah_dist_best [[1.98536477e-12]]
# bestmatch 1 29 mah_dist_best [[6.42410429e-05]]
# bestmatch 2 64 mah_dist_best [[7.42229491e-14]]
# bestmatch 3 46 mah_dist_best [[2.90911893e-10]]
# bestmatch 4 14 mah_dist_best [[6.84346113e-06]]
# bestmatch 5 78 mah_dist_best [[1.9183815e-09]]
# bestmatch 6 75 mah_dist_best [[1.78167329e-08]]
# bestmatch 7 22 mah_dist_best [[3.95771888e-08]]
# bestmatch 8 14 mah_dist_best [[7.29922668e-06]]
# bestmatch 9 42 mah_dist_best [[9.20799459e-06]]
# bestmatch 10 63 mah_dist_best [[0.00147706]]
# bestmatch 11 63 mah_dist_best [[0.00128986]]
# bestmatch 12 47 mah_dist_best [[1.99207176e-13]]
# bestmatch 13 32 mah_dist_best [[2.51474709e-07]]
# bestmatch 14 47 mah_dist_best [[1.17508667e-10]]
# bestmatch 15 32 mah_dist_best [[9.23094739e-07]]
# bestmatch 16 71 mah_dist_best [[2.95390138e-09]]
# bestmatch 17 73 mah_dist_best [[1.57175764e-06]]
# bestmatch 18 47 mah_dist_best [[2.28658905e-11]]
# bestmatch 19 1 mah_dist_best [[0.00167679]]
# bestmatch 20 22 mah_dist_best [[2.22358398e-12]]
# [[0, 22], [1, 29], [2, 64], [3, 46], [4, 14], [5, 78], [6, 75], [7, 22], [8, 14], [9, 42], [10, 63], [11, 63], [12, 47], [13, 32], [14, 47], [15, 32], [16, 71], [17, 73], [18, 47], [19, 1], [20, 22]]
# robot_measurement [[-0.04106666]
#  [ 1.39806876]]
# world frame match [[1.10650322]
#  [1.29849074]]
# robot_measurement [[1.439449  ]
#  [6.85541284]]
# world frame match [[-0.44397725]
#  [ 6.9659363 ]]
# robot_measurement [[-0.40040799]
#  [ 1.25272532]]
# world frame match [[1.13958999]
#  [1.25323758]]
# robot_measurement [[0.0944782 ]
#  [6.03557341]]
# world frame match [[-1.65063588]
#  [ 5.99179919]]
# robot_measurement [[1.51911704]
#  [4.94528399]]
# world frame match [[1.12991511]
#  [4.65031714]]
# robot_measurement [[-0.24815115]
#  [-0.63306729]]
# world frame match [[-1.20669892]
#  [-0.47074424]]
# robot_measurement [[1.36370198]
#  [4.53497776]]
# world frame match [[1.15099324]
#  [4.54226348]]
# robot_measurement [[0.26246116]
#  [1.46927626]]
# world frame match [[1.10650322]
#  [1.29849074]]
# robot_measurement [[1.54411705]
#  [4.9191195 ]]
# world frame match [[1.12991511]
#  [4.65031714]]
# robot_measurement [[1.10422258]
#  [4.24746309]]
# world frame match [[1.13669163]
#  [4.27884643]]
# robot_measurement [[-1.56006427]
#  [-5.05178239]]
# world frame match [[-0.14978878]
#  [-5.68243462]]
# robot_measurement [[-1.34939345]
#  [-5.19237632]]
# world frame match [[-0.14978878]
#  [-5.68243462]]
# robot_measurement [[-0.0185067]
#  [-1.8843728]]
# world frame match [[ 1.12873615]
#  [-1.92281132]]
# robot_measurement [[ 0.61647915]
#  [-0.09865551]]
# world frame match [[-1.68344322]
#  [-0.3447311 ]]
# robot_measurement [[-0.06881999]
#  [-1.62916607]]
# world frame match [[ 1.12873615]
#  [-1.92281132]]
# robot_measurement [[ 0.76380117]
#  [-0.04144393]]
# world frame match [[-1.68344322]
#  [-0.3447311 ]]
# robot_measurement [[-0.19136784]
#  [-1.39120529]]
# world frame match [[-1.77734279]
#  [-1.03383404]]
# robot_measurement [[1.54399285]
#  [0.85203603]]
# world frame match [[-1.46779026]
#  [ 0.73728275]]
# robot_measurement [[-0.052243  ]
#  [-1.61896888]]
# world frame match [[ 1.12873615]
#  [-1.92281132]]
# robot_measurement [[-1.35273264]
#  [ 8.45272983]]
# world frame match [[-0.4305185 ]
#  [ 8.54056879]]
# robot_measurement [[-0.04522755]
#  [ 1.39909029]]
# world frame match [[1.10650322]
#  [1.29849074]]
# Scan 7
# x_hat = [[-2.1629131 ]
#  [ 2.56344589]
#  [ 0.38934333]]
# [[-0.60553817]
#  [-0.04354822]
#  [ 0.        ]]
# [[ 1.86456021e-07]
#  [-1.12306213e-08]
#  [ 0.00000000e+00]]
# [[-2.92247236e-07]
#  [ 4.92391177e-08]
#  [ 0.00000000e+00]]
# [[-9.23992077e-04]
#  [ 6.03594132e-05]
#  [ 0.00000000e+00]]
# [[ 2.79754423e-07]
#  [-8.23415900e-08]
#  [ 0.00000000e+00]]
# [[ 0.01426377]
#  [-0.00088546]
#  [ 0.        ]]
# [[-5.26119770e-09]
#  [ 6.94988955e-10]
#  [ 0.00000000e+00]]
# [[-1.56358122e-05]
#  [-1.25862820e-06]
#  [ 0.00000000e+00]]
# [[ 1.82823888e-07]
#  [-5.74512957e-08]
#  [ 0.00000000e+00]]
# [[-4.18096668e-10]
#  [ 8.37347969e-11]
#  [ 0.00000000e+00]]
# [[-1.33717034e-06]
#  [ 7.94544226e-08]
#  [ 0.00000000e+00]]
# [[-7.18479997e-07]
#  [ 4.26919531e-08]
#  [ 0.00000000e+00]]
# [[ 0.01681875]
#  [-0.00598927]
#  [ 0.        ]]
# [[-1.60322674e-04]
#  [ 1.03291921e-05]
#  [ 0.00000000e+00]]
# [[ 0.01102229]
#  [-0.0039264 ]
#  [ 0.        ]]
# [[-8.17174470e-05]
#  [ 5.25442453e-06]
#  [ 0.00000000e+00]]
# [[ 0.03036056]
#  [-0.0020183 ]
#  [ 0.        ]]
# [[-4.04876826e-06]
#  [ 2.50760962e-07]
#  [ 0.00000000e+00]]
# [[ 0.05922254]
#  [-0.02191244]
#  [ 0.        ]]
# [[ 3.24644533e-09]
#  [-1.89897875e-10]
#  [ 0.00000000e+00]]
# [[-0.06103313]
#  [-0.00288697]
#  [ 0.        ]]
# x_t = [[-2.6989839 ]
#  [ 2.48235378]
#  [ 0.38934333]]
# covarience = [[ 7.93865374e-09 -4.72339520e-10  0.00000000e+00]
#  [-4.72339520e-10  4.13230626e-11  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.72176386e-11]]), array([[0.        , 0.        ],
#        [0.        , 0.00974908]]), array([[0.        , 0.        ],
#        [0.        , 0.02444963]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.96807453e-07]]), array([[0.       , 0.       ],
#        [0.       , 0.0038207]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.85501653e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.02565115e-05]]), array([[0.        , 0.        ],
#        [0.        , 0.00018664]]), array([[0.        , 0.        ],
#        [0.        , 0.00035571]]), array([[0.000000e+00, 0.000000e+00],
#        [0.000000e+00, 1.633831e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00010826]]), array([[0.        , 0.        ],
#        [0.        , 0.00303946]]), array([[0.        , 0.        ],
#        [0.        , 0.00149175]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.38376561e-09]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.25850454e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.10247338e-11]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.03802124e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.93308651e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00012639]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.15955852e-11]]), array([[0.        , 0.        ],
#        [0.        , 0.12090037]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.14504647e-11]])]
# (2, 1, 82)
# (2, 1, 22)
# bestmatch 0 22 mah_dist_best [[2.23570664e-12]]
# bestmatch 1 63 mah_dist_best [[0.00941235]]
# bestmatch 2 29 mah_dist_best [[0.00046014]]
# bestmatch 3 11 mah_dist_best [[4.32567965e-09]]
# bestmatch 4 65 mah_dist_best [[0.00014591]]
# bestmatch 5 46 mah_dist_best [[9.851542e-09]]
# bestmatch 6 69 mah_dist_best [[9.12119084e-06]]
# bestmatch 7 47 mah_dist_best [[4.3058934e-05]]
# bestmatch 8 14 mah_dist_best [[1.02274309e-06]]
# bestmatch 9 73 mah_dist_best [[6.50159433e-12]]
# bestmatch 10 69 mah_dist_best [[1.06029628e-05]]
# bestmatch 11 58 mah_dist_best [[3.68441344e-07]]
# bestmatch 12 63 mah_dist_best [[9.13242067e-06]]
# bestmatch 13 47 mah_dist_best [[1.83024068e-12]]
# bestmatch 14 32 mah_dist_best [[8.51333293e-10]]
# bestmatch 15 47 mah_dist_best [[1.56437432e-11]]
# bestmatch 16 78 mah_dist_best [[1.36578639e-10]]
# bestmatch 17 71 mah_dist_best [[5.66093881e-09]]
# bestmatch 18 34 mah_dist_best [[2.86219189e-06]]
# bestmatch 19 47 mah_dist_best [[1.18733556e-11]]
# bestmatch 20 2 mah_dist_best [[7.49717709e-05]]
# bestmatch 21 22 mah_dist_best [[2.32662381e-12]]
# [[0, 22], [1, 63], [2, 29], [3, 11], [4, 65], [5, 46], [6, 69], [7, 47], [8, 14], [9, 73], [10, 69], [11, 58], [12, 63], [13, 47], [14, 32], [15, 47], [16, 78], [17, 71], [18, 34], [19, 47], [20, 2], [21, 22]]
# robot_measurement [[-0.04238583]
#  [ 1.398538  ]]
# world frame match [[1.10650322]
#  [1.25776706]]
# robot_measurement [[-1.54028047]
#  [-6.16349084]]
# world frame match [[-0.14978878]
#  [-5.1809127 ]]
# robot_measurement [[0.75928228]
#  [7.36844983]]
# world frame match [[-0.44397725]
#  [ 7.50563543]]
# robot_measurement [[-0.44002428]
#  [ 0.95529958]]
# world frame match [[-1.4692266 ]
#  [ 1.04844238]]
# robot_measurement [[0.57797199]
#  [9.41772374]]
# world frame match [[-0.53451948]
#  [ 9.22230129]]
# robot_measurement [[0.07898058]
#  [5.87990692]]
# world frame match [[-1.65063588]
#  [ 6.23231788]]
# robot_measurement [[1.52405075]
#  [4.94179975]]
# world frame match [[0.79394135]
#  [4.60468134]]
# robot_measurement [[-0.43545697]
#  [-1.49523134]]
# world frame match [[ 1.12873615]
#  [-1.97554391]]
# robot_measurement [[1.37889542]
#  [4.54332761]]
# world frame match [[1.12991511]
#  [4.59694842]]
# robot_measurement [[0.18055731]
#  [1.08107204]]
# world frame match [[-1.46779026]
#  [ 1.06214248]]
# robot_measurement [[1.54737566]
#  [4.917626  ]]
# world frame match [[0.79394135]
#  [4.60468134]]
# robot_measurement [[1.12208971]
#  [4.28867739]]
# world frame match [[1.11669216]
#  [4.27766742]]
# robot_measurement [[-1.47773118]
#  [-5.10266988]]
# world frame match [[-0.14978878]
#  [-5.1809127 ]]
# robot_measurement [[-0.0606407 ]
#  [-2.00289255]]
# world frame match [[ 1.12873615]
#  [-1.97554391]]
# robot_measurement [[ 0.61948698]
#  [-0.10614202]]
# world frame match [[-1.68344322]
#  [-0.12028005]]
# robot_measurement [[-0.04481011]
#  [-1.62074765]]
# world frame match [[ 1.12873615]
#  [-1.97554391]]
# robot_measurement [[ 0.76972192]
#  [-0.04121984]]
# world frame match [[-1.20669892]
#  [-0.04484653]]
# robot_measurement [[-0.18938534]
#  [-1.39361479]]
# world frame match [[-1.77734279]
#  [-0.85664575]]
# robot_measurement [[1.56336445]
#  [0.87659853]]
# world frame match [[-1.50783474]
#  [ 0.72611735]]
# robot_measurement [[-0.04269362]
#  [-1.62172721]]
# world frame match [[ 1.12873615]
#  [-1.97554391]]
# robot_measurement [[-1.27244667]
#  [ 8.25218315]]
# world frame match [[-1.02892653]
#  [ 8.2770852 ]]
# robot_measurement [[-0.04321166]
#  [ 1.39875139]]
# world frame match [[1.10650322]
#  [1.25776706]]
# Scan 8
# x_hat = [[-2.6989839 ]
#  [ 2.48235378]
#  [ 0.38934333]]
# [[-0.74171101]
#  [-0.0514157 ]
#  [ 0.        ]]
# [[ 4.65413299e-07]
#  [-2.06293218e-08]
#  [ 0.00000000e+00]]
# [[ 2.69957194e-08]
#  [-1.22446142e-09]
#  [ 0.00000000e+00]]
# [[ 4.59068585e-04]
#  [-2.34490277e-05]
#  [ 0.00000000e+00]]
# [[-2.44250848e-07]
#  [ 1.11511755e-08]
#  [ 0.00000000e+00]]
# [[ 0.00740387]
#  [-0.000404  ]
#  [ 0.        ]]
# [[-6.72009221e-06]
#  [ 2.38967014e-07]
#  [ 0.00000000e+00]]
# [[-9.39220097e-08]
#  [-3.80688583e-08]
#  [ 0.00000000e+00]]
# [[4.65496974e-09]
#  [2.26827446e-09]
#  [0.00000000e+00]]
# [[-0.00254442]
#  [ 0.00012985]
#  [ 0.        ]]
# [[-4.31106182e-06]
#  [ 1.48453533e-07]
#  [ 0.00000000e+00]]
# [[-3.23661986e-10]
#  [-4.50093296e-11]
#  [ 0.00000000e+00]]
# [[-2.23337342e-07]
#  [ 9.76656933e-09]
#  [ 0.00000000e+00]]
# [[0.00040156]
#  [0.00016566]
#  [0.        ]]
# [[-4.65058031e-06]
#  [ 2.60059406e-07]
#  [ 0.00000000e+00]]
# [[-0.10188203]
#  [-0.04202724]
#  [ 0.        ]]
# [[-1.10774484e-06]
#  [ 5.43053225e-08]
#  [ 0.00000000e+00]]
# [[ 0.02741056]
#  [-0.00163596]
#  [ 0.        ]]
# [[-2.48613131e-06]
#  [ 1.28544049e-07]
#  [ 0.00000000e+00]]
# [[-0.11666893]
#  [-0.04751071]
#  [ 0.        ]]
# [[ 7.45180806e-10]
#  [-3.62585517e-11]
#  [ 0.00000000e+00]]
# [[-0.14876612]
#  [-0.00754467]
#  [ 0.        ]]
# x_t = [[-3.77490069]
#  [ 2.33208836]
#  [ 0.38934333]]
# covarience = [[ 4.22751671e-09 -2.09980340e-10  0.00000000e+00]
#  [-2.09980340e-10  2.12176306e-11  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]]
#
#
#
#
# [array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.66581038e-11]]), array([[0.       , 0.       ],
#        [0.       , 0.0242466]]), array([[0.        , 0.        ],
#        [0.        , 0.01737357]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.17714791e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00066823]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.67884525e-08]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.10680365e-07]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.10008927e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.54973021e-07]]), array([[0.        , 0.        ],
#        [0.        , 0.00035043]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.57921851e-06]]), array([[0.       , 0.       ],
#        [0.       , 0.0001017]]), array([[0.        , 0.        ],
#        [0.        , 0.00656916]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.08151073e-12]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.14534951e-06]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.40717066e-09]]), array([[0.000000e+00, 0.000000e+00],
#        [0.000000e+00, 1.061277e-05]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.47593628e-08]]), array([[0.        , 0.        ],
#        [0.        , 0.00010803]]), array([[0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 9.1903444e-11]]), array([[0.        , 0.        ],
#        [0.        , 0.15241233]]), array([[0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.92737306e-11]])]
# (2, 1, 82)
# (2, 1, 22)
# bestmatch 0 22 mah_dist_best [[3.15424519e-12]]
# bestmatch 1 31 mah_dist_best [[0.00015905]]
# bestmatch 2 63 mah_dist_best [[0.0801285]]
# bestmatch 3 11 mah_dist_best [[3.09280149e-12]]
# bestmatch 4 29 mah_dist_best [[2.52972847e-05]]
# bestmatch 5 46 mah_dist_best [[1.35778573e-08]]
# bestmatch 6 71 mah_dist_best [[3.95580423e-09]]
# bestmatch 7 69 mah_dist_best [[4.36715755e-07]]
# bestmatch 8 71 mah_dist_best [[3.7222467e-08]]
# bestmatch 9 14 mah_dist_best [[5.70213539e-07]]
# bestmatch 10 34 mah_dist_best [[2.01205443e-08]]
# bestmatch 11 69 mah_dist_best [[6.62565624e-07]]
# bestmatch 12 63 mah_dist_best [[0.00684384]]
# bestmatch 13 47 mah_dist_best [[1.19722544e-12]]
# bestmatch 14 57 mah_dist_best [[3.19946036e-07]]
# bestmatch 15 47 mah_dist_best [[4.40891967e-10]]
# bestmatch 16 57 mah_dist_best [[5.13980695e-07]]
# bestmatch 17 47 mah_dist_best [[1.11177135e-08]]
# bestmatch 18 78 mah_dist_best [[6.33241342e-08]]
# bestmatch 19 47 mah_dist_best [[2.53133328e-11]]
# bestmatch 20 29 mah_dist_best [[4.83463025e-05]]
# bestmatch 21 22 mah_dist_best [[3.72786678e-12]]
# [[0, 22], [1, 31], [2, 63], [3, 11], [4, 29], [5, 46], [6, 71], [7, 69], [8, 71], [9, 14], [10, 34], [11, 69], [12, 63], [13, 47], [14, 57], [15, 47], [16, 57], [17, 47], [18, 78], [19, 47], [20, 29], [21, 22]]
# robot_measurement [[-0.04175731]
#  [ 1.39858258]]
# world frame match [[1.10650322]
#  [1.18848774]]
# robot_measurement [[1.02763073]
#  [7.86576725]]
# world frame match [[-0.58618852]
#  [ 7.78477548]]
# robot_measurement [[-1.57015083]
#  [-6.31895162]]
# world frame match [[-0.14978878]
#  [-4.17137351]]
# robot_measurement [[-0.36602198]
#  [ 1.68442194]]
# world frame match [[-1.4692266 ]
#  [ 1.68818274]]
# robot_measurement [[0.39570011]
#  [8.39358333]]
# world frame match [[-0.44397725]
#  [ 8.58815239]]
# robot_measurement [[0.0905912 ]
#  [5.99662043]]
# world frame match [[-1.65063588]
#  [ 6.70315265]]
# robot_measurement [[-0.48856034]
#  [-0.60130152]]
# world frame match [[-1.77734279]
#  [-0.51330313]]
# robot_measurement [[1.52210788]
#  [4.94555788]]
# world frame match [[0.79394135]
#  [4.87213137]]
# robot_measurement [[-0.32504981]
#  [-1.00313852]]
# world frame match [[-1.77734279]
#  [-0.51330313]]
# robot_measurement [[1.37669708]
#  [4.54264655]]
# world frame match [[1.12991511]
#  [4.50230845]]
# robot_measurement [[0.26275638]
#  [1.4443367 ]]
# world frame match [[-1.50783474]
#  [ 1.3314909 ]]
# robot_measurement [[1.50756436]
#  [4.9528467 ]]
# world frame match [[0.79394135]
#  [4.87213137]]
# robot_measurement [[-1.35699955]
#  [-5.19206582]]
# world frame match [[-0.14978878]
#  [-4.17137351]]
# robot_measurement [[-0.02327227]
#  [-1.89364954]]
# world frame match [[ 1.12873615]
#  [-2.06890791]]
# robot_measurement [[ 0.61655861]
#  [-0.09879825]]
# world frame match [[-1.34376185]
#  [ 0.17897029]]
# robot_measurement [[-0.07817555]
#  [-1.64383325]]
# world frame match [[ 1.12873615]
#  [-2.06890791]]
# robot_measurement [[ 0.76964951]
#  [-0.041084  ]]
# world frame match [[-1.34376185]
#  [ 0.17897029]]
# robot_measurement [[-0.1971289 ]
#  [-1.39925511]]
# world frame match [[ 1.12873615]
#  [-2.06890791]]
# robot_measurement [[1.48629993]
#  [0.77662763]]
# world frame match [[-1.20669892]
#  [ 0.80083885]]
# robot_measurement [[-0.05065823]
#  [-1.61853976]]
# world frame match [[ 1.12873615]
#  [-2.06890791]]
# robot_measurement [[-1.43042014]
#  [ 8.57034208]]
# world frame match [[-0.44397725]
#  [ 8.58815239]]
# robot_measurement [[-0.0436844 ]
#  [ 1.39905673]]
# world frame match [[1.10650322]
#  [1.18848774]]
# Scan 9
# x_hat = [[-3.77490069]
#  [ 2.33208836]
#  [ 0.38934333]]
# [[-0.93067847]
#  [-0.06220519]
#  [ 0.        ]]
# [[-9.31623312e-09]
#  [ 3.16799031e-10]
#  [ 0.00000000e+00]]
# [[ 3.36511406e-07]
#  [-1.08162324e-08]
#  [ 0.00000000e+00]]
# [[ 2.43283332e-05]
#  [-9.86720126e-07]
#  [ 0.00000000e+00]]
# [[ 8.20223436e-07]
#  [-2.73791438e-08]
#  [ 0.00000000e+00]]
# [[ 0.02458993]
#  [-0.00110819]
#  [ 0.        ]]
# [[ 1.02712576e-04]
#  [-5.39584415e-06]
#  [ 0.00000000e+00]]
# [[-8.76042217e-07]
#  [ 1.89778731e-08]
#  [ 0.00000000e+00]]
# [[ 1.88217312e-03]
#  [-9.88772419e-05]
#  [ 0.00000000e+00]]
# [[-5.94284089e-09]
#  [-1.16473764e-09]
#  [ 0.00000000e+00]]
# [[-9.26680830e-05]
#  [ 3.81739263e-06]
#  [ 0.00000000e+00]]
# [[-7.66127026e-07]
#  [ 1.65726712e-08]
#  [ 0.00000000e+00]]
# [[ 4.16089606e-07]
#  [-1.32884943e-08]
#  [ 0.00000000e+00]]
# [[-0.24682387]
#  [-0.04500939]
#  [ 0.        ]]
# [[ 1.10399224e-04]
#  [-4.76728379e-06]
#  [ 0.00000000e+00]]
# [[-0.00639966]
#  [-0.00116725]
#  [ 0.        ]]
# [[ 3.41560636e-05]
#  [-1.47604500e-06]
#  [ 0.00000000e+00]]
# [[-0.00098869]
#  [-0.00018034]
#  [ 0.        ]]
# [[ 4.31332568e-07]
#  [-1.82337039e-08]
#  [ 0.00000000e+00]]
# [[-0.13204591]
#  [-0.0240865 ]
#  [ 0.        ]]
# [[ 3.14499538e-10]
#  [-1.26534339e-11]
#  [ 0.00000000e+00]]
# [[-0.23516309]
#  [-0.00953321]
#  [ 0.        ]]
# x_t = [[-5.300349  ]
#  [ 2.18869056]
#  [ 0.38934333]]
# covarience = [[ 2.58460430e-09 -1.12044062e-10  0.00000000e+00]
#  [-1.12044062e-10  1.17390293e-11  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]]

# %%
plt.figure()
# plt.xlim(-1,1)
# plt.ylim(-1,1)
color = []
for i in range(len(all_xt)):
    
    color.append(i/len(all_xt))
color = np.array(color)

plt.scatter(np.array(all_xhat)[:,0], np.array(all_xhat)[:,1], c='red',s = 150)
plt.scatter(np.array(all_xt)[:,0], np.array(all_xt)[:,1], c=color   ,s=100)
